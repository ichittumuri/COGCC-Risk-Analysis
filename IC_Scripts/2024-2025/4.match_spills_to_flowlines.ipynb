# %% [markdown]
# This code creates a buffer(50 meters max) around the spill points and finds the nearest flowline intersection, asserting that the operator name is the same. It then changes the matches spills geometry location to its respective flowline intersection point.
#
# - you cannot export 2 geometry columns, so we only kept the flowline geometry, not the spills

# %% [markdown]
# ## Setup

# %%
import os
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import MultiLineString, LineString, Point
from shapely.ops import nearest_points
from multiprocessing import Pool, cpu_count
from sklearn.neighbors import BallTree

os.chdir('/Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/Data')
pd.options.display.max_columns = None

# %%
# Load Data
flowlines_gdf = gpd.read_file('split_flowlines.geojson')
spills_gdf = gpd.read_file('spills.geojson')

# %%
# Check if CRS is the same for both files
if flowlines_gdf.crs != spills_gdf.crs:
    flowlines_gdf = flowlines_gdf.to_crs(spills_gdf.crs)

# %%
print(spills_gdf.crs)
print(flowlines_gdf.crs)
# Out:
# EPSG:26913
# EPSG:26913

# %%
# Check size
print(flowlines_gdf.shape)
print(spills_gdf.shape)
# Out:
# (463940, 27)
# (849, 14)

# %%
# Check and count missing geometries in spills
missing_geometry_count = spills_gdf[spills_gdf.geometry.isna()].shape[0]

# Print the count of missing geometries
print(f"Number of spills with missing geometry: {missing_geometry_count}")
# Out:
# Number of spills with missing geometry: 180

# %%
# Drop rows with missing geometries
spills_gdf = spills_gdf.dropna(subset=['geometry'])
spills_gdf.reset_index(drop=True, inplace=True)

# %%
# Check size
print(flowlines_gdf.shape)
print(spills_gdf.shape)
# Out:
# (463940, 27)
# (669, 14)

# %% [markdown]
# ## Matching

# %%
# Split the spills_gdf into two halves
spills_gdf_1 = spills_gdf.iloc[:len(spills_gdf) // 2].copy()  # First half of the spills_gdf
spills_gdf_2 = spills_gdf.iloc[len(spills_gdf) // 2:].copy()  # Second half of the spills_gdf

# %%
# Initialize counters for matches and non-matches
same_operator_match_count = 0
no_match_count = 0

# Function to create a BallTree for fast nearest neighbor search
def create_balltree(flowlines_gdf):
    coords = np.array([(geom.centroid.x, geom.centroid.y) for geom in flowlines_gdf.geometry])
    return BallTree(coords, leaf_size=15), coords

# Create BallTree for flowlines
ball_tree, flowline_coords = create_balltree(flowlines_gdf)

# Function to find the nearest flowline for each spill point that matches the operator name
def find_nearest_matching_flowline(row, flowlines_gdf, ball_tree, flowline_coords, spill_index):
    global same_operator_match_count, no_match_count
    spill_point = row.geometry
    spill_operator = row['Operator Name'].strip().lower()

    # Use BallTree to find all nearby flowlines, sorted by distance
    spill_coords = np.array([[spill_point.x, spill_point.y]])
    dist, indices = ball_tree.query(spill_coords, k=len(flowlines_gdf))
    sorted_flowlines = flowlines_gdf.iloc[indices[0]].copy()
    sorted_flowlines['distance'] = dist[0]

    # Iterate through the sorted flowlines to find the first matching operator
    for _, flowline in sorted_flowlines.iterrows():
        flowline_operator = flowline['Operator'].strip().lower()
        if spill_operator == flowline_operator:
            same_operator_match_count += 1
            print(f"Match #{same_operator_match_count}: Spill index {spill_index} matched with flowline of the same operator.")
            return flowline.name  # Return the index of the matching flowline

    # Increment the no match counter and print a message if no operator match is found
    no_match_count += 1
    print(f"No operator match found for Spill index {spill_index}")
    return None  # Return None for unmatched spills

# Function to process each spills GeoDataFrame
def process_spills_gdf(spills_gdf, flowlines_gdf, ball_tree, flowline_coords):
    # Apply the function to ensure every spill is matched with a flowline using the optimized method
    spills_gdf['nearest_flowline_index'] = spills_gdf.apply(
        lambda row: find_nearest_matching_flowline(row, flowlines_gdf, ball_tree, flowline_coords, row.name), axis=1
    )

    # Filter out unmatched spills (where nearest_flowline_index is None)
    matched_spills_gdf = spills_gdf[spills_gdf['nearest_flowline_index'].notnull()]

    # Merge the matched spills with their nearest flowlines using the indices
    matched_spills_gdf['nearest_flowline_index'] = matched_spills_gdf['nearest_flowline_index'].astype(int)
    merged_gdf = matched_spills_gdf.merge(
        flowlines_gdf, left_on='nearest_flowline_index', right_index=True, suffixes=('', '_flowline')
    )

    return merged_gdf

# Process both splits of the spills GeoDataFrame
merged_gdf_1 = process_spills_gdf(spills_gdf_1, flowlines_gdf, ball_tree, flowline_coords)
# Out:
# No operator match found for Spill index 0
# Match #1: Spill index 1 matched with flowline of the same operator.
# No operator match found for Spill index 2
# Match #2: Spill index 3 matched with flowline of the same operator.
# Match #3: Spill index 4 matched with flowline of the same operator.
# Match #4: Spill index 5 matched with flowline of the same operator.
# Match #5: Spill index 6 matched with flowline of the same operator.
# Match #6: Spill index 7 matched with flowline of the same operator.
# Match #7: Spill index 8 matched with flowline of the same operator.
# Match #8: Spill index 9 matched with flowline of the same operator.
# Match #9: Spill index 10 matched with flowline of the same operator.
# Match #10: Spill index 11 matched with flowline of the same operator.
# Match #11: Spill index 12 matched with flowline of the same operator.
# Match #12: Spill index 13 matched with flowline of the same operator.
# Match #13: Spill index 14 matched with flowline of the same operator.
# Match #14: Spill index 15 matched with flowline of the same operator.
# Match #15: Spill index 16 matched with flowline of the same operator.
# Match #16: Spill index 17 matched with flowline of the same operator.
# Match #17: Spill index 18 matched with flowline of the same operator.
# Match #18: Spill index 19 matched with flowline of the same operator.
# Match #19: Spill index 20 matched with flowline of the same operator.
# Match #20: Spill index 21 matched with flowline of the same operator.
# Match #21: Spill index 22 matched with flowline of the same operator.
# Match #22: Spill index 23 matched with flowline of the same operator.
# No operator match found for Spill index 24
# Match #23: Spill index 25 matched with flowline of the same operator.
# Match #24: Spill index 26 matched with flowline of the same operator.
# No operator match found for Spill index 27
# No operator match found for Spill index 28
# Match #25: Spill index 29 matched with flowline of the same operator.
# Match #26: Spill index 30 matched with flowline of the same operator.
# Match #27: Spill index 31 matched with flowline of the same operator.
# No operator match found for Spill index 32
# Match #28: Spill index 33 matched with flowline of the same operator.
# Match #29: Spill index 34 matched with flowline of the same operator.
# No operator match found for Spill index 35
# No operator match found for Spill index 36
# Match #30: Spill index 37 matched with flowline of the same operator.
# Match #31: Spill index 38 matched with flowline of the same operator.
# Match #32: Spill index 39 matched with flowline of the same operator.
# Match #33: Spill index 40 matched with flowline of the same operator.
# Match #34: Spill index 41 matched with flowline of the same operator.
# Match #35: Spill index 42 matched with flowline of the same operator.
# Match #36: Spill index 43 matched with flowline of the same operator.
# Match #37: Spill index 44 matched with flowline of the same operator.
# No operator match found for Spill index 45
# Match #38: Spill index 46 matched with flowline of the same operator.
# Match #39: Spill index 47 matched with flowline of the same operator.
# Match #40: Spill index 48 matched with flowline of the same operator.
# Match #41: Spill index 49 matched with flowline of the same operator.
# Match #42: Spill index 50 matched with flowline of the same operator.
# Match #43: Spill index 51 matched with flowline of the same operator.
# Match #44: Spill index 52 matched with flowline of the same operator.
# Match #45: Spill index 53 matched with flowline of the same operator.
# Match #46: Spill index 54 matched with flowline of the same operator.
# Match #47: Spill index 55 matched with flowline of the same operator.
# Match #48: Spill index 56 matched with flowline of the same operator.
# Match #49: Spill index 57 matched with flowline of the same operator.
# Match #50: Spill index 58 matched with flowline of the same operator.
# Match #51: Spill index 59 matched with flowline of the same operator.
# Match #52: Spill index 60 matched with flowline of the same operator.
# Match #53: Spill index 61 matched with flowline of the same operator.
# Match #54: Spill index 62 matched with flowline of the same operator.
# Match #55: Spill index 63 matched with flowline of the same operator.
# Match #56: Spill index 64 matched with flowline of the same operator.
# Match #57: Spill index 65 matched with flowline of the same operator.
# Match #58: Spill index 66 matched with flowline of the same operator.
# Match #59: Spill index 67 matched with flowline of the same operator.
# Match #60: Spill index 68 matched with flowline of the same operator.
# Match #61: Spill index 69 matched with flowline of the same operator.
# Match #62: Spill index 70 matched with flowline of the same operator.
# Match #63: Spill index 71 matched with flowline of the same operator.
# Match #64: Spill index 72 matched with flowline of the same operator.
# Match #65: Spill index 73 matched with flowline of the same operator.
# Match #66: Spill index 74 matched with flowline of the same operator.
# Match #67: Spill index 75 matched with flowline of the same operator.
# Match #68: Spill index 76 matched with flowline of the same operator.
# Match #69: Spill index 77 matched with flowline of the same operator.
# Match #70: Spill index 78 matched with flowline of the same operator.
# Match #71: Spill index 79 matched with flowline of the same operator.
# Match #72: Spill index 80 matched with flowline of the same operator.
# No operator match found for Spill index 81
# No operator match found for Spill index 82
# Match #73: Spill index 83 matched with flowline of the same operator.
# Match #74: Spill index 84 matched with flowline of the same operator.
# Match #75: Spill index 85 matched with flowline of the same operator.
# Match #76: Spill index 86 matched with flowline of the same operator.
# Match #77: Spill index 87 matched with flowline of the same operator.
# Match #78: Spill index 88 matched with flowline of the same operator.
# Match #79: Spill index 89 matched with flowline of the same operator.
# No operator match found for Spill index 90
# Match #80: Spill index 91 matched with flowline of the same operator.
# Match #81: Spill index 92 matched with flowline of the same operator.
# Match #82: Spill index 93 matched with flowline of the same operator.
# Match #83: Spill index 94 matched with flowline of the same operator.
# Match #84: Spill index 95 matched with flowline of the same operator.
# Match #85: Spill index 96 matched with flowline of the same operator.
# Match #86: Spill index 97 matched with flowline of the same operator.
# Match #87: Spill index 98 matched with flowline of the same operator.
# Match #88: Spill index 99 matched with flowline of the same operator.
# Match #89: Spill index 100 matched with flowline of the same operator.
# Match #90: Spill index 101 matched with flowline of the same operator.
# Match #91: Spill index 102 matched with flowline of the same operator.
# Match #92: Spill index 103 matched with flowline of the same operator.
# Match #93: Spill index 104 matched with flowline of the same operator.
# Match #94: Spill index 105 matched with flowline of the same operator.
# Match #95: Spill index 106 matched with flowline of the same operator.
# Match #96: Spill index 107 matched with flowline of the same operator.
# Match #97: Spill index 108 matched with flowline of the same operator.
# Match #98: Spill index 109 matched with flowline of the same operator.
# Match #99: Spill index 110 matched with flowline of the same operator.
# Match #100: Spill index 111 matched with flowline of the same operator.
# Match #101: Spill index 112 matched with flowline of the same operator.
# Match #102: Spill index 113 matched with flowline of the same operator.
# Match #103: Spill index 114 matched with flowline of the same operator.
# Match #104: Spill index 115 matched with flowline of the same operator.
# Match #105: Spill index 116 matched with flowline of the same operator.
# Match #106: Spill index 117 matched with flowline of the same operator.
# Match #107: Spill index 118 matched with flowline of the same operator.
# Match #108: Spill index 119 matched with flowline of the same operator.
# Match #109: Spill index 120 matched with flowline of the same operator.
# Match #110: Spill index 121 matched with flowline of the same operator.
# Match #111: Spill index 122 matched with flowline of the same operator.
# Match #112: Spill index 123 matched with flowline of the same operator.
# Match #113: Spill index 124 matched with flowline of the same operator.
# No operator match found for Spill index 125
# Match #114: Spill index 126 matched with flowline of the same operator.
# Match #115: Spill index 127 matched with flowline of the same operator.
# No operator match found for Spill index 128
# No operator match found for Spill index 129
# Match #116: Spill index 130 matched with flowline of the same operator.
# Match #117: Spill index 131 matched with flowline of the same operator.
# Match #118: Spill index 132 matched with flowline of the same operator.
# Match #119: Spill index 133 matched with flowline of the same operator.
# Match #120: Spill index 134 matched with flowline of the same operator.
# Match #121: Spill index 135 matched with flowline of the same operator.
# Match #122: Spill index 136 matched with flowline of the same operator.
# No operator match found for Spill index 137
# Match #123: Spill index 138 matched with flowline of the same operator.
# Match #124: Spill index 139 matched with flowline of the same operator.
# Match #125: Spill index 140 matched with flowline of the same operator.
# Match #126: Spill index 141 matched with flowline of the same operator.
# Match #127: Spill index 142 matched with flowline of the same operator.
# Match #128: Spill index 143 matched with flowline of the same operator.
# Match #129: Spill index 144 matched with flowline of the same operator.
# No operator match found for Spill index 145
# Match #130: Spill index 146 matched with flowline of the same operator.
# Match #131: Spill index 147 matched with flowline of the same operator.
# Match #132: Spill index 148 matched with flowline of the same operator.
# No operator match found for Spill index 149
# Match #133: Spill index 150 matched with flowline of the same operator.
# Match #134: Spill index 151 matched with flowline of the same operator.
# Match #135: Spill index 152 matched with flowline of the same operator.
# Match #136: Spill index 153 matched with flowline of the same operator.
# Match #137: Spill index 154 matched with flowline of the same operator.
# Match #138: Spill index 155 matched with flowline of the same operator.
# Match #139: Spill index 156 matched with flowline of the same operator.
# Match #140: Spill index 157 matched with flowline of the same operator.
# No operator match found for Spill index 158
# Match #141: Spill index 159 matched with flowline of the same operator.
# Match #142: Spill index 160 matched with flowline of the same operator.
# Match #143: Spill index 161 matched with flowline of the same operator.
# Match #144: Spill index 162 matched with flowline of the same operator.
# No operator match found for Spill index 163
# No operator match found for Spill index 164
# Match #145: Spill index 165 matched with flowline of the same operator.
# No operator match found for Spill index 166
# Match #146: Spill index 167 matched with flowline of the same operator.
# Match #147: Spill index 168 matched with flowline of the same operator.
# Match #148: Spill index 169 matched with flowline of the same operator.
# Match #149: Spill index 170 matched with flowline of the same operator.
# Match #150: Spill index 171 matched with flowline of the same operator.
# Match #151: Spill index 172 matched with flowline of the same operator.
# Match #152: Spill index 173 matched with flowline of the same operator.
# Match #153: Spill index 174 matched with flowline of the same operator.
# Match #154: Spill index 175 matched with flowline of the same operator.
# Match #155: Spill index 176 matched with flowline of the same operator.
# Match #156: Spill index 177 matched with flowline of the same operator.
# Match #157: Spill index 178 matched with flowline of the same operator.
# Match #158: Spill index 179 matched with flowline of the same operator.
# Match #159: Spill index 180 matched with flowline of the same operator.
# No operator match found for Spill index 181
# Match #160: Spill index 182 matched with flowline of the same operator.
# Match #161: Spill index 183 matched with flowline of the same operator.
# Match #162: Spill index 184 matched with flowline of the same operator.
# Match #163: Spill index 185 matched with flowline of the same operator.
# Match #164: Spill index 186 matched with flowline of the same operator.
# Match #165: Spill index 187 matched with flowline of the same operator.
# No operator match found for Spill index 188
# Match #166: Spill index 189 matched with flowline of the same operator.
# Match #167: Spill index 190 matched with flowline of the same operator.
# Match #168: Spill index 191 matched with flowline of the same operator.
# Match #169: Spill index 192 matched with flowline of the same operator.
# No operator match found for Spill index 193
# Match #170: Spill index 194 matched with flowline of the same operator.
# Match #171: Spill index 195 matched with flowline of the same operator.
# Match #172: Spill index 196 matched with flowline of the same operator.
# Match #173: Spill index 197 matched with flowline of the same operator.
# Match #174: Spill index 198 matched with flowline of the same operator.
# Match #175: Spill index 199 matched with flowline of the same operator.
# Match #176: Spill index 200 matched with flowline of the same operator.
# No operator match found for Spill index 201
# Match #177: Spill index 202 matched with flowline of the same operator.
# Match #178: Spill index 203 matched with flowline of the same operator.
# Match #179: Spill index 204 matched with flowline of the same operator.
# Match #180: Spill index 205 matched with flowline of the same operator.
# Match #181: Spill index 206 matched with flowline of the same operator.
# Match #182: Spill index 207 matched with flowline of the same operator.
# Match #183: Spill index 208 matched with flowline of the same operator.
# Match #184: Spill index 209 matched with flowline of the same operator.
# Match #185: Spill index 210 matched with flowline of the same operator.
# Match #186: Spill index 211 matched with flowline of the same operator.
# Match #187: Spill index 212 matched with flowline of the same operator.
# Match #188: Spill index 213 matched with flowline of the same operator.
# Match #189: Spill index 214 matched with flowline of the same operator.
# No operator match found for Spill index 215
# No operator match found for Spill index 216
# Match #190: Spill index 217 matched with flowline of the same operator.
# Match #191: Spill index 218 matched with flowline of the same operator.
# Match #192: Spill index 219 matched with flowline of the same operator.
# Match #193: Spill index 220 matched with flowline of the same operator.
# Match #194: Spill index 221 matched with flowline of the same operator.
# Match #195: Spill index 222 matched with flowline of the same operator.
# No operator match found for Spill index 223
# Match #196: Spill index 224 matched with flowline of the same operator.
# Match #197: Spill index 225 matched with flowline of the same operator.
# No operator match found for Spill index 226
# Match #198: Spill index 227 matched with flowline of the same operator.
# Match #199: Spill index 228 matched with flowline of the same operator.
# Match #200: Spill index 229 matched with flowline of the same operator.
# Match #201: Spill index 230 matched with flowline of the same operator.
# Match #202: Spill index 231 matched with flowline of the same operator.
# Match #203: Spill index 232 matched with flowline of the same operator.
# Match #204: Spill index 233 matched with flowline of the same operator.
# Match #205: Spill index 234 matched with flowline of the same operator.
# Match #206: Spill index 235 matched with flowline of the same operator.
# Match #207: Spill index 236 matched with flowline of the same operator.
# No operator match found for Spill index 237
# Match #208: Spill index 238 matched with flowline of the same operator.
# Match #209: Spill index 239 matched with flowline of the same operator.
# No operator match found for Spill index 240
# Match #210: Spill index 241 matched with flowline of the same operator.
# Match #211: Spill index 242 matched with flowline of the same operator.
# Match #212: Spill index 243 matched with flowline of the same operator.
# Match #213: Spill index 244 matched with flowline of the same operator.
# Match #214: Spill index 245 matched with flowline of the same operator.
# Match #215: Spill index 246 matched with flowline of the same operator.
# Match #216: Spill index 247 matched with flowline of the same operator.
# No operator match found for Spill index 248
# No operator match found for Spill index 249
# No operator match found for Spill index 250
# Match #217: Spill index 251 matched with flowline of the same operator.
# Match #218: Spill index 252 matched with flowline of the same operator.
# Match #219: Spill index 253 matched with flowline of the same operator.
# Match #220: Spill index 254 matched with flowline of the same operator.
# Match #221: Spill index 255 matched with flowline of the same operator.
# Match #222: Spill index 256 matched with flowline of the same operator.
# Match #223: Spill index 257 matched with flowline of the same operator.
# Match #224: Spill index 258 matched with flowline of the same operator.
# Match #225: Spill index 259 matched with flowline of the same operator.
# Match #226: Spill index 260 matched with flowline of the same operator.
# Match #227: Spill index 261 matched with flowline of the same operator.
# Match #228: Spill index 262 matched with flowline of the same operator.
# Match #229: Spill index 263 matched with flowline of the same operator.
# No operator match found for Spill index 264
# Match #230: Spill index 265 matched with flowline of the same operator.
# Match #231: Spill index 266 matched with flowline of the same operator.
# No operator match found for Spill index 267
# Match #232: Spill index 268 matched with flowline of the same operator.
# Match #233: Spill index 269 matched with flowline of the same operator.
# Match #234: Spill index 270 matched with flowline of the same operator.
# Match #235: Spill index 271 matched with flowline of the same operator.
# Match #236: Spill index 272 matched with flowline of the same operator.
# Match #237: Spill index 273 matched with flowline of the same operator.
# Match #238: Spill index 274 matched with flowline of the same operator.
# Match #239: Spill index 275 matched with flowline of the same operator.
# Match #240: Spill index 276 matched with flowline of the same operator.
# Match #241: Spill index 277 matched with flowline of the same operator.
# Match #242: Spill index 278 matched with flowline of the same operator.
# Match #243: Spill index 279 matched with flowline of the same operator.
# Match #244: Spill index 280 matched with flowline of the same operator.
# Match #245: Spill index 281 matched with flowline of the same operator.
# Match #246: Spill index 282 matched with flowline of the same operator.
# No operator match found for Spill index 283
# Match #247: Spill index 284 matched with flowline of the same operator.
# Match #248: Spill index 285 matched with flowline of the same operator.
# No operator match found for Spill index 286
# No operator match found for Spill index 287
# No operator match found for Spill index 288
# Match #249: Spill index 289 matched with flowline of the same operator.
# Match #250: Spill index 290 matched with flowline of the same operator.
# No operator match found for Spill index 291
# Match #251: Spill index 292 matched with flowline of the same operator.
# Match #252: Spill index 293 matched with flowline of the same operator.
# Match #253: Spill index 294 matched with flowline of the same operator.
# Match #254: Spill index 295 matched with flowline of the same operator.
# Match #255: Spill index 296 matched with flowline of the same operator.
# Match #256: Spill index 297 matched with flowline of the same operator.
# Match #257: Spill index 298 matched with flowline of the same operator.
# Match #258: Spill index 299 matched with flowline of the same operator.
# Match #259: Spill index 300 matched with flowline of the same operator.
# Match #260: Spill index 301 matched with flowline of the same operator.
# Match #261: Spill index 302 matched with flowline of the same operator.
# Match #262: Spill index 303 matched with flowline of the same operator.
# Match #263: Spill index 304 matched with flowline of the same operator.
# Match #264: Spill index 305 matched with flowline of the same operator.
# Match #265: Spill index 306 matched with flowline of the same operator.
# Match #266: Spill index 307 matched with flowline of the same operator.
# Match #267: Spill index 308 matched with flowline of the same operator.
# Match #268: Spill index 309 matched with flowline of the same operator.
# Match #269: Spill index 310 matched with flowline of the same operator.
# No operator match found for Spill index 311
# Match #270: Spill index 312 matched with flowline of the same operator.
# Match #271: Spill index 313 matched with flowline of the same operator.
# Match #272: Spill index 314 matched with flowline of the same operator.
# Match #273: Spill index 315 matched with flowline of the same operator.
# Match #274: Spill index 316 matched with flowline of the same operator.
# No operator match found for Spill index 317
# Match #275: Spill index 318 matched with flowline of the same operator.
# Match #276: Spill index 319 matched with flowline of the same operator.
# Match #277: Spill index 320 matched with flowline of the same operator.
# Match #278: Spill index 321 matched with flowline of the same operator.
# Match #279: Spill index 322 matched with flowline of the same operator.
# Match #280: Spill index 323 matched with flowline of the same operator.
# Match #281: Spill index 324 matched with flowline of the same operator.
# Match #282: Spill index 325 matched with flowline of the same operator.
# Match #283: Spill index 326 matched with flowline of the same operator.
# Match #284: Spill index 327 matched with flowline of the same operator.
# No operator match found for Spill index 328
# Match #285: Spill index 329 matched with flowline of the same operator.
# No operator match found for Spill index 330
# Match #286: Spill index 331 matched with flowline of the same operator.
# No operator match found for Spill index 332
# Match #287: Spill index 333 matched with flowline of the same operator.
# /Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/ecmc_env/lib/python3.11/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Run the modified process function
merged_gdf_2 = process_spills_gdf(spills_gdf_2, flowlines_gdf, ball_tree, flowline_coords)
# Out:
# Match #288: Spill index 334 matched with flowline of the same operator.
# No operator match found for Spill index 335
# Match #289: Spill index 336 matched with flowline of the same operator.
# No operator match found for Spill index 337
# Match #290: Spill index 338 matched with flowline of the same operator.
# No operator match found for Spill index 339
# Match #291: Spill index 340 matched with flowline of the same operator.
# No operator match found for Spill index 341
# Match #292: Spill index 342 matched with flowline of the same operator.
# Match #293: Spill index 343 matched with flowline of the same operator.
# Match #294: Spill index 344 matched with flowline of the same operator.
# Match #295: Spill index 345 matched with flowline of the same operator.
# Match #296: Spill index 346 matched with flowline of the same operator.
# Match #297: Spill index 347 matched with flowline of the same operator.
# Match #298: Spill index 348 matched with flowline of the same operator.
# Match #299: Spill index 349 matched with flowline of the same operator.
# Match #300: Spill index 350 matched with flowline of the same operator.
# No operator match found for Spill index 351
# Match #301: Spill index 352 matched with flowline of the same operator.
# Match #302: Spill index 353 matched with flowline of the same operator.
# Match #303: Spill index 354 matched with flowline of the same operator.
# Match #304: Spill index 355 matched with flowline of the same operator.
# No operator match found for Spill index 356
# Match #305: Spill index 357 matched with flowline of the same operator.
# Match #306: Spill index 358 matched with flowline of the same operator.
# Match #307: Spill index 359 matched with flowline of the same operator.
# Match #308: Spill index 360 matched with flowline of the same operator.
# Match #309: Spill index 361 matched with flowline of the same operator.
# No operator match found for Spill index 362
# Match #310: Spill index 363 matched with flowline of the same operator.
# Match #311: Spill index 364 matched with flowline of the same operator.
# Match #312: Spill index 365 matched with flowline of the same operator.
# Match #313: Spill index 366 matched with flowline of the same operator.
# No operator match found for Spill index 367
# Match #314: Spill index 368 matched with flowline of the same operator.
# Match #315: Spill index 369 matched with flowline of the same operator.
# Match #316: Spill index 370 matched with flowline of the same operator.
# Match #317: Spill index 371 matched with flowline of the same operator.
# Match #318: Spill index 372 matched with flowline of the same operator.
# Match #319: Spill index 373 matched with flowline of the same operator.
# Match #320: Spill index 374 matched with flowline of the same operator.
# Match #321: Spill index 375 matched with flowline of the same operator.
# Match #322: Spill index 376 matched with flowline of the same operator.
# Match #323: Spill index 377 matched with flowline of the same operator.
# Match #324: Spill index 378 matched with flowline of the same operator.
# Match #325: Spill index 379 matched with flowline of the same operator.
# Match #326: Spill index 380 matched with flowline of the same operator.
# Match #327: Spill index 381 matched with flowline of the same operator.
# Match #328: Spill index 382 matched with flowline of the same operator.
# Match #329: Spill index 383 matched with flowline of the same operator.
# Match #330: Spill index 384 matched with flowline of the same operator.
# Match #331: Spill index 385 matched with flowline of the same operator.
# Match #332: Spill index 386 matched with flowline of the same operator.
# Match #333: Spill index 387 matched with flowline of the same operator.
# Match #334: Spill index 388 matched with flowline of the same operator.
# Match #335: Spill index 389 matched with flowline of the same operator.
# Match #336: Spill index 390 matched with flowline of the same operator.
# Match #337: Spill index 391 matched with flowline of the same operator.
# Match #338: Spill index 392 matched with flowline of the same operator.
# No operator match found for Spill index 393
# No operator match found for Spill index 394
# Match #339: Spill index 395 matched with flowline of the same operator.
# Match #340: Spill index 396 matched with flowline of the same operator.
# Match #341: Spill index 397 matched with flowline of the same operator.
# Match #342: Spill index 398 matched with flowline of the same operator.
# Match #343: Spill index 399 matched with flowline of the same operator.
# No operator match found for Spill index 400
# Match #344: Spill index 401 matched with flowline of the same operator.
# Match #345: Spill index 402 matched with flowline of the same operator.
# Match #346: Spill index 403 matched with flowline of the same operator.
# Match #347: Spill index 404 matched with flowline of the same operator.
# Match #348: Spill index 405 matched with flowline of the same operator.
# Match #349: Spill index 406 matched with flowline of the same operator.
# Match #350: Spill index 407 matched with flowline of the same operator.
# Match #351: Spill index 408 matched with flowline of the same operator.
# Match #352: Spill index 409 matched with flowline of the same operator.
# Match #353: Spill index 410 matched with flowline of the same operator.
# Match #354: Spill index 411 matched with flowline of the same operator.
# Match #355: Spill index 412 matched with flowline of the same operator.
# Match #356: Spill index 413 matched with flowline of the same operator.
# Match #357: Spill index 414 matched with flowline of the same operator.
# Match #358: Spill index 415 matched with flowline of the same operator.
# Match #359: Spill index 416 matched with flowline of the same operator.
# Match #360: Spill index 417 matched with flowline of the same operator.
# Match #361: Spill index 418 matched with flowline of the same operator.
# Match #362: Spill index 419 matched with flowline of the same operator.
# No operator match found for Spill index 420
# Match #363: Spill index 421 matched with flowline of the same operator.
# Match #364: Spill index 422 matched with flowline of the same operator.
# Match #365: Spill index 423 matched with flowline of the same operator.
# Match #366: Spill index 424 matched with flowline of the same operator.
# Match #367: Spill index 425 matched with flowline of the same operator.
# Match #368: Spill index 426 matched with flowline of the same operator.
# Match #369: Spill index 427 matched with flowline of the same operator.
# Match #370: Spill index 428 matched with flowline of the same operator.
# Match #371: Spill index 429 matched with flowline of the same operator.
# Match #372: Spill index 430 matched with flowline of the same operator.
# Match #373: Spill index 431 matched with flowline of the same operator.
# Match #374: Spill index 432 matched with flowline of the same operator.
# Match #375: Spill index 433 matched with flowline of the same operator.
# Match #376: Spill index 434 matched with flowline of the same operator.
# No operator match found for Spill index 435
# Match #377: Spill index 436 matched with flowline of the same operator.
# Match #378: Spill index 437 matched with flowline of the same operator.
# Match #379: Spill index 438 matched with flowline of the same operator.
# Match #380: Spill index 439 matched with flowline of the same operator.
# Match #381: Spill index 440 matched with flowline of the same operator.
# Match #382: Spill index 441 matched with flowline of the same operator.
# Match #383: Spill index 442 matched with flowline of the same operator.
# Match #384: Spill index 443 matched with flowline of the same operator.
# Match #385: Spill index 444 matched with flowline of the same operator.
# Match #386: Spill index 445 matched with flowline of the same operator.
# Match #387: Spill index 446 matched with flowline of the same operator.
# Match #388: Spill index 447 matched with flowline of the same operator.
# Match #389: Spill index 448 matched with flowline of the same operator.
# Match #390: Spill index 449 matched with flowline of the same operator.
# No operator match found for Spill index 450
# Match #391: Spill index 451 matched with flowline of the same operator.
# No operator match found for Spill index 452
# No operator match found for Spill index 453
# Match #392: Spill index 454 matched with flowline of the same operator.
# Match #393: Spill index 455 matched with flowline of the same operator.
# Match #394: Spill index 456 matched with flowline of the same operator.
# No operator match found for Spill index 457
# Match #395: Spill index 458 matched with flowline of the same operator.
# Match #396: Spill index 459 matched with flowline of the same operator.
# Match #397: Spill index 460 matched with flowline of the same operator.
# Match #398: Spill index 461 matched with flowline of the same operator.
# No operator match found for Spill index 462
# Match #399: Spill index 463 matched with flowline of the same operator.
# Match #400: Spill index 464 matched with flowline of the same operator.
# Match #401: Spill index 465 matched with flowline of the same operator.
# No operator match found for Spill index 466
# No operator match found for Spill index 467
# Match #402: Spill index 468 matched with flowline of the same operator.
# Match #403: Spill index 469 matched with flowline of the same operator.
# No operator match found for Spill index 470
# Match #404: Spill index 471 matched with flowline of the same operator.
# Match #405: Spill index 472 matched with flowline of the same operator.
# Match #406: Spill index 473 matched with flowline of the same operator.
# No operator match found for Spill index 474
# Match #407: Spill index 475 matched with flowline of the same operator.
# Match #408: Spill index 476 matched with flowline of the same operator.
# Match #409: Spill index 477 matched with flowline of the same operator.
# Match #410: Spill index 478 matched with flowline of the same operator.
# No operator match found for Spill index 479
# Match #411: Spill index 480 matched with flowline of the same operator.
# Match #412: Spill index 481 matched with flowline of the same operator.
# Match #413: Spill index 482 matched with flowline of the same operator.
# Match #414: Spill index 483 matched with flowline of the same operator.
# Match #415: Spill index 484 matched with flowline of the same operator.
# Match #416: Spill index 485 matched with flowline of the same operator.
# Match #417: Spill index 486 matched with flowline of the same operator.
# No operator match found for Spill index 487
# Match #418: Spill index 488 matched with flowline of the same operator.
# Match #419: Spill index 489 matched with flowline of the same operator.
# Match #420: Spill index 490 matched with flowline of the same operator.
# Match #421: Spill index 491 matched with flowline of the same operator.
# Match #422: Spill index 492 matched with flowline of the same operator.
# No operator match found for Spill index 493
# Match #423: Spill index 494 matched with flowline of the same operator.
# Match #424: Spill index 495 matched with flowline of the same operator.
# No operator match found for Spill index 496
# Match #425: Spill index 497 matched with flowline of the same operator.
# Match #426: Spill index 498 matched with flowline of the same operator.
# Match #427: Spill index 499 matched with flowline of the same operator.
# Match #428: Spill index 500 matched with flowline of the same operator.
# Match #429: Spill index 501 matched with flowline of the same operator.
# Match #430: Spill index 502 matched with flowline of the same operator.
# Match #431: Spill index 503 matched with flowline of the same operator.
# Match #432: Spill index 504 matched with flowline of the same operator.
# Match #433: Spill index 505 matched with flowline of the same operator.
# Match #434: Spill index 506 matched with flowline of the same operator.
# Match #435: Spill index 507 matched with flowline of the same operator.
# No operator match found for Spill index 508
# Match #436: Spill index 509 matched with flowline of the same operator.
# Match #437: Spill index 510 matched with flowline of the same operator.
# Match #438: Spill index 511 matched with flowline of the same operator.
# No operator match found for Spill index 512
# Match #439: Spill index 513 matched with flowline of the same operator.
# Match #440: Spill index 514 matched with flowline of the same operator.
# Match #441: Spill index 515 matched with flowline of the same operator.
# Match #442: Spill index 516 matched with flowline of the same operator.
# Match #443: Spill index 517 matched with flowline of the same operator.
# Match #444: Spill index 518 matched with flowline of the same operator.
# Match #445: Spill index 519 matched with flowline of the same operator.
# Match #446: Spill index 520 matched with flowline of the same operator.
# Match #447: Spill index 521 matched with flowline of the same operator.
# Match #448: Spill index 522 matched with flowline of the same operator.
# Match #449: Spill index 523 matched with flowline of the same operator.
# Match #450: Spill index 524 matched with flowline of the same operator.
# Match #451: Spill index 525 matched with flowline of the same operator.
# Match #452: Spill index 526 matched with flowline of the same operator.
# Match #453: Spill index 527 matched with flowline of the same operator.
# No operator match found for Spill index 528
# Match #454: Spill index 529 matched with flowline of the same operator.
# Match #455: Spill index 530 matched with flowline of the same operator.
# No operator match found for Spill index 531
# Match #456: Spill index 532 matched with flowline of the same operator.
# Match #457: Spill index 533 matched with flowline of the same operator.
# Match #458: Spill index 534 matched with flowline of the same operator.
# Match #459: Spill index 535 matched with flowline of the same operator.
# No operator match found for Spill index 536
# Match #460: Spill index 537 matched with flowline of the same operator.
# Match #461: Spill index 538 matched with flowline of the same operator.
# Match #462: Spill index 539 matched with flowline of the same operator.
# Match #463: Spill index 540 matched with flowline of the same operator.
# No operator match found for Spill index 541
# Match #464: Spill index 542 matched with flowline of the same operator.
# Match #465: Spill index 543 matched with flowline of the same operator.
# Match #466: Spill index 544 matched with flowline of the same operator.
# Match #467: Spill index 545 matched with flowline of the same operator.
# Match #468: Spill index 546 matched with flowline of the same operator.
# Match #469: Spill index 547 matched with flowline of the same operator.
# Match #470: Spill index 548 matched with flowline of the same operator.
# Match #471: Spill index 549 matched with flowline of the same operator.
# Match #472: Spill index 550 matched with flowline of the same operator.
# Match #473: Spill index 551 matched with flowline of the same operator.
# Match #474: Spill index 552 matched with flowline of the same operator.
# Match #475: Spill index 553 matched with flowline of the same operator.
# Match #476: Spill index 554 matched with flowline of the same operator.
# No operator match found for Spill index 555
# No operator match found for Spill index 556
# Match #477: Spill index 557 matched with flowline of the same operator.
# Match #478: Spill index 558 matched with flowline of the same operator.
# Match #479: Spill index 559 matched with flowline of the same operator.
# Match #480: Spill index 560 matched with flowline of the same operator.
# Match #481: Spill index 561 matched with flowline of the same operator.
# No operator match found for Spill index 562
# Match #482: Spill index 563 matched with flowline of the same operator.
# No operator match found for Spill index 564
# Match #483: Spill index 565 matched with flowline of the same operator.
# Match #484: Spill index 566 matched with flowline of the same operator.
# Match #485: Spill index 567 matched with flowline of the same operator.
# Match #486: Spill index 568 matched with flowline of the same operator.
# Match #487: Spill index 569 matched with flowline of the same operator.
# Match #488: Spill index 570 matched with flowline of the same operator.
# Match #489: Spill index 571 matched with flowline of the same operator.
# No operator match found for Spill index 572
# Match #490: Spill index 573 matched with flowline of the same operator.
# Match #491: Spill index 574 matched with flowline of the same operator.
# Match #492: Spill index 575 matched with flowline of the same operator.
# Match #493: Spill index 576 matched with flowline of the same operator.
# No operator match found for Spill index 577
# Match #494: Spill index 578 matched with flowline of the same operator.
# Match #495: Spill index 579 matched with flowline of the same operator.
# Match #496: Spill index 580 matched with flowline of the same operator.
# Match #497: Spill index 581 matched with flowline of the same operator.
# Match #498: Spill index 582 matched with flowline of the same operator.
# Match #499: Spill index 583 matched with flowline of the same operator.
# No operator match found for Spill index 584
# No operator match found for Spill index 585
# Match #500: Spill index 586 matched with flowline of the same operator.
# Match #501: Spill index 587 matched with flowline of the same operator.
# Match #502: Spill index 588 matched with flowline of the same operator.
# Match #503: Spill index 589 matched with flowline of the same operator.
# Match #504: Spill index 590 matched with flowline of the same operator.
# Match #505: Spill index 591 matched with flowline of the same operator.
# Match #506: Spill index 592 matched with flowline of the same operator.
# No operator match found for Spill index 593
# Match #507: Spill index 594 matched with flowline of the same operator.
# Match #508: Spill index 595 matched with flowline of the same operator.
# Match #509: Spill index 596 matched with flowline of the same operator.
# Match #510: Spill index 597 matched with flowline of the same operator.
# Match #511: Spill index 598 matched with flowline of the same operator.
# Match #512: Spill index 599 matched with flowline of the same operator.
# Match #513: Spill index 600 matched with flowline of the same operator.
# Match #514: Spill index 601 matched with flowline of the same operator.
# Match #515: Spill index 602 matched with flowline of the same operator.
# Match #516: Spill index 603 matched with flowline of the same operator.
# Match #517: Spill index 604 matched with flowline of the same operator.
# No operator match found for Spill index 605
# Match #518: Spill index 606 matched with flowline of the same operator.
# No operator match found for Spill index 607
# Match #519: Spill index 608 matched with flowline of the same operator.
# Match #520: Spill index 609 matched with flowline of the same operator.
# Match #521: Spill index 610 matched with flowline of the same operator.
# No operator match found for Spill index 611
# Match #522: Spill index 612 matched with flowline of the same operator.
# Match #523: Spill index 613 matched with flowline of the same operator.
# Match #524: Spill index 614 matched with flowline of the same operator.
# Match #525: Spill index 615 matched with flowline of the same operator.
# No operator match found for Spill index 616
# Match #526: Spill index 617 matched with flowline of the same operator.
# No operator match found for Spill index 618
# Match #527: Spill index 619 matched with flowline of the same operator.
# Match #528: Spill index 620 matched with flowline of the same operator.
# Match #529: Spill index 621 matched with flowline of the same operator.
# Match #530: Spill index 622 matched with flowline of the same operator.
# No operator match found for Spill index 623
# No operator match found for Spill index 624
# Match #531: Spill index 625 matched with flowline of the same operator.
# Match #532: Spill index 626 matched with flowline of the same operator.
# Match #533: Spill index 627 matched with flowline of the same operator.
# Match #534: Spill index 628 matched with flowline of the same operator.
# Match #535: Spill index 629 matched with flowline of the same operator.
# No operator match found for Spill index 630
# Match #536: Spill index 631 matched with flowline of the same operator.
# No operator match found for Spill index 632
# Match #537: Spill index 633 matched with flowline of the same operator.
# Match #538: Spill index 634 matched with flowline of the same operator.
# Match #539: Spill index 635 matched with flowline of the same operator.
# No operator match found for Spill index 636
# Match #540: Spill index 637 matched with flowline of the same operator.
# Match #541: Spill index 638 matched with flowline of the same operator.
# No operator match found for Spill index 639
# No operator match found for Spill index 640
# Match #542: Spill index 641 matched with flowline of the same operator.
# No operator match found for Spill index 642
# Match #543: Spill index 643 matched with flowline of the same operator.
# Match #544: Spill index 644 matched with flowline of the same operator.
# No operator match found for Spill index 645
# Match #545: Spill index 646 matched with flowline of the same operator.
# Match #546: Spill index 647 matched with flowline of the same operator.
# Match #547: Spill index 648 matched with flowline of the same operator.
# Match #548: Spill index 649 matched with flowline of the same operator.
# No operator match found for Spill index 650
# Match #549: Spill index 651 matched with flowline of the same operator.
# No operator match found for Spill index 652
# No operator match found for Spill index 653
# Match #550: Spill index 654 matched with flowline of the same operator.
# Match #551: Spill index 655 matched with flowline of the same operator.
# No operator match found for Spill index 656
# Match #552: Spill index 657 matched with flowline of the same operator.
# Match #553: Spill index 658 matched with flowline of the same operator.
# Match #554: Spill index 659 matched with flowline of the same operator.
# Match #555: Spill index 660 matched with flowline of the same operator.
# No operator match found for Spill index 661
# Match #556: Spill index 662 matched with flowline of the same operator.
# Match #557: Spill index 663 matched with flowline of the same operator.
# Match #558: Spill index 664 matched with flowline of the same operator.
# Match #559: Spill index 665 matched with flowline of the same operator.
# Match #560: Spill index 666 matched with flowline of the same operator.
# Match #561: Spill index 667 matched with flowline of the same operator.
# Match #562: Spill index 668 matched with flowline of the same operator.
# /Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/ecmc_env/lib/python3.11/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
merged_gdf_1 = merged_gdf_1.drop(columns=['geometry'])  # Drop the extra geometry column
merged_gdf_2 = merged_gdf_2.drop(columns=['geometry'])  # Drop the extra geometry column

# Combine the results from both processed GeoDataFrames
merged_spills_flowlines = pd.concat([merged_gdf_1, merged_gdf_2], ignore_index=True)

# Display the combined merged GeoDataFrame
print(merged_spills_flowlines.head()) 

# Print the count of unmatched spills
print(f"Total unmatched spills: {no_match_count}")

# Save the merged dataset if needed
merged_spills_flowlines.to_file("merged_spills_flowlines.geojson", driver="GeoJSON")
# Out:
#     trkg_num                        Operator Name facility_type  \
# 0  401524345  GREAT WESTERN OPERATING COMPANY LLC  TANK BATTERY
# 1  401541267                       PDC ENERGY INC      FLOWLINE
# 2  401569119      KERR MCGEE OIL & GAS ONSHORE LP  TANK BATTERY
# 3  401576719                     NOBLE ENERGY INC  TANK BATTERY
# 4  401585074                     NOBLE ENERGY INC  TANK BATTERY
#
#                                           Spill_Desc Spill Type  \
# 0  Soil impacts were discovered during removal of...          1
# 1  PDC discovered a reportable historical spill a...          1
# 2  While deconstructing the Weichel 26N-11HZ tank...          1
# 3  During decommisioning of facilitiy soil impact...          1
# 4  During reclamation activities historical impac...          1
#
#                                           Root Cause  \
# 0                                            Unknown
# 1  On January 8, 2018, historic petroleum hydroca...
# 2  While deconstructing the Weichel 26N-11HZ tank...
# 3  Historical impacts were discovered during dism...
# 4  During reclamation of the oil and gas facility...
#
#                                 Preventative Measure Root Cause Type  \
# 0                                               None         Unknown
# 1  The facility was decommissioned and will not b...         Unknown
# 2  The excavated portion of the Kerr-McGee tank b...         Unknown
# 3  The site was dismantled and reclamation has oc...         Unknown
# 4  The location was plugged and abandoned and exc...         Unknown
#
#   Detailed Root Cause Type        Long        Lat facility_status Metallic?  \
# 0                  Unknown -104.467746  39.602613              AC   Unknown
# 1                  Unknown -104.674320  40.385970              CL   Unknown
# 2                  Unknown -104.631328  40.132392              CL   Unknown
# 3                  Unknown -104.602541  40.319666              CL   Unknown
# 4                  Unknown -104.754486  40.484583              CL   Unknown
#
#    nearest_flowline_index                                  ACTIONDESCRIPTION  \
# 0                  129530  This flowline will be flushed prior to removin...
# 1                  169035                                               None
# 2                  462001                                               None
# 3                  385305  Purged fluids, abandoned in place, cut risers ...
# 4                  354636                                               None
#
#   BEDDINGMATERIAL                                       COMPANY_NAME  \
# 0            None  GREAT WESTERN OPERATING COMPANY LLC           ...
# 1            None  PDC ENERGY INC                                ...
# 2            None  KERR MCGEE OIL & GAS ONSHORE LP               ...
# 3            None  NOBLE ENERGY INC                              ...
# 4            None  NOBLE ENERGY INC                              ...
#
#   CONSTRUCTDATE  Diam_in     ENDLAT     ENDLONG ENTIRELINEREMOVED  \
# 0    1972-08-07      2.0  39.844718 -104.470638              None
# 1    2017-12-07      3.5  40.367408 -104.656320              None
# 2    2011-08-10      2.0  40.159243 -104.687167              None
# 3    1987-12-18      2.0  40.333750 -104.595567                 1
# 4    1993-11-07      2.0  40.495920 -104.744664              None
#
#            FLOWLINEACTION  FLOWLINEID            Fluid           LOCATIONTYPE  \
# 0  Pre-Abandonment Notice    470450.0              Oil  Production Facilities
# 1            Registration    477982.0  Produced Fluids  Production Facilities
# 2            Registration    457300.0   PRODUCED WATER  Production Facilities
# 3             Abandonment    465120.0       Multiphase  Production Facilities
# 4            Registration    466186.0       Multiphase  Production Facilities
#
#    LOCATION_ID  Length_ft  MAXOPPRESSURE      Material  OPERATOR_NUM  \
# 0     470449.0     542.71            NaN         Steel         10110
# 1     447490.0     404.27            NaN  Carbon Steel         69175
# 2     318070.0      18.23            NaN         Steel         47120
# 3     464594.0    1884.61            NaN  Carbon Steel        100322
# 4     455178.0     768.11            NaN  Carbon Steel        100322
#
#                               Operator  PIPEMATERIAL            RECEIVE_DATE  \
# 0  GREAT WESTERN OPERATING COMPANY LLC          None 2021-02-17 13:32:02.520
# 1                       PDC ENERGY INC  Carbon Steel 2019-10-18 14:51:46.423
# 2      KERR MCGEE OIL & GAS ONSHORE LP          None 2018-08-29 11:31:40.320
# 3                     NOBLE ENERGY INC          None 2019-06-26 08:22:35.043
# 4                     NOBLE ENERGY INC          None 2019-07-19 09:01:04.960
#
#    SHAPE_Length   STARTLAT  STARTLOCATIONID   STARTLONG            Status  \
# 0    165.354619  39.845233              NaN -104.472460            Active
# 1    123.175010  40.367810         447490.0 -104.657390  New Construction
# 2      5.553076  40.158592         332301.0 -104.690146            ACTIVE
# 3    574.207157  40.328560         326813.0 -104.595490            Active
# 4    234.027984  40.497521         310147.0 -104.746461         Abandoned
#
#   TYPEOFFLUIDTRANS                                  geometry_flowline
# 0             None  LINESTRING (545287.5 4410654.506, 545239.243 4...
# 1        Crude Oil  LINESTRING (529087.406 4468617.814, 529106.928...
# 2             None  LINESTRING (526647.996 4445503.586, 526647.873...
# 3             None  LINESTRING (534361.603 4464302.795, 534361.11 ...
# 4             None  LINESTRING (521614.711 4482858.937, 521636.926...
# Total unmatched spills: 107

# %%
# Rename the 'geometry_flowline' column to 'geometry' in merged_spills_flowlines
merged_spills_flowlines = merged_spills_flowlines.rename(columns={'geometry_flowline': 'geometry'})

# Ensure that the GeoDataFrame recognizes the renamed column as the geometry column
merged_spills_flowlines = merged_spills_flowlines.set_geometry('geometry')

# %%
# Check size
print(flowlines_gdf.shape)
print(spills_gdf.shape)
# Out:
# (463940, 27)
# (669, 14)

# %%
# Check size
print(flowlines_gdf.shape)
print(merged_spills_flowlines.shape)
# Out:
# (463940, 27)
# (562, 41)

# %%
# Step 1: Identify the indices of flowlines present in merged_spills_flowlines
matched_flowline_indices = merged_spills_flowlines['nearest_flowline_index'].unique()

# Step 2: Filter the original flowlines_gdf to exclude those present in merged_spills_flowlines
filtered_flowlines_gdf = flowlines_gdf[~flowlines_gdf.index.isin(matched_flowline_indices)].copy()

# Step 3: Concatenate the merged_spills_flowlines with the filtered flowlines_gdf
combined_gdf = pd.concat([merged_spills_flowlines, filtered_flowlines_gdf], ignore_index=True)

# Display the first few rows of the combined GeoDataFrame
print(combined_gdf.head())
# Out:
#       trkg_num                        Operator Name facility_type  \
# 0  401524345.0  GREAT WESTERN OPERATING COMPANY LLC  TANK BATTERY
# 1  401541267.0                       PDC ENERGY INC      FLOWLINE
# 2  401569119.0      KERR MCGEE OIL & GAS ONSHORE LP  TANK BATTERY
# 3  401576719.0                     NOBLE ENERGY INC  TANK BATTERY
# 4  401585074.0                     NOBLE ENERGY INC  TANK BATTERY
#
#                                           Spill_Desc Spill Type  \
# 0  Soil impacts were discovered during removal of...          1
# 1  PDC discovered a reportable historical spill a...          1
# 2  While deconstructing the Weichel 26N-11HZ tank...          1
# 3  During decommisioning of facilitiy soil impact...          1
# 4  During reclamation activities historical impac...          1
#
#                                           Root Cause  \
# 0                                            Unknown
# 1  On January 8, 2018, historic petroleum hydroca...
# 2  While deconstructing the Weichel 26N-11HZ tank...
# 3  Historical impacts were discovered during dism...
# 4  During reclamation of the oil and gas facility...
#
#                                 Preventative Measure Root Cause Type  \
# 0                                               None         Unknown
# 1  The facility was decommissioned and will not b...         Unknown
# 2  The excavated portion of the Kerr-McGee tank b...         Unknown
# 3  The site was dismantled and reclamation has oc...         Unknown
# 4  The location was plugged and abandoned and exc...         Unknown
#
#   Detailed Root Cause Type        Long        Lat facility_status Metallic?  \
# 0                  Unknown -104.467746  39.602613              AC   Unknown
# 1                  Unknown -104.674320  40.385970              CL   Unknown
# 2                  Unknown -104.631328  40.132392              CL   Unknown
# 3                  Unknown -104.602541  40.319666              CL   Unknown
# 4                  Unknown -104.754486  40.484583              CL   Unknown
#
#    nearest_flowline_index                                  ACTIONDESCRIPTION  \
# 0                129530.0  This flowline will be flushed prior to removin...
# 1                169035.0                                               None
# 2                462001.0                                               None
# 3                385305.0  Purged fluids, abandoned in place, cut risers ...
# 4                354636.0                                               None
#
#   BEDDINGMATERIAL                                       COMPANY_NAME  \
# 0            None  GREAT WESTERN OPERATING COMPANY LLC           ...
# 1            None  PDC ENERGY INC                                ...
# 2            None  KERR MCGEE OIL & GAS ONSHORE LP               ...
# 3            None  NOBLE ENERGY INC                              ...
# 4            None  NOBLE ENERGY INC                              ...
#
#   CONSTRUCTDATE  Diam_in     ENDLAT     ENDLONG ENTIRELINEREMOVED  \
# 0    1972-08-07      2.0  39.844718 -104.470638              None
# 1    2017-12-07      3.5  40.367408 -104.656320              None
# 2    2011-08-10      2.0  40.159243 -104.687167              None
# 3    1987-12-18      2.0  40.333750 -104.595567                 1
# 4    1993-11-07      2.0  40.495920 -104.744664              None
#
#            FLOWLINEACTION  FLOWLINEID            Fluid           LOCATIONTYPE  \
# 0  Pre-Abandonment Notice    470450.0              Oil  Production Facilities
# 1            Registration    477982.0  Produced Fluids  Production Facilities
# 2            Registration    457300.0   PRODUCED WATER  Production Facilities
# 3             Abandonment    465120.0       Multiphase  Production Facilities
# 4            Registration    466186.0       Multiphase  Production Facilities
#
#    LOCATION_ID  Length_ft  MAXOPPRESSURE      Material  OPERATOR_NUM  \
# 0     470449.0     542.71            NaN         Steel         10110
# 1     447490.0     404.27            NaN  Carbon Steel         69175
# 2     318070.0      18.23            NaN         Steel         47120
# 3     464594.0    1884.61            NaN  Carbon Steel        100322
# 4     455178.0     768.11            NaN  Carbon Steel        100322
#
#                               Operator  PIPEMATERIAL            RECEIVE_DATE  \
# 0  GREAT WESTERN OPERATING COMPANY LLC          None 2021-02-17 13:32:02.520
# 1                       PDC ENERGY INC  Carbon Steel 2019-10-18 14:51:46.423
# 2      KERR MCGEE OIL & GAS ONSHORE LP          None 2018-08-29 11:31:40.320
# 3                     NOBLE ENERGY INC          None 2019-06-26 08:22:35.043
# 4                     NOBLE ENERGY INC          None 2019-07-19 09:01:04.960
#
#    SHAPE_Length   STARTLAT  STARTLOCATIONID   STARTLONG            Status  \
# 0    165.354619  39.845233              NaN -104.472460            Active
# 1    123.175010  40.367810         447490.0 -104.657390  New Construction
# 2      5.553076  40.158592         332301.0 -104.690146            ACTIVE
# 3    574.207157  40.328560         326813.0 -104.595490            Active
# 4    234.027984  40.497521         310147.0 -104.746461         Abandoned
#
#   TYPEOFFLUIDTRANS                                           geometry
# 0             None  LINESTRING (545287.5 4410654.506, 545239.243 4...
# 1        Crude Oil  LINESTRING (529087.406 4468617.814, 529106.928...
# 2             None  LINESTRING (526647.996 4445503.586, 526647.873...
# 3             None  LINESTRING (534361.603 4464302.795, 534361.11 ...
# 4             None  LINESTRING (521614.711 4482858.937, 521636.926...

# %%
print(combined_gdf.shape)
# Out:
# (464153, 41)

# %%
combined_gdf.to_file("combined_gdf.geojson", driver="GeoJSON")
