# %%
import geopandas as gpd
import os
os.chdir('/Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/Data')

pop_density=gpd.read_file('Population_Density_(Census_Tracts)')
flowlines=gpd.read_file('similarity_matrix_result.geojson')

# %%
# Check the format of the population data - this code uses the census tract data available at:
# https://data-cdphe.opendata.arcgis.com/datasets/CDPHE::population-density-census-tracts/explore?location=38.499827%2C-102.988618%2C6.77

print('Summary of Census Tract Data:')
print(pop_density.info())  # General information about the dataset
print('\nFirst few rows of the data:')
print(pop_density.head())  # Preview the first few rows
# Out:
# Summary of Census Tract Data:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1249 entries, 0 to 1248
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    1249 non-null   int32
#  1   FIPS        1249 non-null   object
#  2   County      1249 non-null   object
#  3   Tract_Name  1249 non-null   object
#  4   Area_Land_  1249 non-null   float64
#  5   Population  1249 non-null   int32
#  6   Populati_1  1249 non-null   float64
#  7   geometry    1249 non-null   geometry
# dtypes: float64(2), geometry(1), int32(2), object(3)
# memory usage: 68.4+ KB
# None
#
# First few rows of the data:
#    OBJECTID         FIPS    County  \
# 0         1  08043979000   FREMONT
# 1         2  08045951600  GARFIELD
# 2         3  08069002803   LARIMER
# 3         4  08125963200      YUMA
# 4         5  08069002401   LARIMER
#
#                                      Tract_Name  Area_Land_  Population  \
# 0   Census Tract 9790, Fremont County, Colorado     1009.02        3456
# 1  Census Tract 9516, Garfield County, Colorado      573.42        3806
# 2  Census Tract 28.03, Larimer County, Colorado      218.45          53
# 3      Census Tract 9632, Yuma County, Colorado     1034.06        5581
# 4  Census Tract 24.01, Larimer County, Colorado      398.87        1352
#
#    Populati_1                                           geometry
# 0         3.4  POLYGON ((-105.88353 38.32817, -105.88385 38.3...
# 1         6.6  POLYGON ((-107.43227 39.57173, -107.43309 39.5...
# 2         0.2  POLYGON ((-105.57906 40.33209, -105.5791 40.33...
# 3         5.4  POLYGON ((-102.80355 39.99325, -102.80359 39.9...
# 4         3.4  POLYGON ((-105.22072 40.79379, -105.22117 40.7...

# %%
print(pop_density['Populati_1'].describe())
# Out:
# count     1249.000000
# mean      3664.680384
# std       3641.594843
# min          0.000000
# 25%        466.600000
# 50%       3139.000000
# 75%       5487.300000
# max      33066.700000
# Name: Populati_1, dtype: float64

# %%
# Ensure matching coordinates

pop_density = pop_density.to_crs(flowlines.crs)

print(f'Flowline CRS: {flowlines.crs}')
print(f'Population CRS: {pop_density.crs}')
# Out:
# Flowline CRS: EPSG:4269
# Population CRS: EPSG:4269

# %%
# Create a buffer around each line in which to calculate population density
# If a buffer lies within multiple tracts, we will take the average density between the tracts.
# A better approach would be an average weighted by the proportion of the buffer in each tract, but I am still working on this.
# It may be possible that our lines are cut into small enough chunks that this isn't an issue.

buffer_distance = 10  # buffer distance in meters
flowlines['buffer'] = flowlines.geometry.buffer(buffer_distance)

buffered_flowlines = gpd.GeoDataFrame(flowlines.drop(columns='geometry'), geometry=flowlines["buffer"])  # create a new dataframe that uses the buffered geometry
buffered_flowlines = buffered_flowlines.reset_index()  # reset index columns

# Perform a left spatial join with the updated predicate parameter
joined = gpd.sjoin(buffered_flowlines, pop_density, how='left', predicate='intersects')
# Out:
# /var/folders/p3/gs65vvgs1wd90mnxb3q3hvy80000gp/T/ipykernel_5635/2257767782.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   flowlines['buffer'] = flowlines.geometry.buffer(buffer_distance)

# %%
# test how many of the buffers intersect at least one tract

intersection_test = buffered_flowlines.geometry.intersects(pop_density.geometry.unary_union)
print(intersection_test.sum())
# Out:
# /var/folders/p3/gs65vvgs1wd90mnxb3q3hvy80000gp/T/ipykernel_5635/1035208378.py:3: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   intersection_test = buffered_flowlines.geometry.intersects(pop_density.geometry.unary_union)
# 15911

# %%
# calculate average density for each buffered line and put it in a new column

aggregated_density = (joined.groupby("index")["Populati_1"].mean().reset_index(name="average_pop_density")) 

flowlines=flowlines.merge(aggregated_density, left_index=True, right_on='index', how='left')

# %%
flowlines
# Out:
#        operator_number  flowline_id  location_id            status  \
# 0                10110     470450.0     470449.0            Active
# 1                69175     477981.0     447490.0  New Construction
# 2                47120     457300.0     318070.0            Active
# 3               100322     457931.0     422528.0            Active
# 4               100322     466186.0     455178.0         Abandoned
# ...                ...          ...          ...               ...
# 15906            96155     456386.0     433999.0            Active
# 15907            96155     456381.0     433999.0            Active
# 15908            96155     456382.0     433999.0            Active
# 15909            35080     455592.0     443145.0            Active
# 15910            39560     455244.0     318928.0         Abandoned
#
#                location_type           fluid      material  diameter_in  \
# 0      Production Facilities       Crude Oil         Steel            2
# 1      Production Facilities           Other  Carbon Steel            3
# 2      Production Facilities  Produced Water         Steel            2
# 3      Production Facilities      Multiphase  Carbon Steel            2
# 4      Production Facilities      Multiphase  Carbon Steel            2
# ...                      ...             ...           ...          ...
# 15906  Production Facilities      Multiphase  Carbon Steel            3
# 15907  Production Facilities      Multiphase  Carbon Steel            3
# 15908  Production Facilities      Multiphase  Carbon Steel            3
# 15909  Production Facilities       Crude Oil          HDPE            3
# 15910  Production Facilities      Condensate         Steel            3
#
#        length_ft  max_operating_pressure  shape_length  line_age_yr  \
# 0            542                      34           165           52
# 1            404                    2430           123            7
# 2             18                    2030             5           13
# 3           1135                     435           345           20
# 4            768                    1006           234           31
# ...          ...                     ...           ...          ...
# 15906       1404                     150           427            6
# 15907       1404                     150           427            6
# 15908       1404                     150           427            6
# 15909       1175                      40           358            7
# 15910        199                    1000            60           41
#
#       root_cause  risk  risk_probability  \
# 0        Unknown     1          1.000000
# 1        Unknown     1          1.000000
# 2        Unknown     1          1.000000
# 3        Unknown     1          1.000000
# 4        Unknown     1          1.000000
# ...          ...   ...               ...
# 15906   No Spill     0          0.873322
# 15907   No Spill     0          0.873322
# 15908   No Spill     0          0.873322
# 15909   No Spill     0          0.796337
# 15910   No Spill     0          0.750714
#
#                                                 geometry  \
# 0      LINESTRING (-104.47065 39.8447, -104.47245 39....
# 1      LINESTRING (-104.65739 40.36763, -104.65647 40...
# 2      LINESTRING (-104.68709 40.15947, -104.68709 40...
# 3      LINESTRING (-104.58882 40.32276, -104.58707 40...
# 4      LINESTRING (-104.74646 40.49752, -104.74466 40...
# ...                                                  ...
# 15906  LINESTRING (-103.84883 40.80845, -103.84502 40...
# 15907  LINESTRING (-103.84883 40.80845, -103.84502 40...
# 15908  LINESTRING (-103.84883 40.80845, -103.84502 40...
# 15909  LINESTRING (-103.40274 39.56441, -103.39982 39...
# 15910  LINESTRING (-105.04049 40.14339, -105.04114 40...
#
#                                                   buffer  index  \
# 0      POLYGON ((-107.23386 30.23405, -108.16263 30.5...      0
# 1      POLYGON ((-102.73157 50.18043, -101.779 49.944...      1
# 2      POLYGON ((-94.69273 39.82351, -94.77378 38.845...      2
# 3      POLYGON ((-96.09493 45.60044, -95.61825 44.742...      3
# 4      POLYGON ((-98.09252 47.96244, -97.3927 47.2744...      4
# ...                                                  ...    ...
# 15906  POLYGON ((-106.01459 50.57111, -105.04732 50.7...  15906
# 15907  POLYGON ((-106.01459 50.57111, -105.04732 50.7...  15907
# 15908  POLYGON ((-106.01459 50.57111, -105.04732 50.7...  15908
# 15909  POLYGON ((-103.41584 49.5644, -102.43559 49.51...  15909
# 15910  POLYGON ((-107.87985 30.55496, -108.80603 30.8...  15910
#
#        average_pop_density
# 0              3664.680384
# 1              3664.680384
# 2              3664.680384
# 3              3664.680384
# 4              3664.680384
# ...                    ...
# 15906          3664.680384
# 15907          3664.680384
# 15908          3664.680384
# 15909          3664.680384
# 15910          3664.680384
#
# [15911 rows x 19 columns]

# %%
# Save the updated file
flowlines.drop(columns=['buffer', 'index']).to_file(
    'flowlines_with_pop_density.geojson',
    driver='GeoJSON'
)

# %%
flowlines_with_pop_density=gpd.read_file('flowlines_with_pop_density.geojson')

# %%
flowlines_with_pop_density.tail()
# Out:
#        operator_number  flowline_id  location_id     status  \
# 15906            96155     456386.0     433999.0     Active
# 15907            96155     456381.0     433999.0     Active
# 15908            96155     456382.0     433999.0     Active
# 15909            35080     455592.0     443145.0     Active
# 15910            39560     455244.0     318928.0  Abandoned
#
#                location_type       fluid      material  diameter_in  \
# 15906  Production Facilities  Multiphase  Carbon Steel            3
# 15907  Production Facilities  Multiphase  Carbon Steel            3
# 15908  Production Facilities  Multiphase  Carbon Steel            3
# 15909  Production Facilities   Crude Oil          HDPE            3
# 15910  Production Facilities  Condensate         Steel            3
#
#        length_ft  max_operating_pressure  shape_length  line_age_yr  \
# 15906       1404                     150           427            6
# 15907       1404                     150           427            6
# 15908       1404                     150           427            6
# 15909       1175                      40           358            7
# 15910        199                    1000            60           41
#
#       root_cause  risk  risk_probability  average_pop_density  \
# 15906   No Spill     0          0.873322          3664.680384
# 15907   No Spill     0          0.873322          3664.680384
# 15908   No Spill     0          0.873322          3664.680384
# 15909   No Spill     0          0.796337          3664.680384
# 15910   No Spill     0          0.750714          3664.680384
#
#                                                 geometry
# 15906  LINESTRING (-103.84883 40.80845, -103.84502 40...
# 15907  LINESTRING (-103.84883 40.80845, -103.84502 40...
# 15908  LINESTRING (-103.84883 40.80845, -103.84502 40...
# 15909  LINESTRING (-103.40274 39.56441, -103.39982 39...
# 15910  LINESTRING (-105.04049 40.14339, -105.04114 40...
