# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder

pd.options.display.max_columns = None

# set working directory
os.chdir('/Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/Data')
flowline_pts = gpd.read_file("final_dataset.geojson").to_crs(epsg=4326)
flowline_pts.tail
# Out:
#        unique_id  operator_number  flowline_id  location_id  status  \
# 31927      35225            46290     475769.0     324591.0  Active
# 31928      41643            46290     475769.0     324591.0  Active
# 31929      15161           100322     458276.0     457997.0  Active
# 31930     140893            10456     476844.0     324174.0  Active
# 31931      47615           100322     464758.0     464517.0  Active
#
#       flowline_action          location_type           fluid      material  \
# 31927            None  Production Facilities      Multiphase  Carbon Steel
# 31928            None  Production Facilities      Multiphase  Carbon Steel
# 31929    Registration  Production Facilities             Gas  Carbon Steel
# 31930    Registration              Well Site  Produced Water         Steel
# 31931     Abandonment  Production Facilities             Gas  Carbon Steel
#
#        diameter_in  length_ft  max_operating_pressure  avg_population  \
# 31927            3        938                      90             0.8
# 31928            3       1762                      90             0.8
# 31929            3        624                     150            14.7
# 31930           12       4863                     512             5.3
# 31931            3        226                     160             2.3
#
#        avg_elevation  line_age_yr construct_date           spill_date  \
# 31927    2458.651367           69     1956-01-14  2024-12-10 00:00:00
# 31928    2450.490723           69     1956-01-14  2024-12-10 00:00:00
# 31929    1504.124512           19     2005-09-19  2024-12-19 00:00:00
# 31930    1767.559937           18     2007-04-30  2024-12-25 00:00:00
# 31931    1450.161743           17     2007-12-18  2024-12-09 00:00:00
#
#                  root_cause  risk                                     coords  \
# 31927     Equipment Failure     1   (-106.23428018034532, 40.82237731293913)
# 31928     Equipment Failure     1   (-106.2383781861833, 40.824181312091326)
# 31929             Corrosion     1   (-104.51948069370744, 40.15805457582379)
# 31930             Corrosion     1  (-108.11027517914566, 39.578417134474755)
# 31931  Incorrect Operations     1   (-104.47111749254847, 40.55178272897746)
#
#                           geometry
# 31927  POINT (-106.23428 40.82238)
# 31928  POINT (-106.23838 40.82418)
# 31929  POINT (-104.51948 40.15805)
# 31930  POINT (-108.11028 39.57842)
# 31931  POINT (-104.47112 40.55178)

# %%
# 29. Save final point-based GeoJSON
flowlines.to_file("final_dataset.geojson", driver='GeoJSON')
