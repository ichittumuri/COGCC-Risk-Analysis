# %% [markdown]
# This code transforms the original data formats into GeoJSON files, removing unnecessary attributes along the way.
#
# The gbd files are in CRS : EPSG-26913

# %% [markdown]
# ### Setup

# %%
import os
import pandas as pd
import openpyxl
import geopandas as gpd
from shapely.geometry import Point, LineString


os.chdir('/Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/Data')
pd.options.display.max_columns = None

# Load Data
gdf0 = gpd.GeoDataFrame(gpd.read_file("ECMC_Flowline_Data_Access/COGCC_Form44_Off_Location_Flowlines_Approved_CONFIDENTIAL.gdb"))
gdf1 = gpd.GeoDataFrame(gpd.read_file("ECMC_Flowline_Data_Access/COGCC_Form44_Crude_Oil_Produced_Water_Transfer_Flowlines_Approved_CONFIDENTIAL.gdb"))
flowlines = pd.read_excel('FlowlineSpreadsheet_Mines.xlsx')
spills = pd.read_excel('Flowline-Related Spills (through 2024).xlsx')
# Out:
# /Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/ecmc_env/lib/python3.11/site-packages/pyogrio/geopandas.py:265: UserWarning: More than one layer found in 'COGCC_Form44_Off_Location_Flowlines_Approved_CONFIDENTIAL.gdb': 'Off_Location_Flowlines' (default), 'Off_Location_Flowline_Valves'. Specify layer parameter to avoid this warning.
#   result = read_func(
# /Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/ecmc_env/lib/python3.11/site-packages/pyogrio/geopandas.py:265: UserWarning: More than one layer found in 'COGCC_Form44_Crude_Oil_Produced_Water_Transfer_Flowlines_Approved_CONFIDENTIAL.gdb': 'Crude_Oil_Produced_Water_Transfer_Lines' (default), 'Crude_Oil_Produced_Water_Transfer_Line_Valves'. Specify layer parameter to avoid this warning.
#   result = read_func(

# %%
spills.info
# Out:
# <bound method DataFrame.info of        trkg_num                      Operator Name operator_num  \
# 0     400768997         PETRON DEVELOPMENT COMPANY        69760
# 1     400763041  PIONEER NATURAL RESOURCES USA INC        10084
# 2     400763258                   DCP MIDSTREAM LP         4680
# 3     400764687          BARRETT CORPORATION* BILL        10071
# 4     400764760  PIONEER NATURAL RESOURCES USA INC        10084
# ...         ...                                ...          ...
# 2116  404037117               VERDAD RESOURCES LLC        10651
# 2117  404037373                   NOBLE ENERGY INC       100322
# 2118  404038294                         SIMCOE LLC        10749
# 2119  404040195                CAERUS PICEANCE LLC        10456
# 2120  404050492                   NOBLE ENERGY INC       100322
#
#             incident_date                   facility_type  \
# 0     2015-01-01 00:00:00                            WELL
# 1     2015-01-02 00:00:00     WATER GATHERING SYSTEM/LINE
# 2     2015-01-02 00:00:00                        PIPELINE
# 3     2015-01-04 00:00:00                    TANK BATTERY
# 4     2015-01-04 00:00:00                            WELL
# ...                   ...                             ...
# 2116  2024-12-19 00:00:00            OIL AND GAS LOCATION
# 2117  2024-12-19 00:00:00            OIL AND GAS LOCATION
# 2118  2024-12-20 00:00:00  PRODUCED WATER TRANSFER SYSTEM
# 2119  2024-12-25 00:00:00                       WELL SITE
# 2120  2024-12-09 00:00:00                 FLOWLINE SYSTEM
#
#                                              Spill_Desc           county  \
# 0     A backup restraint that keeps our drive head o...       WASHINGTON
# 1     One inch valve on the waterline inside the met...       LAS ANIMAS
# 2     The release occurred as a result of a trenchin...             WELD
# 3     Incident still under investigation, however, p...             WELD
# 4     PC well head torqued up and broke 2" line at f...       LAS ANIMAS
# ...                                                 ...              ...
# 2116  flowline between west well header and separato...  WELD
# 2117  A reportable release occurred on 12/19/24 at t...  WELD
# 2118  On 12/20/24, a hunter notified a SIMCOE contra...  LA PLATA
# 2119  Operator discovered an underground flowline le...  GARFIELD
# 2120  A reportable release occurred on 12/9/2024 at ...  WELD
#
#      Spill Type                                         Root Cause  \
# 0           NaN  A backup restraint that keeps our drive head o...
# 1           NaN  One inch valve on the waterline inside the met...
# 2           NaN  A ditcher struck an active DCP line when diggi...
# 3           NaN  Investigation has indicated that the burner on...
# 4           NaN  PC well head torqued up for an unknown reason ...
# ...         ...                                                ...
# 2116     Recent  An underground wellhead flowline failed from a...
# 2117     Recent  On 12/19/2024, produced water released from a ...
# 2118     Recent  As of January 8, 2025, SIMCOE has located and ...
# 2119     Recent  Buried flow line was compromised due to intern...
# 2120     Recent  This release occurred during a hydrostatic tes...
#
#                                    Preventative Measure       Root Cause Type  \
# 0     We replaced the restraining chain with a heavi...  Incorrect Operations
# 1     The valve has been replaced and everything is ...  Natural Force Damage
# 2     More accurate line locates and more frequent f...     Excavation Damage
# 3     Ensure all heaters are adequately shrouded and...  Incorrect Operations
# 4     The old corroded 2" pipe at the wellhead has b...             Corrosion
# ...                                                 ...                   ...
# 2116  The section of pipe effected by corrosion was ...             Corrosion
# 2117  Noble conducts annual integrity tests on all s...             Corrosion
# 2118  SIMCOE intends to replace the fiberglass line ...               Unknown
# 2119  Point of release was exposed, verified, and re...             Corrosion
# 2120  Upon discovering the source of the release, th...  Incorrect Operations
#
#      Detailed Root Cause Type        Long        Lat  oil_spilled  \
# 0         Improper Procedures -102.844180  40.144390          1.0
# 1                Valve Freeze -104.909560  37.190370          0.0
# 2                 Line Strike -104.712654  40.539301          0.0
# 3         Improper Procedures -104.248140  40.465660          2.0
# 4      Corrosion Type Unknown -104.832020  37.076170          0.0
# ...                       ...         ...        ...          ...
# 2116       Internal Corrosion -104.704267  40.001795          NaN
# 2117        Corrosion Unknown -104.519667  40.158056          0.0
# 2118                      NaN -107.649574  37.214966          0.0
# 2119        Corrosion Unknown -108.110408  39.578405          0.0
# 2120   Incorrect Installation -104.471118  40.551783          NaN
#
#       oil_recovered  cond_spilled  cond_recovered  PW_spilled  PW_recovered  \
# 0               NaN           0.0             NaN        40.0           NaN
# 1               NaN           0.0             NaN        20.0           NaN
# 2               NaN           3.0             NaN         0.0           NaN
# 3               NaN           0.0             NaN         0.0           NaN
# 4               NaN           0.0             NaN      2000.0           NaN
# ...             ...           ...             ...         ...           ...
# 2116            NaN           NaN             NaN         NaN           NaN
# 2117            0.0           0.0             0.0         3.0           3.0
# 2118            0.0           0.0             0.0         NaN           NaN
# 2119            0.0           0.0             0.0         NaN           0.0
# 2120            NaN           0.0             0.0         NaN           NaN
#
#       drilling_spilled  drilling_recovered  frac_spilled  frac_recovered  \
# 0                  0.0                 NaN           0.0             NaN
# 1                  0.0                 NaN           0.0             NaN
# 2                  0.0                 NaN           0.0             NaN
# 3                  0.0                 NaN           0.0             NaN
# 4                  0.0                 NaN           0.0             NaN
# ...                ...                 ...           ...             ...
# 2116               NaN                 NaN           NaN             NaN
# 2117               0.0                 0.0           0.0             0.0
# 2118               0.0                 0.0           0.0             0.0
# 2119               0.0                 0.0           0.0             0.0
# 2120               0.0                 0.0           0.0             0.0
#
#       other_spilled  other_recovered other_spilled_specify facility_status  \
# 0               NaN              NaN                   NaN             NaN
# 1               NaN              NaN                   NaN             NaN
# 2               NaN              NaN                   NaN             NaN
# 3               NaN              NaN                   NaN             NaN
# 4               NaN              NaN                   NaN             NaN
# ...             ...              ...                   ...             ...
# 2116            NaN              NaN                   NaN              CL
# 2117            NaN              NaN                   NaN              CL
# 2118            NaN              NaN                   NaN              AC
# 2119            NaN              NaN                   NaN              CL
# 2120            NaN              NaN                   NaN              CL
#
#                        Basin     Gathering? Metallic?  NaN nan.1 On Location?  \
# 0     DENVER JULESBURG BASIN  Non-Gathering   Unknown  NaN   NaN          NaN
# 1                RATON BASIN  Non-Gathering   Unknown  NaN   NaN          NaN
# 2     DENVER JULESBURG BASIN  Non-Gathering   Unknown  NaN   NaN          NaN
# 3     DENVER JULESBURG BASIN  Non-Gathering   Unknown  NaN   NaN          NaN
# 4                RATON BASIN  Non-Gathering  Metallic  NaN   NaN          NaN
# ...                      ...            ...       ...  ...   ...          ...
# 2116       Denver (DJ) Basin            NaN       NaN  NaN   NaN       474767
# 2117       Denver (DJ) Basin            NaN       NaN  NaN   NaN       450627
# 2118          San Juan Basin            NaN       NaN  NaN   NaN          NaN
# 2119          Piceance Basin            NaN       NaN  NaN   NaN       335848
# 2120       Denver (DJ) Basin            NaN       NaN  NaN   NaN       427074
#
#       Fac or Loc ID
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 2116       488924.0
# 2117       488925.0
# 2118       488909.0
# 2119       488929.0
# 2120       488863.0
#
# [2121 rows x 35 columns]>

# %% [markdown]
# In data cleaning, keep:
# - Tracking #
# - Operator #
# - Lat Long
# - Failure mechanism
# - Material
# - Fluid type
# - Size
# - Age
# - Status (active or not)

# %% [markdown]
# ### Combine both gbd files

# %%
# Check if the CRS of gdf0 is different from that of gdf1
if gdf0.crs != gdf1.crs:
    # If true, convert the CRS of gdf1 to match that of gdf0, modifying gdf1 in place
    gdf1.to_crs(gdf.crs, inplace=True)

# Concatenate gdf0 and gdf1 into a single GeoDataFrame, ignoring the original indices to create a new continuous index
gdf = pd.concat([gdf0,gdf1],ignore_index=True)
gdf.head(1)

#EPSG-26913
# Out:
#                           Operator Fluid Material  Diam_in  Status  Length_ft  \
# 0  EVERGREEN NATURAL RESOURCES LLC   Gas    polly      4.0  Active    2277.71
#
#      Doc_Num  SHAPE_Length                                           geometry
# 0  403322934    693.972162  MULTILINESTRING ((524642.67 4117088.796, 52463...

# %%
# remove Doc_Num
gdf.drop(columns=['Doc_Num'], inplace=True)

# %%
gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Clean Flowlines

# %%
flowlines.head(2)
# Out:
#      DOC_NUM  FORM_NUM             RECEIVE_DATE  OPERATOR_NUM  \
# 0  403564520        44   2023-10-30 08:10:52.12         10673
# 1  403554566        44  2023-10-24 08:33:49.223         10633
#
#                                         COMPANY_NAME              SUBMIT_DATE  \
# 0  GADECO LLC                                    ...   2023-10-30 08:10:52.12
# 1  CRESTONE PEAK RESOURCES OPERATING LLC         ...  2023-10-24 08:33:49.223
#
#                STATUS_DATE  FACILITY_ID      STATUS  \
# 0  2023-11-29 13:21:12.307          NaN  APPROVED
# 1   2023-11-27 11:52:05.37          NaN  APPROVED
#
#                                            USER_NAME          DATA_ENTRY_DATE  \
# 0  trent                                         ...    2023-10-18 10:39:05.0
# 1  solsen                                        ...  2023-10-09 14:56:12.247
#
#   DATA_ENTRY_OP  LOCATION_ID LAST_USER LAST_UPDATE_USER  \
# 0         trent     331872.0  wheelers         wheelers
# 1        solsen     470443.0  wheelers         wheelers
#
#           LAST_UPDATE_DATE     EXPR1           LOCATIONTYPE  NOLOCATIONID  \
# 0  2023-11-29 13:20:08.413  331872.0              Well Site         False
# 1  2023-11-27 11:50:08.687  470443.0  Production Facilities         False
#
#                          FACILITY_NAME     FACILITY_NUM COUNTY  QTRQTR  SEC  \
# 0  CROISSANT-69N62W                     26NENW            WELD  NENW     26
# 1  EMERSON-62N67W                       29SWNE            WELD  SWNE     29
#
#       TWP    RANGE MERIDIAN        LAT        LONG  PDOP MEASURE_DATE  \
# 0  9N      62W            6  40.724723 -104.289869   NaN          NaN
# 1  2N      67W            6  40.109444 -104.909686   NaN          NaN
#
#    INSTRUMENT_OPERATOR             REPORTTYPE ONECALLCODE  \
# 0                  NaN  Off-Location Flowline         NaN
# 1                  NaN  Off-Location Flowline         NaN
#
#   PLANNEDCONSTRUCTDATE  ASBUILTSERVICEDATE MODABANDINFO         PKEY  \
# 0                  NaN                 NaN          NaN  [B@3a47216c
# 1                  NaN                 NaN          NaN  [B@1c56c730
#
#     SYSTEMTYPE  FLOWLINEID   FLOWLINETYPE ENDEQUIPTYPE     ENDLAT     ENDLONG  \
# 0  OffLocation    485633.0      Dump Line         Well        NaN         NaN
# 1  OffLocation    470446.0  Wellhead Line    Separator  40.109444 -104.909686
#
#     ENDUTMX    ENDUTMY  ENDPDOP                ENDDATE    TYPEOFSTARTLOCATION  \
# 0       NaN        NaN      NaN                    NaN  Production Facilities
# 1  507699.0  4439909.0      3.3  2019-06-18 12:02:00.0              Well Site
#
#   STARTEQUIPTYPE  STARTLOCATIONID  STARTLOCATIONOID  \
# 0      Separator              NaN              True
# 1           Well              NaN             False
#
#                           STARTFACNAME   STARTFACNUMBER STARTFACCOUNTY  \
# 0  GRAEFE-69N62W                        26SWNW                    WELD
# 1                       EMERSON-62N67W            29CSE           WELD
#
#   STARTFACQTRQTR  STARTFACSECTION STARTFACTWP STARTFACRANGE STARTFACMERIDIAN  \
# 0         SWNW                 26      9N           62W                    6
# 1            CSE               29          2N           67W                6
#
#    STARTFACLAT  STARTFACLONG  STARTFACUTMX  STARTFACUTMY  STARTFACPDOP  \
# 0    40.720843   -104.294569        559576       4508009           NaN
# 1    40.105607   -104.909943        507675       4439483           NaN
#
#   STARTFACDATE   STARTLAT  STARTLONG  STARTUTMX  STARTUTMY  STARTPDOP  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN  40.105743 -104.90986   507685.0  4439496.0        5.4
#
#                STARTDATE          CONSTRUCTDATE  PIPEMATERIAL PIPEOTHER  \
# 0                    NaN  2000-07-15 00:00:00.0          HDPE       NaN
# 1  2019-06-18 12:23:00.0  1983-11-09 00:00:00.0  Carbon Steel       NaN
#
#     BEDDINGMATERIAL BEDDINGOTHER  MAXOD TYPEOFFLUIDTRANS OTHERFLUID  \
# 0  Native Materials          NaN    2.0   Produced Water        NaN
# 1  Native Materials          NaN    2.0       Multiphase        NaN
#
#    MAXOPPRESSURE  TESTINGPRESSURE TESTDATE FLOWLINEACTION  \
# 0            NaN              NaN      NaN   Registration
# 1          325.0              NaN      NaN            NaN
#
#               ACTIONDATE                                  ACTIONDESCRIPTION  \
# 0                    NaN                                                NaN
# 1  2022-04-14 00:00:00.0  The flowline serving the Emerson 3-29J (05-123...
#
#   ENTIRELINEREMOVED OPERATORFLOWLINEID
# 0               NaN             485273
# 1               NaN       12311381_FL

# %%
# List all columns in the 'flowlines' DataFrame
columns_list = flowlines.columns.tolist()
print("Columns in spills DataFrame:", columns_list)
# Out:
# Columns in spills DataFrame: ['DOC_NUM', 'FORM_NUM', 'RECEIVE_DATE', 'OPERATOR_NUM', 'COMPANY_NAME', 'SUBMIT_DATE', 'STATUS_DATE', 'FACILITY_ID', 'STATUS', 'USER_NAME', 'DATA_ENTRY_DATE', 'DATA_ENTRY_OP', 'LOCATION_ID', 'LAST_USER', 'LAST_UPDATE_USER', 'LAST_UPDATE_DATE', 'EXPR1', 'LOCATIONTYPE', 'NOLOCATIONID', 'FACILITY_NAME', 'FACILITY_NUM', 'COUNTY', 'QTRQTR', 'SEC', 'TWP', 'RANGE', 'MERIDIAN', 'LAT', 'LONG', 'PDOP', 'MEASURE_DATE', 'INSTRUMENT_OPERATOR', 'REPORTTYPE', 'ONECALLCODE', 'PLANNEDCONSTRUCTDATE', 'ASBUILTSERVICEDATE', 'MODABANDINFO', 'PKEY', 'SYSTEMTYPE', 'FLOWLINEID', 'FLOWLINETYPE', 'ENDEQUIPTYPE', 'ENDLAT', 'ENDLONG', 'ENDUTMX', 'ENDUTMY', 'ENDPDOP', 'ENDDATE', 'TYPEOFSTARTLOCATION', 'STARTEQUIPTYPE', 'STARTLOCATIONID', 'STARTLOCATIONOID', 'STARTFACNAME', 'STARTFACNUMBER', 'STARTFACCOUNTY', 'STARTFACQTRQTR', 'STARTFACSECTION', 'STARTFACTWP', 'STARTFACRANGE', 'STARTFACMERIDIAN', 'STARTFACLAT', 'STARTFACLONG', 'STARTFACUTMX', 'STARTFACUTMY', 'STARTFACPDOP', 'STARTFACDATE', 'STARTLAT', 'STARTLONG', 'STARTUTMX', 'STARTUTMY', 'STARTPDOP', 'STARTDATE', 'CONSTRUCTDATE', 'PIPEMATERIAL', 'PIPEOTHER', 'BEDDINGMATERIAL', 'BEDDINGOTHER', 'MAXOD', 'TYPEOFFLUIDTRANS', 'OTHERFLUID', 'MAXOPPRESSURE', 'TESTINGPRESSURE', 'TESTDATE', 'FLOWLINEACTION', 'ACTIONDATE', 'ACTIONDESCRIPTION', 'ENTIRELINEREMOVED', 'OPERATORFLOWLINEID']

# %%
# Keep the following columns
selected_columns = ['LOCATION_ID', 'FLOWLINEID', 'STARTLOCATIONID', 'FLOWLINEACTION', 'ENTIRELINEREMOVED', 'ACTIONDESCRIPTION', 'RECEIVE_DATE', 'OPERATOR_NUM', 'COMPANY_NAME', 'LOCATIONTYPE', 'ENDLAT', 'ENDLONG', 'STARTLAT', 'STARTLONG',
                    'PIPEMATERIAL', 'BEDDINGMATERIAL', 'TYPEOFFLUIDTRANS', 'MAXOPPRESSURE', 'CONSTRUCTDATE']
flowlines_selected = flowlines[selected_columns]

# %% [markdown]
# ### Clean spills excel (remove gathering)

# %%
spills.head(2)
# Out:
#     trkg_num                      Operator Name operator_num  \
# 0  400768997         PETRON DEVELOPMENT COMPANY        69760
# 1  400763041  PIONEER NATURAL RESOURCES USA INC        10084
#
#          incident_date                facility_type  \
# 0  2015-01-01 00:00:00                         WELL
# 1  2015-01-02 00:00:00  WATER GATHERING SYSTEM/LINE
#
#                                           Spill_Desc      county Spill Type  \
# 0  A backup restraint that keeps our drive head o...  WASHINGTON        NaN
# 1  One inch valve on the waterline inside the met...  LAS ANIMAS        NaN
#
#                                           Root Cause  \
# 0  A backup restraint that keeps our drive head o...
# 1  One inch valve on the waterline inside the met...
#
#                                 Preventative Measure       Root Cause Type  \
# 0  We replaced the restraining chain with a heavi...  Incorrect Operations
# 1  The valve has been replaced and everything is ...  Natural Force Damage
#
#   Detailed Root Cause Type       Long       Lat  oil_spilled  oil_recovered  \
# 0      Improper Procedures -102.84418  40.14439          1.0            NaN
# 1             Valve Freeze -104.90956  37.19037          0.0            NaN
#
#    cond_spilled  cond_recovered  PW_spilled  PW_recovered  drilling_spilled  \
# 0           0.0             NaN        40.0           NaN               0.0
# 1           0.0             NaN        20.0           NaN               0.0
#
#    drilling_recovered  frac_spilled  frac_recovered  other_spilled  \
# 0                 NaN           0.0             NaN            NaN
# 1                 NaN           0.0             NaN            NaN
#
#    other_recovered other_spilled_specify facility_status  \
# 0              NaN                   NaN             NaN
# 1              NaN                   NaN             NaN
#
#                     Basin     Gathering? Metallic?  NaN nan.1 On Location?  \
# 0  DENVER JULESBURG BASIN  Non-Gathering   Unknown  NaN   NaN          NaN
# 1             RATON BASIN  Non-Gathering   Unknown  NaN   NaN          NaN
#
#    Fac or Loc ID
# 0            NaN
# 1            NaN

# %%
# List all columns in the 'spills' DataFrame
columns_list = spills.columns.tolist()
print("Columns in spills DataFrame:", columns_list)
# Out:
# Columns in spills DataFrame: ['trkg_num', 'Operator Name', 'operator_num', 'incident_date', 'facility_type', 'Spill_Desc', 'county', 'Spill Type', 'Root Cause', 'Preventative Measure', 'Root Cause Type', 'Detailed Root Cause Type', 'Long', 'Lat', 'oil_spilled', 'oil_recovered', 'cond_spilled', 'cond_recovered', 'PW_spilled', 'PW_recovered', 'drilling_spilled', 'drilling_recovered', 'frac_spilled', 'frac_recovered', 'other_spilled', 'other_recovered', 'other_spilled_specify', 'facility_status', 'Basin', 'Gathering?', 'Metallic?', nan, 'nan.1', 'On Location?', 'Fac or Loc ID']

# %%
# Keep the following columns
selected_columns = ['trkg_num', 'Operator Name', 'facility_type', 'Spill_Desc', 'Spill Type', 'Root Cause', 'Preventative Measure',
                    'Root Cause Type', 'Detailed Root Cause Type', 'Long', 'Lat','facility_status', 'Gathering?', 'Metallic?', 'incident_date']
spills_selected = spills[selected_columns]

# Number of spills
num_rows = len(spills_selected)
print("Number of rows:", num_rows)
# Out:
# Number of rows: 2121

# %%
# Remove rows where the 'Gathering?' column has information (non-NaN values)
spills_cleaned = spills_selected[spills_selected['Gathering?'].isna()]

# %%
# Check if all gathering intances are removed
only_nan_columns = spills_cleaned.isna().all()

columns_with_all_nan = only_nan_columns[only_nan_columns].index.tolist()
print("Columns with all NaN values:", columns_with_all_nan)
# Out:
# Columns with all NaN values: ['Gathering?']

# %%
# Remove rows where 'Operator Name' contains the word "GATHERING"
spills_filtered = spills_cleaned[~spills_cleaned['Operator Name'].str.contains("GATHERING", case=False, na=False)]

# %%
# Remove 'Gathering?' and 'Operator Name' columns from the DataFrame
final_spills = spills_filtered.drop(columns=['Gathering?'])

# %%
# Number of spills after cleaning
num_rows = len(final_spills)
print("New number of rows:", num_rows)
# Out:
# New number of rows: 1199

# %% [markdown]
# ### Transform flowlines and spills excel files into gbd files

# %% [markdown]
# #### Flowlines Transformation

# %%
# Check if the 'geometry' column does not exist in the flowlines DataFrame and initialize it as an empty string if true
if 'geometry' not in flowlines_selected.columns:
    flowlines_selected['geometry'] = ''

# Iterate over each row in the flowlines DataFrame
for index, row in flowlines_selected.iterrows():
    # Create a LineString geometry from the start and end coordinates of each flowline
    geom = LineString([(row['STARTLONG'],row['STARTLAT']),(row['ENDLONG'],row['ENDLAT'])])
    # Assign the created LineString geometry to the 'geometry' column at the current index
    flowlines_selected.at[index,'geometry'] = geom

# Convert the flowlines DataFrame into a GeoDataFrame, explicitly setting the 'geometry' column and the Coordinate Reference System (CRS) to 'EPSG:4326' (WGS 84)
fl_gdf = gpd.GeoDataFrame(flowlines_selected, geometry='geometry', crs='EPSG:4326')
fl_gdf.plot()
# Out:
# /var/folders/p3/gs65vvgs1wd90mnxb3q3hvy80000gp/T/ipykernel_6756/1872236487.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flowlines_selected['geometry'] = ''
# <Axes: >

# %%
# Check if the CRS of fl_gdf is different from that of gdf
if fl_gdf.crs != gdf.crs:
    # If true, convert the CRS of fl_gdf to match that of gdf, modifying fl_gdf in place
    fl_gdf.to_crs(gdf.crs, inplace=True)
    print('Change fl crs to gdf crs')
# Out:
# Change fl crs to gdf crs

# %%
fl_gdf
# Out:
#        LOCATION_ID  FLOWLINEID  STARTLOCATIONID  FLOWLINEACTION  \
# 0         331872.0    485633.0              NaN    Registration
# 1         470443.0    470446.0              NaN             NaN
# 2         470443.0    470445.0         319521.0  Out of Service
# 3         318620.0    466061.0         305594.0             NaN
# 4         318620.0    466062.0         305595.0             NaN
# ...            ...         ...              ...             ...
# 21937     446052.0    455232.0         333012.0    Registration
# 21938     455177.0    455190.0         310572.0    Registration
# 21939     455096.0    455155.0         306660.0    Registration
# 21940     455096.0    455156.0         306575.0    Registration
# 21941     319507.0    455152.0         319507.0    Registration
#
#       ENTIRELINEREMOVED                                  ACTIONDESCRIPTION  \
# 0                   NaN                                                NaN
# 1                   NaN  The flowline serving the Emerson 3-29J (05-123...
# 2                  True  The flowline (12311399_FL) servicing the Emers...
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 21937               NaN                                                NaN
# 21938               NaN                                                NaN
# 21939               NaN                                                NaN
# 21940               NaN                                                NaN
# 21941               NaN                                                NaN
#
#                   RECEIVE_DATE  OPERATOR_NUM  \
# 0       2023-10-30 08:10:52.12         10673
# 1      2023-10-24 08:33:49.223         10633
# 2      2023-10-24 08:33:49.223         10633
# 3      2023-10-24 16:00:01.117         68710
# 4      2023-10-24 16:00:01.117         68710
# ...                        ...           ...
# 21937  2018-05-04 09:16:11.403        100322
# 21938   2018-05-10 12:16:07.97        100322
# 21939   2018-05-10 13:40:00.33        100322
# 21940   2018-05-10 13:40:00.33        100322
# 21941   2018-05-10 12:19:25.19        100322
#
#                                             COMPANY_NAME  \
# 0      GADECO LLC                                    ...
# 1      CRESTONE PEAK RESOURCES OPERATING LLC         ...
# 2      CRESTONE PEAK RESOURCES OPERATING LLC         ...
# 3      PETERSON ENERGY OPERATING INC                 ...
# 4      PETERSON ENERGY OPERATING INC                 ...
# ...                                                  ...
# 21937  NOBLE ENERGY INC                              ...
# 21938  NOBLE ENERGY INC                              ...
# 21939  NOBLE ENERGY INC                              ...
# 21940  NOBLE ENERGY INC                              ...
# 21941  NOBLE ENERGY INC                              ...
#
#                 LOCATIONTYPE     ENDLAT     ENDLONG   STARTLAT   STARTLONG  \
# 0                  Well Site        NaN         NaN        NaN         NaN
# 1      Production Facilities  40.109444 -104.909686  40.105743 -104.909860
# 2      Production Facilities  40.109441 -104.909670  40.112203 -104.909862
# 3      Production Facilities  40.063138 -105.034086  40.063823 -105.030068
# 4      Production Facilities  40.063142 -105.034085  40.060063 -105.034795
# ...                      ...        ...         ...        ...         ...
# 21937  Production Facilities  40.397700 -104.647660  40.398090 -104.642610
# 21938  Production Facilities  40.481530 -104.492930  40.481330 -104.491050
# 21939  Production Facilities  40.495330 -104.772282  40.489670 -104.771610
# 21940  Production Facilities  40.495330 -104.772282  40.493320 -104.770310
# 21941  Production Facilities  40.475900 -104.815900  40.474990 -104.813920
#
#        PIPEMATERIAL   BEDDINGMATERIAL TYPEOFFLUIDTRANS  MAXOPPRESSURE  \
# 0              HDPE  Native Materials   Produced Water            NaN
# 1      Carbon Steel  Native Materials       Multiphase          325.0
# 2      Carbon Steel  Native Materials       Multiphase          250.0
# 3      Carbon Steel               NaN       Multiphase            NaN
# 4      Carbon Steel               NaN       Multiphase            NaN
# ...             ...               ...              ...            ...
# 21937           NaN               NaN              NaN            NaN
# 21938           NaN               NaN              NaN            NaN
# 21939           NaN               NaN              NaN            NaN
# 21940           NaN               NaN              NaN            NaN
# 21941         Other               NaN              NaN            NaN
#
#                CONSTRUCTDATE  \
# 0      2000-07-15 00:00:00.0
# 1      1983-11-09 00:00:00.0
# 2      1983-12-07 00:00:00.0
# 3      2006-06-05 00:00:00.0
# 4      2007-04-08 00:00:00.0
# ...                      ...
# 21937  2001-10-02 00:00:00.0
# 21938  2008-02-22 00:00:00.0
# 21939  2007-08-05 00:00:00.0
# 21940  1998-09-27 00:00:00.0
# 21941  1983-10-21 00:00:00.0
#
#                                                 geometry
# 0                          LINESTRING (NaN NaN, NaN NaN)
# 1      LINESTRING (507682.442 4439497.658, 507696.855...
# 2      LINESTRING (507681.545 4440214.668, 507698.219...
# 3      LINESTRING (497435.796 4434841.42, 497093.111 ...
# 4      LINESTRING (497032.513 4434424.239, 497093.196...
# ...                                                  ...
# 21937  LINESTRING (530328.842 4472004.142, 529900.46 ...
# 21938  LINESTRING (543137.34 4481306.751, 542977.867 ...
# 21939  LINESTRING (519355.342 4482133.153, 519296.77 ...
# 21940  LINESTRING (519464.458 4482538.588, 519296.77 ...
# 21941  LINESTRING (515773.134 4480495.258, 515605.088...
#
# [21942 rows x 20 columns]

# %%
fl_gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# #### Spills Transformation

# %%
# Convert 'spills' DataFrame to GeoDataFrame 'spl_gdf' with Point geometries from 'Long' and 'Lat', setting CRS to 'EPSG:4326'.
spl_gdf = gpd.GeoDataFrame(final_spills, geometry=gpd.points_from_xy(final_spills.Long,final_spills.Lat), crs='EPSG:4326')
spl_gdf.head(2)
spl_gdf.plot()
# Out:
# <Axes: >

# %%
# Check if the CRS of fl_gdf is different from that of gdf
if spl_gdf.crs != gdf.crs:
    # If true, convert the CRS of fl_gdf to match that of gdf, modifying fl_gdf in place
    spl_gdf.to_crs(gdf.crs, inplace=True)
    print('Change spl crs to gdf crs')
# Out:
# Change spl crs to gdf crs

# %%
spl_gdf.plot()
# Out:
# <Axes: >

# %%
spl_gdf.head(2)
# Out:
#       trkg_num                        Operator Name facility_type  \
# 705  401530532             K P KAUFFMAN COMPANY INC      FLOWLINE
# 713  401524345  GREAT WESTERN OPERATING COMPANY LLC  TANK BATTERY
#
#                                             Spill_Desc Spill Type  \
# 705  Historical contamination was discovered during...          1
# 713  Soil impacts were discovered during removal of...          1
#
#                                             Root Cause  \
# 705  Facility #7 consolidation line failed do to un...
# 713                                            Unknown
#
#                                   Preventative Measure Root Cause Type  \
# 705  The damaged section of flowline was repaired a...         Unknown
# 713                                                NaN         Unknown
#
#     Detailed Root Cause Type        Long        Lat facility_status Metallic?  \
# 705                  Unknown -104.914183  40.019361              CL   Unknown
# 713                  Unknown -104.467746  39.602613              AC   Unknown
#
#            incident_date                        geometry
# 705  2018-01-10 00:00:00  POINT (507323.245 4429909.631)
# 713  2018-01-23 00:00:00  POINT (545695.434 4383787.964)

# %% [markdown]
# ### Download all new gbd files

# %%
gdf.to_file('crudeoil_offlocation.geojson', driver='GeoJSON')

# %%
fl_gdf.to_file('flowlines.geojson', driver='GeoJSON')
# Out:
# /Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/ecmc_env/lib/python3.11/site-packages/pyogrio/raw.py:723: RuntimeWarning: Infinite or NaN coordinate encountered
#   ogr_write(

# %%
spl_gdf.to_file('spills.geojson', driver='GeoJSON')
# Out:
# /Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/ecmc_env/lib/python3.11/site-packages/pyogrio/raw.py:723: RuntimeWarning: Infinite or NaN coordinate encountered
#   ogr_write(
