# %% [markdown]
# This code creates a buffer(50 meters max) around the spill points and finds the nearest flowline intersection, asserting that the operator name is the same. It then changes the matches spills geometry location to its respective flowline intersection point.
#
# - you cannot export 2 geometry columns, so we only kept the flowline geometry, not the spills

# %% [markdown]
# ## Setup

# %%
import os
import pandas as pd
import geopandas as gpd
from shapely.geometry import MultiLineString, LineString, Point
from shapely.ops import nearest_points

os.chdir('/Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/Data')
pd.options.display.max_columns = None

# %%
# Load Data
matched_flowlines_gdf = gpd.read_file('matched_flowlines.geojson')
spills_gdf = gpd.read_file('spills.geojson')

# %%
# Check if CRS is the same for both files
if matched_flowlines_gdf.crs != spills_gdf.crs:
    flowlines_gdf = matched_flowlines_gdf.to_crs(spills_gdf.crs)

# %%
print(spills_gdf.crs)
print(matched_flowlines_gdf.crs)
# Out:
# EPSG:26913
# EPSG:26913

# %%
# Check size
print(matched_flowlines_gdf.shape)
print(spills_gdf.shape)
# Out:
# (14611, 27)
# (1115, 16)

# %%
print(spills_gdf.is_valid.all())
print(matched_flowlines_gdf.is_valid.all())
# Out:
# False
# True

# %%
spills_gdf = spills_gdf[spills_gdf.is_valid]
matched_flowlines_gdf = matched_flowlines_gdf[matched_flowlines_gdf.is_valid]

# %%
print(spills_gdf.is_valid.all())
print(matched_flowlines_gdf.is_valid.all())
# Out:
# True
# True

# %%
matched_flowlines_gdf.head(2)
# Out:
#                                    ACTIONDESCRIPTION   BEDDINGMATERIAL  \
# 0  The flowline serving the Emerson 3-29J (05-123...  Native Materials
# 1  The flowline (12311399_FL) servicing the Emers...  Native Materials
#
#                                         COMPANY_NAME CONSTRUCTDATE  Diam_in  \
# 0  CRESTONE PEAK RESOURCES OPERATING LLC         ...    1983-11-09      2.0
# 1  CRESTONE PEAK RESOURCES OPERATING LLC         ...    1983-12-07      2.0
#
#       ENDLAT     ENDLONG ENTIRELINEREMOVED  FLOWLINEACTION  FLOWLINEID  \
# 0  40.109444 -104.909686              None            None    470446.0
# 1  40.109441 -104.909670              True  Out of Service    470445.0
#
#         Fluid           LOCATIONTYPE  LOCATION_ID  Length_ft  MAXOPPRESSURE  \
# 0  Multiphase  Production Facilities     470443.0    1361.28          325.0
# 1  Multiphase  Production Facilities     470443.0    1025.98          250.0
#
#        Material  OPERATOR_NUM                               Operator  \
# 0  Carbon Steel         10633  CRESTONE PEAK RESOURCES OPERATING LLC
# 1  Carbon Steel         10633  CRESTONE PEAK RESOURCES OPERATING LLC
#
#    PIPEMATERIAL            RECEIVE_DATE  SHAPE_Length   STARTLAT  \
# 0  Carbon Steel 2023-10-24 08:33:49.223    414.751530  40.105743
# 1  Carbon Steel 2023-10-24 08:33:49.223    312.594254  40.112203
#
#    STARTLOCATIONID   STARTLONG  Status TYPEOFFLUIDTRANS  \
# 0              NaN -104.909860  Active       Multiphase
# 1         319521.0 -104.909862  Active       Multiphase
#
#                                             geometry
# 0  MULTILINESTRING ((507682.447 4439497.657, 5076...
# 1  MULTILINESTRING ((507681.553 4440214.644, 5076...

# %%
matched_flowlines_gdf["geometry"].head(1)[0]
matched_flowlines_gdf["geometry"].head(1).buffer(50)[0]
# Out:
# <POLYGON ((507633.549 4439515.817, 507633.729 4439552.229, 507633.733 443955...>

# %%
spills_gdf.head(2)
# Out:
#     trkg_num                        Operator Name facility_type  \
# 0  401530532             K P KAUFFMAN COMPANY INC      FLOWLINE
# 1  401524345  GREAT WESTERN OPERATING COMPANY LLC  TANK BATTERY
#
#                                           Spill_Desc Spill Type  \
# 0  Historical contamination was discovered during...          1
# 1  Soil impacts were discovered during removal of...          1
#
#                                           Root Cause  \
# 0  Facility #7 consolidation line failed do to un...
# 1                                            Unknown
#
#                                 Preventative Measure Root Cause Type  \
# 0  The damaged section of flowline was repaired a...         Unknown
# 1                                               None         Unknown
#
#   Detailed Root Cause Type        Long        Lat facility_status Gathering?  \
# 0                  Unknown -104.914183  40.019361              CL       None
# 1                  Unknown -104.467746  39.602613              AC       None
#
#   Metallic?        incident_date                        geometry
# 0   Unknown  2018-01-10 00:00:00  POINT (507323.245 4429909.631)
# 1   Unknown  2018-01-23 00:00:00  POINT (545695.434 4383787.964)

# %%
import geopandas as gpd

# Initialize an empty list to store matched data and a set for matched flowline indices
matched_spills = []
matched_flowline_indices = set()

max_buffer_distance = 25  # Maximum buffer distance in meters
buffer_increment = 0.5    # Buffer increment in meters

# Create spatial index for the flowlines geometries
flowlines_sindex = matched_flowlines_gdf.sindex

for index, spill in spills_gdf.iterrows():
    if spill.geometry is None:
        print(f"Missing geometry for spill at index {index}. Skipping...")
        continue

    buffer_distance = 0
    match_found = False

    while buffer_distance <= max_buffer_distance and not match_found:
        buffered_spill = spill.geometry.buffer(buffer_distance)
        possible_matches_index = list(flowlines_sindex.intersection(buffered_spill.bounds))
        possible_matches = matched_flowlines_gdf.iloc[possible_matches_index]

        for flowline_index, flowline in possible_matches.iterrows():
            if buffered_spill.intersects(flowline.geometry):
                if spill['Operator Name'].strip().lower() == flowline['Operator'].strip().lower():
                    print(f"Operator match found at buffer distance {buffer_distance} meters for spill at index {index}.")
                    match_found = True
                    matched_flowline_indices.add(flowline_index)  # Track matched flowline index
                    print(f"Adding match: Flowline index {flowline_index}")

                    updated_spill = spill.copy()
                    updated_spill.geometry = flowline.geometry
                    for col in flowline.index:
                        updated_spill[col] = flowline[col]

                    matched_spills.append(updated_spill)
                    break

        if not match_found:
            buffer_distance += buffer_increment

    if not match_found:
        print(f"No operator match found for spill at index {index} even after expanding buffer to {max_buffer_distance} meters.")

matched_spills_gdf = gpd.GeoDataFrame(matched_spills, columns=spills_gdf.columns.union(matched_flowlines_gdf.columns), crs=spills_gdf.crs)
# Out:
# No operator match found for spill at index 0 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1 even after expanding buffer to 25 meters.
# No operator match found for spill at index 2 even after expanding buffer to 25 meters.
# No operator match found for spill at index 3 even after expanding buffer to 25 meters.
# No operator match found for spill at index 4 even after expanding buffer to 25 meters.
# No operator match found for spill at index 5 even after expanding buffer to 25 meters.
# No operator match found for spill at index 6 even after expanding buffer to 25 meters.
# No operator match found for spill at index 7 even after expanding buffer to 25 meters.
# No operator match found for spill at index 8 even after expanding buffer to 25 meters.
# No operator match found for spill at index 9 even after expanding buffer to 25 meters.
# No operator match found for spill at index 10 even after expanding buffer to 25 meters.
# No operator match found for spill at index 11 even after expanding buffer to 25 meters.
# No operator match found for spill at index 12 even after expanding buffer to 25 meters.
# No operator match found for spill at index 13 even after expanding buffer to 25 meters.
# No operator match found for spill at index 14 even after expanding buffer to 25 meters.
# No operator match found for spill at index 15 even after expanding buffer to 25 meters.
# No operator match found for spill at index 16 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 4.5 meters for spill at index 17.
# Adding match: Flowline index 11402
# No operator match found for spill at index 18 even after expanding buffer to 25 meters.
# No operator match found for spill at index 19 even after expanding buffer to 25 meters.
# No operator match found for spill at index 20 even after expanding buffer to 25 meters.
# No operator match found for spill at index 21 even after expanding buffer to 25 meters.
# No operator match found for spill at index 22 even after expanding buffer to 25 meters.
# No operator match found for spill at index 23 even after expanding buffer to 25 meters.
# No operator match found for spill at index 24 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 16.5 meters for spill at index 25.
# Adding match: Flowline index 11402
# No operator match found for spill at index 26 even after expanding buffer to 25 meters.
# No operator match found for spill at index 27 even after expanding buffer to 25 meters.
# No operator match found for spill at index 28 even after expanding buffer to 25 meters.
# No operator match found for spill at index 29 even after expanding buffer to 25 meters.
# No operator match found for spill at index 30 even after expanding buffer to 25 meters.
# No operator match found for spill at index 31 even after expanding buffer to 25 meters.
# No operator match found for spill at index 32 even after expanding buffer to 25 meters.
# No operator match found for spill at index 33 even after expanding buffer to 25 meters.
# No operator match found for spill at index 34 even after expanding buffer to 25 meters.
# No operator match found for spill at index 35 even after expanding buffer to 25 meters.
# No operator match found for spill at index 36 even after expanding buffer to 25 meters.
# No operator match found for spill at index 37 even after expanding buffer to 25 meters.
# No operator match found for spill at index 38 even after expanding buffer to 25 meters.
# No operator match found for spill at index 39 even after expanding buffer to 25 meters.
# No operator match found for spill at index 40 even after expanding buffer to 25 meters.
# No operator match found for spill at index 41 even after expanding buffer to 25 meters.
# No operator match found for spill at index 42 even after expanding buffer to 25 meters.
# No operator match found for spill at index 43 even after expanding buffer to 25 meters.
# No operator match found for spill at index 44 even after expanding buffer to 25 meters.
# No operator match found for spill at index 45 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 2.0 meters for spill at index 46.
# Adding match: Flowline index 10241
# No operator match found for spill at index 47 even after expanding buffer to 25 meters.
# No operator match found for spill at index 48 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 12.5 meters for spill at index 49.
# Adding match: Flowline index 11408
# Operator match found at buffer distance 12.5 meters for spill at index 50.
# Adding match: Flowline index 11408
# No operator match found for spill at index 51 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 1.5 meters for spill at index 52.
# Adding match: Flowline index 13590
# No operator match found for spill at index 53 even after expanding buffer to 25 meters.
# No operator match found for spill at index 54 even after expanding buffer to 25 meters.
# No operator match found for spill at index 55 even after expanding buffer to 25 meters.
# No operator match found for spill at index 56 even after expanding buffer to 25 meters.
# No operator match found for spill at index 57 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 2.5 meters for spill at index 58.
# Adding match: Flowline index 8966
# No operator match found for spill at index 59 even after expanding buffer to 25 meters.
# No operator match found for spill at index 60 even after expanding buffer to 25 meters.
# No operator match found for spill at index 61 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 1.0 meters for spill at index 62.
# Adding match: Flowline index 9391
# No operator match found for spill at index 63 even after expanding buffer to 25 meters.
# No operator match found for spill at index 64 even after expanding buffer to 25 meters.
# No operator match found for spill at index 65 even after expanding buffer to 25 meters.
# No operator match found for spill at index 66 even after expanding buffer to 25 meters.
# No operator match found for spill at index 67 even after expanding buffer to 25 meters.
# No operator match found for spill at index 68 even after expanding buffer to 25 meters.
# No operator match found for spill at index 69 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 12.5 meters for spill at index 70.
# Adding match: Flowline index 4476
# No operator match found for spill at index 71 even after expanding buffer to 25 meters.
# No operator match found for spill at index 72 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 1.5 meters for spill at index 73.
# Adding match: Flowline index 2568
# No operator match found for spill at index 74 even after expanding buffer to 25 meters.
# No operator match found for spill at index 75 even after expanding buffer to 25 meters.
# No operator match found for spill at index 76 even after expanding buffer to 25 meters.
# No operator match found for spill at index 77 even after expanding buffer to 25 meters.
# No operator match found for spill at index 78 even after expanding buffer to 25 meters.
# No operator match found for spill at index 79 even after expanding buffer to 25 meters.
# No operator match found for spill at index 80 even after expanding buffer to 25 meters.
# No operator match found for spill at index 81 even after expanding buffer to 25 meters.
# No operator match found for spill at index 82 even after expanding buffer to 25 meters.
# No operator match found for spill at index 83 even after expanding buffer to 25 meters.
# No operator match found for spill at index 84 even after expanding buffer to 25 meters.
# No operator match found for spill at index 85 even after expanding buffer to 25 meters.
# No operator match found for spill at index 86 even after expanding buffer to 25 meters.
# No operator match found for spill at index 87 even after expanding buffer to 25 meters.
# No operator match found for spill at index 88 even after expanding buffer to 25 meters.
# No operator match found for spill at index 89 even after expanding buffer to 25 meters.
# No operator match found for spill at index 90 even after expanding buffer to 25 meters.
# No operator match found for spill at index 91 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 2.5 meters for spill at index 92.
# Adding match: Flowline index 4833
# No operator match found for spill at index 93 even after expanding buffer to 25 meters.
# No operator match found for spill at index 94 even after expanding buffer to 25 meters.
# No operator match found for spill at index 95 even after expanding buffer to 25 meters.
# No operator match found for spill at index 96 even after expanding buffer to 25 meters.
# No operator match found for spill at index 97 even after expanding buffer to 25 meters.
# No operator match found for spill at index 98 even after expanding buffer to 25 meters.
# No operator match found for spill at index 99 even after expanding buffer to 25 meters.
# No operator match found for spill at index 100 even after expanding buffer to 25 meters.
# No operator match found for spill at index 101 even after expanding buffer to 25 meters.
# No operator match found for spill at index 102 even after expanding buffer to 25 meters.
# No operator match found for spill at index 103 even after expanding buffer to 25 meters.
# No operator match found for spill at index 104 even after expanding buffer to 25 meters.
# No operator match found for spill at index 105 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 5.5 meters for spill at index 106.
# Adding match: Flowline index 11402
# No operator match found for spill at index 107 even after expanding buffer to 25 meters.
# No operator match found for spill at index 108 even after expanding buffer to 25 meters.
# No operator match found for spill at index 109 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 10.5 meters for spill at index 110.
# Adding match: Flowline index 11402
# No operator match found for spill at index 111 even after expanding buffer to 25 meters.
# No operator match found for spill at index 112 even after expanding buffer to 25 meters.
# No operator match found for spill at index 113 even after expanding buffer to 25 meters.
# No operator match found for spill at index 114 even after expanding buffer to 25 meters.
# No operator match found for spill at index 115 even after expanding buffer to 25 meters.
# No operator match found for spill at index 116 even after expanding buffer to 25 meters.
# No operator match found for spill at index 117 even after expanding buffer to 25 meters.
# No operator match found for spill at index 118 even after expanding buffer to 25 meters.
# No operator match found for spill at index 119 even after expanding buffer to 25 meters.
# No operator match found for spill at index 120 even after expanding buffer to 25 meters.
# No operator match found for spill at index 121 even after expanding buffer to 25 meters.
# No operator match found for spill at index 122 even after expanding buffer to 25 meters.
# No operator match found for spill at index 123 even after expanding buffer to 25 meters.
# No operator match found for spill at index 124 even after expanding buffer to 25 meters.
# No operator match found for spill at index 125 even after expanding buffer to 25 meters.
# No operator match found for spill at index 126 even after expanding buffer to 25 meters.
# No operator match found for spill at index 127 even after expanding buffer to 25 meters.
# No operator match found for spill at index 128 even after expanding buffer to 25 meters.
# No operator match found for spill at index 129 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 10.5 meters for spill at index 130.
# Adding match: Flowline index 7352
# No operator match found for spill at index 131 even after expanding buffer to 25 meters.
# No operator match found for spill at index 132 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 17.0 meters for spill at index 133.
# Adding match: Flowline index 11021
# Operator match found at buffer distance 11.5 meters for spill at index 134.
# Adding match: Flowline index 5334
# No operator match found for spill at index 135 even after expanding buffer to 25 meters.
# No operator match found for spill at index 136 even after expanding buffer to 25 meters.
# No operator match found for spill at index 137 even after expanding buffer to 25 meters.
# No operator match found for spill at index 138 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 25.0 meters for spill at index 139.
# Adding match: Flowline index 9046
# No operator match found for spill at index 140 even after expanding buffer to 25 meters.
# No operator match found for spill at index 141 even after expanding buffer to 25 meters.
# No operator match found for spill at index 142 even after expanding buffer to 25 meters.
# No operator match found for spill at index 143 even after expanding buffer to 25 meters.
# No operator match found for spill at index 144 even after expanding buffer to 25 meters.
# No operator match found for spill at index 145 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 0.5 meters for spill at index 146.
# Adding match: Flowline index 4035
# No operator match found for spill at index 147 even after expanding buffer to 25 meters.
# No operator match found for spill at index 148 even after expanding buffer to 25 meters.
# No operator match found for spill at index 149 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 1.0 meters for spill at index 150.
# Adding match: Flowline index 12553
# No operator match found for spill at index 151 even after expanding buffer to 25 meters.
# No operator match found for spill at index 152 even after expanding buffer to 25 meters.
# No operator match found for spill at index 153 even after expanding buffer to 25 meters.
# No operator match found for spill at index 154 even after expanding buffer to 25 meters.
# No operator match found for spill at index 155 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 2.5 meters for spill at index 156.
# Adding match: Flowline index 4673
# No operator match found for spill at index 157 even after expanding buffer to 25 meters.
# No operator match found for spill at index 158 even after expanding buffer to 25 meters.
# No operator match found for spill at index 159 even after expanding buffer to 25 meters.
# No operator match found for spill at index 160 even after expanding buffer to 25 meters.
# No operator match found for spill at index 161 even after expanding buffer to 25 meters.
# No operator match found for spill at index 162 even after expanding buffer to 25 meters.
# No operator match found for spill at index 163 even after expanding buffer to 25 meters.
# No operator match found for spill at index 164 even after expanding buffer to 25 meters.
# No operator match found for spill at index 165 even after expanding buffer to 25 meters.
# No operator match found for spill at index 166 even after expanding buffer to 25 meters.
# No operator match found for spill at index 167 even after expanding buffer to 25 meters.
# No operator match found for spill at index 168 even after expanding buffer to 25 meters.
# No operator match found for spill at index 169 even after expanding buffer to 25 meters.
# No operator match found for spill at index 170 even after expanding buffer to 25 meters.
# No operator match found for spill at index 171 even after expanding buffer to 25 meters.
# No operator match found for spill at index 172 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 24.0 meters for spill at index 173.
# Adding match: Flowline index 11402
# No operator match found for spill at index 174 even after expanding buffer to 25 meters.
# No operator match found for spill at index 175 even after expanding buffer to 25 meters.
# No operator match found for spill at index 176 even after expanding buffer to 25 meters.
# No operator match found for spill at index 177 even after expanding buffer to 25 meters.
# No operator match found for spill at index 178 even after expanding buffer to 25 meters.
# No operator match found for spill at index 179 even after expanding buffer to 25 meters.
# No operator match found for spill at index 180 even after expanding buffer to 25 meters.
# No operator match found for spill at index 181 even after expanding buffer to 25 meters.
# No operator match found for spill at index 182 even after expanding buffer to 25 meters.
# No operator match found for spill at index 183 even after expanding buffer to 25 meters.
# No operator match found for spill at index 184 even after expanding buffer to 25 meters.
# No operator match found for spill at index 185 even after expanding buffer to 25 meters.
# No operator match found for spill at index 186 even after expanding buffer to 25 meters.
# No operator match found for spill at index 187 even after expanding buffer to 25 meters.
# No operator match found for spill at index 188 even after expanding buffer to 25 meters.
# No operator match found for spill at index 189 even after expanding buffer to 25 meters.
# No operator match found for spill at index 190 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 3.5 meters for spill at index 191.
# Adding match: Flowline index 8169
# No operator match found for spill at index 192 even after expanding buffer to 25 meters.
# No operator match found for spill at index 193 even after expanding buffer to 25 meters.
# No operator match found for spill at index 194 even after expanding buffer to 25 meters.
# No operator match found for spill at index 195 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 7.5 meters for spill at index 196.
# Adding match: Flowline index 11408
# No operator match found for spill at index 197 even after expanding buffer to 25 meters.
# No operator match found for spill at index 198 even after expanding buffer to 25 meters.
# No operator match found for spill at index 199 even after expanding buffer to 25 meters.
# No operator match found for spill at index 200 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 9.0 meters for spill at index 201.
# Adding match: Flowline index 11414
# No operator match found for spill at index 202 even after expanding buffer to 25 meters.
# No operator match found for spill at index 203 even after expanding buffer to 25 meters.
# No operator match found for spill at index 204 even after expanding buffer to 25 meters.
# No operator match found for spill at index 205 even after expanding buffer to 25 meters.
# No operator match found for spill at index 206 even after expanding buffer to 25 meters.
# No operator match found for spill at index 207 even after expanding buffer to 25 meters.
# No operator match found for spill at index 208 even after expanding buffer to 25 meters.
# No operator match found for spill at index 209 even after expanding buffer to 25 meters.
# No operator match found for spill at index 210 even after expanding buffer to 25 meters.
# No operator match found for spill at index 211 even after expanding buffer to 25 meters.
# No operator match found for spill at index 212 even after expanding buffer to 25 meters.
# No operator match found for spill at index 213 even after expanding buffer to 25 meters.
# No operator match found for spill at index 214 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 5.5 meters for spill at index 215.
# Adding match: Flowline index 10449
# No operator match found for spill at index 216 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 2.5 meters for spill at index 217.
# Adding match: Flowline index 4378
# No operator match found for spill at index 218 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 3.5 meters for spill at index 219.
# Adding match: Flowline index 5917
# No operator match found for spill at index 220 even after expanding buffer to 25 meters.
# No operator match found for spill at index 221 even after expanding buffer to 25 meters.
# No operator match found for spill at index 222 even after expanding buffer to 25 meters.
# No operator match found for spill at index 223 even after expanding buffer to 25 meters.
# No operator match found for spill at index 224 even after expanding buffer to 25 meters.
# No operator match found for spill at index 225 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 3.5 meters for spill at index 226.
# Adding match: Flowline index 3987
# No operator match found for spill at index 227 even after expanding buffer to 25 meters.
# No operator match found for spill at index 228 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 5.0 meters for spill at index 229.
# Adding match: Flowline index 1271
# Operator match found at buffer distance 8.5 meters for spill at index 230.
# Adding match: Flowline index 4378
# No operator match found for spill at index 231 even after expanding buffer to 25 meters.
# No operator match found for spill at index 232 even after expanding buffer to 25 meters.
# No operator match found for spill at index 233 even after expanding buffer to 25 meters.
# No operator match found for spill at index 234 even after expanding buffer to 25 meters.
# No operator match found for spill at index 235 even after expanding buffer to 25 meters.
# No operator match found for spill at index 236 even after expanding buffer to 25 meters.
# No operator match found for spill at index 237 even after expanding buffer to 25 meters.
# No operator match found for spill at index 238 even after expanding buffer to 25 meters.
# No operator match found for spill at index 239 even after expanding buffer to 25 meters.
# No operator match found for spill at index 240 even after expanding buffer to 25 meters.
# No operator match found for spill at index 241 even after expanding buffer to 25 meters.
# No operator match found for spill at index 242 even after expanding buffer to 25 meters.
# No operator match found for spill at index 243 even after expanding buffer to 25 meters.
# No operator match found for spill at index 244 even after expanding buffer to 25 meters.
# No operator match found for spill at index 245 even after expanding buffer to 25 meters.
# No operator match found for spill at index 246 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 17.0 meters for spill at index 247.
# Adding match: Flowline index 4374
# No operator match found for spill at index 248 even after expanding buffer to 25 meters.
# No operator match found for spill at index 249 even after expanding buffer to 25 meters.
# No operator match found for spill at index 250 even after expanding buffer to 25 meters.
# No operator match found for spill at index 251 even after expanding buffer to 25 meters.
# No operator match found for spill at index 252 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 0.5 meters for spill at index 253.
# Adding match: Flowline index 4309
# No operator match found for spill at index 254 even after expanding buffer to 25 meters.
# No operator match found for spill at index 255 even after expanding buffer to 25 meters.
# No operator match found for spill at index 256 even after expanding buffer to 25 meters.
# No operator match found for spill at index 257 even after expanding buffer to 25 meters.
# No operator match found for spill at index 258 even after expanding buffer to 25 meters.
# No operator match found for spill at index 259 even after expanding buffer to 25 meters.
# No operator match found for spill at index 260 even after expanding buffer to 25 meters.
# No operator match found for spill at index 261 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 6.5 meters for spill at index 262.
# Adding match: Flowline index 7264
# No operator match found for spill at index 263 even after expanding buffer to 25 meters.
# No operator match found for spill at index 264 even after expanding buffer to 25 meters.
# No operator match found for spill at index 265 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 9.5 meters for spill at index 266.
# Adding match: Flowline index 2684
# Operator match found at buffer distance 5.5 meters for spill at index 267.
# Adding match: Flowline index 11408
# No operator match found for spill at index 268 even after expanding buffer to 25 meters.
# No operator match found for spill at index 269 even after expanding buffer to 25 meters.
# No operator match found for spill at index 270 even after expanding buffer to 25 meters.
# No operator match found for spill at index 271 even after expanding buffer to 25 meters.
# No operator match found for spill at index 272 even after expanding buffer to 25 meters.
# No operator match found for spill at index 273 even after expanding buffer to 25 meters.
# No operator match found for spill at index 274 even after expanding buffer to 25 meters.
# No operator match found for spill at index 275 even after expanding buffer to 25 meters.
# No operator match found for spill at index 276 even after expanding buffer to 25 meters.
# No operator match found for spill at index 277 even after expanding buffer to 25 meters.
# No operator match found for spill at index 278 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 5.5 meters for spill at index 279.
# Adding match: Flowline index 11408
# Operator match found at buffer distance 9.0 meters for spill at index 280.
# Adding match: Flowline index 1103
# No operator match found for spill at index 281 even after expanding buffer to 25 meters.
# No operator match found for spill at index 282 even after expanding buffer to 25 meters.
# No operator match found for spill at index 283 even after expanding buffer to 25 meters.
# No operator match found for spill at index 284 even after expanding buffer to 25 meters.
# No operator match found for spill at index 285 even after expanding buffer to 25 meters.
# No operator match found for spill at index 286 even after expanding buffer to 25 meters.
# No operator match found for spill at index 287 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 0.5 meters for spill at index 288.
# Adding match: Flowline index 7098
# No operator match found for spill at index 289 even after expanding buffer to 25 meters.
# No operator match found for spill at index 290 even after expanding buffer to 25 meters.
# No operator match found for spill at index 291 even after expanding buffer to 25 meters.
# No operator match found for spill at index 292 even after expanding buffer to 25 meters.
# No operator match found for spill at index 293 even after expanding buffer to 25 meters.
# No operator match found for spill at index 294 even after expanding buffer to 25 meters.
# No operator match found for spill at index 295 even after expanding buffer to 25 meters.
# No operator match found for spill at index 296 even after expanding buffer to 25 meters.
# No operator match found for spill at index 297 even after expanding buffer to 25 meters.
# No operator match found for spill at index 298 even after expanding buffer to 25 meters.
# No operator match found for spill at index 299 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 10.0 meters for spill at index 300.
# Adding match: Flowline index 12427
# No operator match found for spill at index 301 even after expanding buffer to 25 meters.
# No operator match found for spill at index 302 even after expanding buffer to 25 meters.
# No operator match found for spill at index 303 even after expanding buffer to 25 meters.
# No operator match found for spill at index 304 even after expanding buffer to 25 meters.
# No operator match found for spill at index 305 even after expanding buffer to 25 meters.
# No operator match found for spill at index 306 even after expanding buffer to 25 meters.
# No operator match found for spill at index 307 even after expanding buffer to 25 meters.
# No operator match found for spill at index 308 even after expanding buffer to 25 meters.
# No operator match found for spill at index 309 even after expanding buffer to 25 meters.
# No operator match found for spill at index 310 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 8.5 meters for spill at index 311.
# Adding match: Flowline index 4796
# No operator match found for spill at index 312 even after expanding buffer to 25 meters.
# No operator match found for spill at index 313 even after expanding buffer to 25 meters.
# No operator match found for spill at index 314 even after expanding buffer to 25 meters.
# No operator match found for spill at index 315 even after expanding buffer to 25 meters.
# No operator match found for spill at index 316 even after expanding buffer to 25 meters.
# No operator match found for spill at index 317 even after expanding buffer to 25 meters.
# No operator match found for spill at index 318 even after expanding buffer to 25 meters.
# No operator match found for spill at index 319 even after expanding buffer to 25 meters.
# No operator match found for spill at index 320 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 0.5 meters for spill at index 321.
# Adding match: Flowline index 11402
# No operator match found for spill at index 322 even after expanding buffer to 25 meters.
# No operator match found for spill at index 323 even after expanding buffer to 25 meters.
# No operator match found for spill at index 324 even after expanding buffer to 25 meters.
# No operator match found for spill at index 325 even after expanding buffer to 25 meters.
# No operator match found for spill at index 326 even after expanding buffer to 25 meters.
# No operator match found for spill at index 327 even after expanding buffer to 25 meters.
# No operator match found for spill at index 328 even after expanding buffer to 25 meters.
# No operator match found for spill at index 329 even after expanding buffer to 25 meters.
# No operator match found for spill at index 330 even after expanding buffer to 25 meters.
# No operator match found for spill at index 331 even after expanding buffer to 25 meters.
# No operator match found for spill at index 332 even after expanding buffer to 25 meters.
# No operator match found for spill at index 333 even after expanding buffer to 25 meters.
# No operator match found for spill at index 334 even after expanding buffer to 25 meters.
# No operator match found for spill at index 335 even after expanding buffer to 25 meters.
# No operator match found for spill at index 336 even after expanding buffer to 25 meters.
# No operator match found for spill at index 337 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 13.0 meters for spill at index 338.
# Adding match: Flowline index 12512
# No operator match found for spill at index 339 even after expanding buffer to 25 meters.
# No operator match found for spill at index 340 even after expanding buffer to 25 meters.
# No operator match found for spill at index 341 even after expanding buffer to 25 meters.
# No operator match found for spill at index 342 even after expanding buffer to 25 meters.
# No operator match found for spill at index 343 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 14.0 meters for spill at index 344.
# Adding match: Flowline index 7328
# No operator match found for spill at index 345 even after expanding buffer to 25 meters.
# No operator match found for spill at index 346 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 4.5 meters for spill at index 347.
# Adding match: Flowline index 4689
# No operator match found for spill at index 348 even after expanding buffer to 25 meters.
# No operator match found for spill at index 349 even after expanding buffer to 25 meters.
# No operator match found for spill at index 350 even after expanding buffer to 25 meters.
# No operator match found for spill at index 351 even after expanding buffer to 25 meters.
# No operator match found for spill at index 352 even after expanding buffer to 25 meters.
# No operator match found for spill at index 353 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 2.5 meters for spill at index 354.
# Adding match: Flowline index 5917
# Operator match found at buffer distance 2.5 meters for spill at index 355.
# Adding match: Flowline index 5917
# No operator match found for spill at index 356 even after expanding buffer to 25 meters.
# No operator match found for spill at index 357 even after expanding buffer to 25 meters.
# No operator match found for spill at index 358 even after expanding buffer to 25 meters.
# No operator match found for spill at index 359 even after expanding buffer to 25 meters.
# No operator match found for spill at index 360 even after expanding buffer to 25 meters.
# No operator match found for spill at index 361 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 9.0 meters for spill at index 362.
# Adding match: Flowline index 4786
# Operator match found at buffer distance 9.0 meters for spill at index 363.
# Adding match: Flowline index 4290
# Operator match found at buffer distance 16.0 meters for spill at index 364.
# Adding match: Flowline index 4673
# No operator match found for spill at index 365 even after expanding buffer to 25 meters.
# No operator match found for spill at index 366 even after expanding buffer to 25 meters.
# No operator match found for spill at index 367 even after expanding buffer to 25 meters.
# No operator match found for spill at index 368 even after expanding buffer to 25 meters.
# No operator match found for spill at index 369 even after expanding buffer to 25 meters.
# No operator match found for spill at index 370 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 1.0 meters for spill at index 371.
# Adding match: Flowline index 5343
# No operator match found for spill at index 372 even after expanding buffer to 25 meters.
# No operator match found for spill at index 373 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 4.5 meters for spill at index 374.
# Adding match: Flowline index 12775
# No operator match found for spill at index 375 even after expanding buffer to 25 meters.
# No operator match found for spill at index 376 even after expanding buffer to 25 meters.
# No operator match found for spill at index 377 even after expanding buffer to 25 meters.
# No operator match found for spill at index 378 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 13.5 meters for spill at index 379.
# Adding match: Flowline index 4708
# No operator match found for spill at index 380 even after expanding buffer to 25 meters.
# No operator match found for spill at index 381 even after expanding buffer to 25 meters.
# No operator match found for spill at index 382 even after expanding buffer to 25 meters.
# No operator match found for spill at index 383 even after expanding buffer to 25 meters.
# No operator match found for spill at index 384 even after expanding buffer to 25 meters.
# No operator match found for spill at index 385 even after expanding buffer to 25 meters.
# No operator match found for spill at index 386 even after expanding buffer to 25 meters.
# No operator match found for spill at index 387 even after expanding buffer to 25 meters.
# No operator match found for spill at index 388 even after expanding buffer to 25 meters.
# No operator match found for spill at index 389 even after expanding buffer to 25 meters.
# No operator match found for spill at index 390 even after expanding buffer to 25 meters.
# No operator match found for spill at index 391 even after expanding buffer to 25 meters.
# No operator match found for spill at index 392 even after expanding buffer to 25 meters.
# No operator match found for spill at index 393 even after expanding buffer to 25 meters.
# No operator match found for spill at index 394 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 1.0 meters for spill at index 395.
# Adding match: Flowline index 6517
# No operator match found for spill at index 396 even after expanding buffer to 25 meters.
# No operator match found for spill at index 397 even after expanding buffer to 25 meters.
# No operator match found for spill at index 398 even after expanding buffer to 25 meters.
# No operator match found for spill at index 399 even after expanding buffer to 25 meters.
# No operator match found for spill at index 400 even after expanding buffer to 25 meters.
# No operator match found for spill at index 401 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 14.0 meters for spill at index 402.
# Adding match: Flowline index 9045
# No operator match found for spill at index 403 even after expanding buffer to 25 meters.
# No operator match found for spill at index 404 even after expanding buffer to 25 meters.
# No operator match found for spill at index 405 even after expanding buffer to 25 meters.
# No operator match found for spill at index 406 even after expanding buffer to 25 meters.
# No operator match found for spill at index 407 even after expanding buffer to 25 meters.
# No operator match found for spill at index 408 even after expanding buffer to 25 meters.
# No operator match found for spill at index 409 even after expanding buffer to 25 meters.
# No operator match found for spill at index 410 even after expanding buffer to 25 meters.
# No operator match found for spill at index 411 even after expanding buffer to 25 meters.
# No operator match found for spill at index 412 even after expanding buffer to 25 meters.
# No operator match found for spill at index 413 even after expanding buffer to 25 meters.
# No operator match found for spill at index 414 even after expanding buffer to 25 meters.
# No operator match found for spill at index 415 even after expanding buffer to 25 meters.
# No operator match found for spill at index 416 even after expanding buffer to 25 meters.
# No operator match found for spill at index 417 even after expanding buffer to 25 meters.
# No operator match found for spill at index 418 even after expanding buffer to 25 meters.
# No operator match found for spill at index 419 even after expanding buffer to 25 meters.
# No operator match found for spill at index 420 even after expanding buffer to 25 meters.
# No operator match found for spill at index 592 even after expanding buffer to 25 meters.
# No operator match found for spill at index 593 even after expanding buffer to 25 meters.
# No operator match found for spill at index 594 even after expanding buffer to 25 meters.
# No operator match found for spill at index 595 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 7.0 meters for spill at index 596.
# Adding match: Flowline index 82
# No operator match found for spill at index 597 even after expanding buffer to 25 meters.
# No operator match found for spill at index 598 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 2.0 meters for spill at index 599.
# Adding match: Flowline index 832
# No operator match found for spill at index 600 even after expanding buffer to 25 meters.
# No operator match found for spill at index 601 even after expanding buffer to 25 meters.
# No operator match found for spill at index 602 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 8.5 meters for spill at index 603.
# Adding match: Flowline index 12427
# No operator match found for spill at index 604 even after expanding buffer to 25 meters.
# No operator match found for spill at index 605 even after expanding buffer to 25 meters.
# No operator match found for spill at index 606 even after expanding buffer to 25 meters.
# No operator match found for spill at index 607 even after expanding buffer to 25 meters.
# No operator match found for spill at index 608 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 8.0 meters for spill at index 609.
# Adding match: Flowline index 4401
# No operator match found for spill at index 610 even after expanding buffer to 25 meters.
# No operator match found for spill at index 611 even after expanding buffer to 25 meters.
# No operator match found for spill at index 612 even after expanding buffer to 25 meters.
# No operator match found for spill at index 613 even after expanding buffer to 25 meters.
# No operator match found for spill at index 614 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 6.0 meters for spill at index 615.
# Adding match: Flowline index 5478
# No operator match found for spill at index 616 even after expanding buffer to 25 meters.
# No operator match found for spill at index 617 even after expanding buffer to 25 meters.
# No operator match found for spill at index 618 even after expanding buffer to 25 meters.
# No operator match found for spill at index 619 even after expanding buffer to 25 meters.
# No operator match found for spill at index 620 even after expanding buffer to 25 meters.
# No operator match found for spill at index 621 even after expanding buffer to 25 meters.
# No operator match found for spill at index 622 even after expanding buffer to 25 meters.
# No operator match found for spill at index 623 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 10.0 meters for spill at index 624.
# Adding match: Flowline index 11440
# Operator match found at buffer distance 11.5 meters for spill at index 625.
# Adding match: Flowline index 1258
# Operator match found at buffer distance 24.0 meters for spill at index 626.
# Adding match: Flowline index 13067
# No operator match found for spill at index 627 even after expanding buffer to 25 meters.
# No operator match found for spill at index 628 even after expanding buffer to 25 meters.
# No operator match found for spill at index 629 even after expanding buffer to 25 meters.
# No operator match found for spill at index 630 even after expanding buffer to 25 meters.
# No operator match found for spill at index 631 even after expanding buffer to 25 meters.
# No operator match found for spill at index 632 even after expanding buffer to 25 meters.
# No operator match found for spill at index 633 even after expanding buffer to 25 meters.
# No operator match found for spill at index 634 even after expanding buffer to 25 meters.
# No operator match found for spill at index 635 even after expanding buffer to 25 meters.
# No operator match found for spill at index 636 even after expanding buffer to 25 meters.
# No operator match found for spill at index 637 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 5.0 meters for spill at index 638.
# Adding match: Flowline index 7237
# No operator match found for spill at index 639 even after expanding buffer to 25 meters.
# No operator match found for spill at index 640 even after expanding buffer to 25 meters.
# No operator match found for spill at index 641 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 13.5 meters for spill at index 642.
# Adding match: Flowline index 3324
# No operator match found for spill at index 643 even after expanding buffer to 25 meters.
# No operator match found for spill at index 644 even after expanding buffer to 25 meters.
# No operator match found for spill at index 645 even after expanding buffer to 25 meters.
# No operator match found for spill at index 646 even after expanding buffer to 25 meters.
# No operator match found for spill at index 647 even after expanding buffer to 25 meters.
# No operator match found for spill at index 648 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 7.5 meters for spill at index 649.
# Adding match: Flowline index 2249
# No operator match found for spill at index 650 even after expanding buffer to 25 meters.
# No operator match found for spill at index 651 even after expanding buffer to 25 meters.
# No operator match found for spill at index 652 even after expanding buffer to 25 meters.
# No operator match found for spill at index 653 even after expanding buffer to 25 meters.
# No operator match found for spill at index 654 even after expanding buffer to 25 meters.
# No operator match found for spill at index 655 even after expanding buffer to 25 meters.
# No operator match found for spill at index 656 even after expanding buffer to 25 meters.
# No operator match found for spill at index 657 even after expanding buffer to 25 meters.
# No operator match found for spill at index 658 even after expanding buffer to 25 meters.
# No operator match found for spill at index 659 even after expanding buffer to 25 meters.
# No operator match found for spill at index 660 even after expanding buffer to 25 meters.
# No operator match found for spill at index 661 even after expanding buffer to 25 meters.
# No operator match found for spill at index 662 even after expanding buffer to 25 meters.
# No operator match found for spill at index 663 even after expanding buffer to 25 meters.
# No operator match found for spill at index 664 even after expanding buffer to 25 meters.
# No operator match found for spill at index 665 even after expanding buffer to 25 meters.
# No operator match found for spill at index 666 even after expanding buffer to 25 meters.
# No operator match found for spill at index 667 even after expanding buffer to 25 meters.
# No operator match found for spill at index 668 even after expanding buffer to 25 meters.
# No operator match found for spill at index 669 even after expanding buffer to 25 meters.
# No operator match found for spill at index 670 even after expanding buffer to 25 meters.
# No operator match found for spill at index 671 even after expanding buffer to 25 meters.
# No operator match found for spill at index 672 even after expanding buffer to 25 meters.
# No operator match found for spill at index 673 even after expanding buffer to 25 meters.
# No operator match found for spill at index 674 even after expanding buffer to 25 meters.
# No operator match found for spill at index 675 even after expanding buffer to 25 meters.
# No operator match found for spill at index 676 even after expanding buffer to 25 meters.
# No operator match found for spill at index 677 even after expanding buffer to 25 meters.
# No operator match found for spill at index 678 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 14.0 meters for spill at index 679.
# Adding match: Flowline index 6596
# No operator match found for spill at index 680 even after expanding buffer to 25 meters.
# No operator match found for spill at index 681 even after expanding buffer to 25 meters.
# No operator match found for spill at index 682 even after expanding buffer to 25 meters.
# No operator match found for spill at index 683 even after expanding buffer to 25 meters.
# No operator match found for spill at index 684 even after expanding buffer to 25 meters.
# No operator match found for spill at index 685 even after expanding buffer to 25 meters.
# No operator match found for spill at index 686 even after expanding buffer to 25 meters.
# No operator match found for spill at index 687 even after expanding buffer to 25 meters.
# No operator match found for spill at index 688 even after expanding buffer to 25 meters.
# No operator match found for spill at index 689 even after expanding buffer to 25 meters.
# No operator match found for spill at index 690 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 25.0 meters for spill at index 691.
# Adding match: Flowline index 3952
# No operator match found for spill at index 692 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 0.5 meters for spill at index 693.
# Adding match: Flowline index 2634
# No operator match found for spill at index 694 even after expanding buffer to 25 meters.
# ...
# No operator match found for spill at index 942 even after expanding buffer to 25 meters.
# No operator match found for spill at index 943 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 9.0 meters for spill at index 944.
# Adding match: Flowline index 7719
# No operator match found for spill at index 945 even after expanding buffer to 25 meters.
# No operator match found for spill at index 946 even after expanding buffer to 25 meters.
# No operator match found for spill at index 947 even after expanding buffer to 25 meters.
# No operator match found for spill at index 948 even after expanding buffer to 25 meters.
# No operator match found for spill at index 949 even after expanding buffer to 25 meters.
# No operator match found for spill at index 950 even after expanding buffer to 25 meters.
# No operator match found for spill at index 951 even after expanding buffer to 25 meters.
# No operator match found for spill at index 952 even after expanding buffer to 25 meters.
# No operator match found for spill at index 953 even after expanding buffer to 25 meters.
# No operator match found for spill at index 954 even after expanding buffer to 25 meters.
# No operator match found for spill at index 955 even after expanding buffer to 25 meters.
# No operator match found for spill at index 956 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 3.0 meters for spill at index 957.
# Adding match: Flowline index 5309
# No operator match found for spill at index 958 even after expanding buffer to 25 meters.
# No operator match found for spill at index 959 even after expanding buffer to 25 meters.
# No operator match found for spill at index 960 even after expanding buffer to 25 meters.
# No operator match found for spill at index 961 even after expanding buffer to 25 meters.
# No operator match found for spill at index 962 even after expanding buffer to 25 meters.
# No operator match found for spill at index 963 even after expanding buffer to 25 meters.
# No operator match found for spill at index 964 even after expanding buffer to 25 meters.
# No operator match found for spill at index 965 even after expanding buffer to 25 meters.
# No operator match found for spill at index 966 even after expanding buffer to 25 meters.
# No operator match found for spill at index 967 even after expanding buffer to 25 meters.
# No operator match found for spill at index 968 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 1.5 meters for spill at index 969.
# Adding match: Flowline index 13076
# No operator match found for spill at index 970 even after expanding buffer to 25 meters.
# No operator match found for spill at index 971 even after expanding buffer to 25 meters.
# No operator match found for spill at index 972 even after expanding buffer to 25 meters.
# No operator match found for spill at index 973 even after expanding buffer to 25 meters.
# No operator match found for spill at index 974 even after expanding buffer to 25 meters.
# No operator match found for spill at index 975 even after expanding buffer to 25 meters.
# No operator match found for spill at index 976 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 1.0 meters for spill at index 977.
# Adding match: Flowline index 6578
# No operator match found for spill at index 978 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 2.5 meters for spill at index 979.
# Adding match: Flowline index 5410
# No operator match found for spill at index 980 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 0.5 meters for spill at index 981.
# Adding match: Flowline index 4395
# No operator match found for spill at index 982 even after expanding buffer to 25 meters.
# No operator match found for spill at index 983 even after expanding buffer to 25 meters.
# No operator match found for spill at index 984 even after expanding buffer to 25 meters.
# No operator match found for spill at index 985 even after expanding buffer to 25 meters.
# No operator match found for spill at index 986 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 0.5 meters for spill at index 987.
# Adding match: Flowline index 10873
# No operator match found for spill at index 988 even after expanding buffer to 25 meters.
# No operator match found for spill at index 989 even after expanding buffer to 25 meters.
# No operator match found for spill at index 990 even after expanding buffer to 25 meters.
# No operator match found for spill at index 991 even after expanding buffer to 25 meters.
# No operator match found for spill at index 992 even after expanding buffer to 25 meters.
# No operator match found for spill at index 993 even after expanding buffer to 25 meters.
# No operator match found for spill at index 994 even after expanding buffer to 25 meters.
# No operator match found for spill at index 995 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 17.0 meters for spill at index 996.
# Adding match: Flowline index 12140
# No operator match found for spill at index 997 even after expanding buffer to 25 meters.
# No operator match found for spill at index 998 even after expanding buffer to 25 meters.
# No operator match found for spill at index 999 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1000 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1001 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1002 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1003 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1004 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1005 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1006 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1007 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1008 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1009 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1010 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1011 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1012 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1013 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 5.0 meters for spill at index 1014.
# Adding match: Flowline index 4586
# No operator match found for spill at index 1015 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1016 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1017 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 2.0 meters for spill at index 1018.
# Adding match: Flowline index 11059
# No operator match found for spill at index 1019 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1020 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1021 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1022 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1023 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1024 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 12.5 meters for spill at index 1025.
# Adding match: Flowline index 12503
# No operator match found for spill at index 1026 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1027 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1028 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 5.0 meters for spill at index 1029.
# Adding match: Flowline index 12852
# No operator match found for spill at index 1030 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1031 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1032 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1033 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1034 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 3.0 meters for spill at index 1035.
# Adding match: Flowline index 7318
# No operator match found for spill at index 1036 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1037 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1038 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1039 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1040 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1041 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 1.0 meters for spill at index 1042.
# Adding match: Flowline index 4710
# No operator match found for spill at index 1043 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1044 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1045 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1046 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1047 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1048 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1049 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1050 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1051 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1052 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1053 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1054 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 25.0 meters for spill at index 1055.
# Adding match: Flowline index 12429
# No operator match found for spill at index 1056 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1057 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1058 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 3.0 meters for spill at index 1059.
# Adding match: Flowline index 4016
# No operator match found for spill at index 1060 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1061 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1062 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1063 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1064 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1065 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1066 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1067 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 22.5 meters for spill at index 1068.
# Adding match: Flowline index 4362
# No operator match found for spill at index 1069 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 3.0 meters for spill at index 1070.
# Adding match: Flowline index 5419
# No operator match found for spill at index 1071 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1072 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1073 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1074 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1075 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 15.5 meters for spill at index 1076.
# Adding match: Flowline index 12939
# No operator match found for spill at index 1077 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1078 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1079 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1080 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1081 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1082 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1083 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1084 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1085 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1086 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1087 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1088 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1089 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1090 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1091 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1092 even after expanding buffer to 25 meters.
# Operator match found at buffer distance 10.0 meters for spill at index 1093.
# Adding match: Flowline index 4938
# No operator match found for spill at index 1094 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1095 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1096 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1097 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1098 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1099 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1100 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1101 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1102 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1103 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1104 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1105 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1106 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1107 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1108 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1109 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1110 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1111 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1112 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1113 even after expanding buffer to 25 meters.
# No operator match found for spill at index 1114 even after expanding buffer to 25 meters.

# %%
# Create a GeoDataFrame of unmatched flowlines
unmatched_flowlines_gdf = matched_flowlines_gdf.drop(index=list(matched_flowline_indices))

print(f"Total flowlines: {len(matched_flowlines_gdf)}")
print(f"Matched flowlines: {len(matched_flowline_indices)}")
print(f"Matched spills: {len(matched_spills_gdf)}")
print(f"Unmatched flowlines: {len(unmatched_flowlines_gdf)}")
# Out:
# Total flowlines: 14611
# Matched flowlines: 89
# Matched spills: 109
# Unmatched flowlines: 14522

# %%
matched_spills_gdf.to_file("flowlines_with_spills.geojson", driver='GeoJSON')

# %%
matched_spills_gdf.shape
# Out:
# (109, 42)

# %%
unmatched_flowlines_gdf.to_file("flowlines_without_spills.geojson", driver='GeoJSON')
