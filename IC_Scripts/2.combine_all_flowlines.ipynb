# %% [markdown]
# This code combines the two different flowline datasets into one. One only had end points of an flowline and the other had the entire flowline. We combined them using a spatial join and asserted that the operator name is the same, with a max 50 meter buffer.

# %% [markdown]
# ## Setup

# %%
import os
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon, MultiLineString, LineString,MultiPolygon, MultiPoint
from shapely.ops import nearest_points
os.chdir('/Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/Data')
pd.options.display.max_columns = None
# Out:
# /var/folders/p3/gs65vvgs1wd90mnxb3q3hvy80000gp/T/ipykernel_3198/3583532370.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Load Data
flowlines_gdf = gpd.read_file('flowlines.geojson')
crudeoil_gdf = gpd.read_file('crudeoil_offlocation.geojson')

# %%
# Check size
print(flowlines_gdf.shape)
print(crudeoil_offlocation_gdf.shape)
# Out:
# (21942, 19)
# (259979, 8)

# %%
flowlines_gdf.head(2)
# Out:
#    LOCATION_ID  FLOWLINEID  STARTLOCATIONID FLOWLINEACTION ENTIRELINEREMOVED  \
# 0     331872.0    485633.0              NaN   Registration              None
# 1     470443.0    470446.0              NaN           None              None
#
#                                    ACTIONDESCRIPTION  \
# 0                                               None
# 1  The flowline serving the Emerson 3-29J (05-123...
#
#                  RECEIVE_DATE  OPERATOR_NUM  \
# 0  2023-10-30T08:10:52.119999         10673
# 1  2023-10-24T08:33:49.223000         10633
#
#                                         COMPANY_NAME           LOCATIONTYPE  \
# 0  GADECO LLC                                    ...              Well Site
# 1  CRESTONE PEAK RESOURCES OPERATING LLC         ...  Production Facilities
#
#       ENDLAT     ENDLONG   STARTLAT  STARTLONG  PIPEMATERIAL  \
# 0        NaN         NaN        NaN        NaN          HDPE
# 1  40.109444 -104.909686  40.105743 -104.90986  Carbon Steel
#
#     BEDDINGMATERIAL TYPEOFFLUIDTRANS  MAXOPPRESSURE  \
# 0  Native Materials   Produced Water            NaN
# 1  Native Materials       Multiphase          325.0
#
#                                             geometry
# 0                                               None
# 1  LINESTRING (507682.442 4439497.658, 507696.855...

# %%
print(flowlines_gdf.geometry.iloc[1])
# Out:
# LINESTRING (507682.4421174659 4439497.657752302, 507696.85463215865 4439908.45533576)

# %%
crudeoil_offlocation_gdf.head(5)
# Out:
#                           Operator       Fluid      Material  Diam_in  \
# 0  EVERGREEN NATURAL RESOURCES LLC         Gas         polly      4.0
# 1                 NOBLE ENERGY INC  Multiphase  Carbon Steel      3.0
# 2                   PDC ENERGY INC        None          None      NaN
# 3                 NOBLE ENERGY INC         Gas  Carbon Steel      3.0
# 4                 NOBLE ENERGY INC  Multiphase  Carbon Steel      3.0
#
#                         Status  Length_ft  SHAPE_Length  \
# 0                       Active    2277.71    693.972162
# 1                    Abandoned     651.58    198.525215
# 2  Partial Removed see comment    1902.59    579.687012
# 3                       Active     205.62     62.649840
# 4                       Active    2069.90    630.658768
#
#                                             geometry
# 0  MULTILINESTRING ((524642.670 4117088.796, 5246...
# 1  MULTILINESTRING ((527997.281 4463899.920, 5281...
# 2  MULTILINESTRING ((537519.211 4475984.687, 5375...
# 3  MULTILINESTRING ((544793.476 4489156.672, 5447...
# 4  MULTILINESTRING ((526448.455 4461830.702, 5258...

# %%
# from shapely import GeometryCollection, LineString, Point
import shapely

# %%
shapely.get_num_coordinates(crudeoil_offlocation_gdf.geometry)
# Out:
# 0         46
# 1          2
# 2         26
# 3          2
# 4          2
#           ..
# 259974     5
# 259975    23
# 259976     2
# 259977    27
# 259978    15
# Name: geometry, Length: 259979, dtype: int32

# %%
print(crudeoil_offlocation_gdf.geometry.iloc[1])
# Out:
# MULTILINESTRING ((527997.2812999999 4463899.920399999, 528172.7903000005 4463992.704299999))

# %%
# Check if CRS is the same for both files
if flowlines_gdf.crs != crudeoil_offlocation_gdf.crs:
    flowlines_gdf = flowlines_gdf.to_crs(crudeoil_offlocation_gdf.crs)

# %%
drop_crudeoil_offlocation_gdf = crudeoil_offlocation_gdf.dropna()
drop_crudeoil_offlocation_gdf.shape
# Out:
# (138943, 8)

# %% [markdown]
# ## Match with Buffer
# find spatial match with/ buffer, update geometry

# %%
from shapely.geometry import LineString

line1 = LineString([(0, 0), (1, 1)])
line2 = LineString([(0.5, 0.5), (2, 2)])
line3 = LineString([(1, 1), (1, 2)])

print(line1.intersects(line2))  # True, because both lines share a common point (1,1)
print(line1.intersects(line3))  # True, because line1 and line3 intersect at point (1,1)
print(line2.intersects(line3))  # True, because line2 and line3 intersect at point (1,1)
# Out:
# True
# True
# True

# %%
import geopandas as gpd

# Load your datasets if not already loaded
# flowlines_gdf = gpd.read_file("path_to_flowlines_dataset.shp")
# crudeoil_gdf = gpd.read_file("path_to_crudeoil_dataset.shp")

# Ensure both datasets use the same coordinate reference system
if flowlines_gdf.crs != crudeoil_gdf.crs:
    crudeoil_gdf = crudeoil_gdf.to_crs(flowlines_gdf.crs)

def replace_geometry_with_closest_match(line, index):
    if line.geometry is None:
        print(f"Index {index}: No geometry to process.")
        return None  # Return None if there's no geometry to process

    initial_buffer = 5
    step = 1
    max_buffer = 25
    buffer_size = initial_buffer

    while True:
        # Create buffer around the linestring
        buffered_line = line.geometry.buffer(buffer_size)

        # Find intersections with the same operator
        potential_matches = crudeoil_gdf[crudeoil_gdf.intersects(buffered_line) & (crudeoil_gdf['Operator'] == line['COMPANY_NAME'])]

        # Debugging logs
        print(f"Index {index}: Buffer size {buffer_size}, Matches found {len(potential_matches)}")

        if len(potential_matches) == 1:
            print(f"Index {index}: Exactly one match found, operator name matches.")
            # If exactly one match, replace the geometry
            return potential_matches.iloc[0].geometry
        elif len(potential_matches) > 1:
            print(f"Index {index}: More than one match found, decreasing buffer size.")
            # If more than one match, decrease the buffer
            buffer_size -= step
        else:
            print(f"Index {index}: No matches found, increasing buffer size.")
            # If no matches, increase the buffer
            buffer_size += step * 5
            if buffer_size > max_buffer:
                print(f"Index {index}: Maximum buffer size exceeded, no suitable match found.")
                # Exit loop if maximum buffer is exceeded
                return line.geometry  # Return original geometry if no suitable match found

        if buffer_size < 0:
            print(f"Index {index}: Buffer size below zero, returning original geometry.")
            # Ensure buffer size doesn't go below zero
            return line.geometry  # Return original geometry if buffer size underflows

# Apply the function to update the geometry of each feature in flowlines dataset
for idx, line in flowlines_gdf.iterrows():
    flowlines_gdf.at[idx, 'geometry'] = replace_geometry_with_closest_match(line, idx)

# Save the updated GeoDataFrame
flowlines_gdf.to_file("path_to_updated_flowlines_dataset.shp")
# Out:
# Index 0: No geometry to process.
# Index 1: Buffer size 5, Matches found 0
# Index 1: No matches found, increasing buffer size.
# Index 1: Buffer size 10, Matches found 0
# Index 1: No matches found, increasing buffer size.
# Index 1: Buffer size 15, Matches found 0
# Index 1: No matches found, increasing buffer size.
# Index 1: Buffer size 20, Matches found 0
# Index 1: No matches found, increasing buffer size.
# Index 1: Buffer size 25, Matches found 0
# Index 1: No matches found, increasing buffer size.
# Index 1: Maximum buffer size exceeded, no suitable match found.
# Index 2: Buffer size 5, Matches found 0
# Index 2: No matches found, increasing buffer size.
# Index 2: Buffer size 10, Matches found 0
# Index 2: No matches found, increasing buffer size.
# Index 2: Buffer size 15, Matches found 0
# Index 2: No matches found, increasing buffer size.
# Index 2: Buffer size 20, Matches found 0
# Index 2: No matches found, increasing buffer size.
# Index 2: Buffer size 25, Matches found 0
# Index 2: No matches found, increasing buffer size.
# Index 2: Maximum buffer size exceeded, no suitable match found.
# Index 3: Buffer size 5, Matches found 0
# Index 3: No matches found, increasing buffer size.
# Index 3: Buffer size 10, Matches found 0
# Index 3: No matches found, increasing buffer size.
# Index 3: Buffer size 15, Matches found 0
# Index 3: No matches found, increasing buffer size.
# Index 3: Buffer size 20, Matches found 0
# Index 3: No matches found, increasing buffer size.
# Index 3: Buffer size 25, Matches found 0
# Index 3: No matches found, increasing buffer size.
# Index 3: Maximum buffer size exceeded, no suitable match found.
# Index 4: Buffer size 5, Matches found 0
# Index 4: No matches found, increasing buffer size.
# Index 4: Buffer size 10, Matches found 0
# Index 4: No matches found, increasing buffer size.
# Index 4: Buffer size 15, Matches found 0
# Index 4: No matches found, increasing buffer size.
# Index 4: Buffer size 20, Matches found 0
# Index 4: No matches found, increasing buffer size.
# Index 4: Buffer size 25, Matches found 0
# Index 4: No matches found, increasing buffer size.
# Index 4: Maximum buffer size exceeded, no suitable match found.
# Index 5: Buffer size 5, Matches found 0
# Index 5: No matches found, increasing buffer size.
# Index 5: Buffer size 10, Matches found 0
# Index 5: No matches found, increasing buffer size.
# Index 5: Buffer size 15, Matches found 0
# Index 5: No matches found, increasing buffer size.
# Index 5: Buffer size 20, Matches found 0
# Index 5: No matches found, increasing buffer size.
# Index 5: Buffer size 25, Matches found 0
# Index 5: No matches found, increasing buffer size.
# Index 5: Maximum buffer size exceeded, no suitable match found.
# Index 6: Buffer size 5, Matches found 0
# Index 6: No matches found, increasing buffer size.
# Index 6: Buffer size 10, Matches found 0
# Index 6: No matches found, increasing buffer size.
# Index 6: Buffer size 15, Matches found 0
# Index 6: No matches found, increasing buffer size.
# Index 6: Buffer size 20, Matches found 0
# Index 6: No matches found, increasing buffer size.
# Index 6: Buffer size 25, Matches found 0
# Index 6: No matches found, increasing buffer size.
# Index 6: Maximum buffer size exceeded, no suitable match found.
# Index 7: Buffer size 5, Matches found 0
# Index 7: No matches found, increasing buffer size.
# Index 7: Buffer size 10, Matches found 0
# Index 7: No matches found, increasing buffer size.
# Index 7: Buffer size 15, Matches found 0
# Index 7: No matches found, increasing buffer size.
# Index 7: Buffer size 20, Matches found 0
# Index 7: No matches found, increasing buffer size.
# Index 7: Buffer size 25, Matches found 0
# Index 7: No matches found, increasing buffer size.
# Index 7: Maximum buffer size exceeded, no suitable match found.
# Index 8: Buffer size 5, Matches found 0
# Index 8: No matches found, increasing buffer size.
# Index 8: Buffer size 10, Matches found 0
# Index 8: No matches found, increasing buffer size.
# Index 8: Buffer size 15, Matches found 0
# Index 8: No matches found, increasing buffer size.
# Index 8: Buffer size 20, Matches found 0
# Index 8: No matches found, increasing buffer size.
# Index 8: Buffer size 25, Matches found 0
# Index 8: No matches found, increasing buffer size.
# Index 8: Maximum buffer size exceeded, no suitable match found.
# Index 9: Buffer size 5, Matches found 0
# Index 9: No matches found, increasing buffer size.
# Index 9: Buffer size 10, Matches found 0
# Index 9: No matches found, increasing buffer size.
# Index 9: Buffer size 15, Matches found 0
# Index 9: No matches found, increasing buffer size.
# Index 9: Buffer size 20, Matches found 0
# Index 9: No matches found, increasing buffer size.
# Index 9: Buffer size 25, Matches found 0
# Index 9: No matches found, increasing buffer size.
# Index 9: Maximum buffer size exceeded, no suitable match found.
# Index 10: Buffer size 5, Matches found 0
# Index 10: No matches found, increasing buffer size.
# Index 10: Buffer size 10, Matches found 0
# Index 10: No matches found, increasing buffer size.
# Index 10: Buffer size 15, Matches found 0
# Index 10: No matches found, increasing buffer size.
# Index 10: Buffer size 20, Matches found 0
# Index 10: No matches found, increasing buffer size.
# Index 10: Buffer size 25, Matches found 0
# Index 10: No matches found, increasing buffer size.
# Index 10: Maximum buffer size exceeded, no suitable match found.
# Index 11: Buffer size 5, Matches found 0
# Index 11: No matches found, increasing buffer size.
# Index 11: Buffer size 10, Matches found 0
# Index 11: No matches found, increasing buffer size.
# Index 11: Buffer size 15, Matches found 0
# Index 11: No matches found, increasing buffer size.
# Index 11: Buffer size 20, Matches found 0
# Index 11: No matches found, increasing buffer size.
# Index 11: Buffer size 25, Matches found 0
# Index 11: No matches found, increasing buffer size.
# Index 11: Maximum buffer size exceeded, no suitable match found.
# Index 12: Buffer size 5, Matches found 0
# Index 12: No matches found, increasing buffer size.
# Index 12: Buffer size 10, Matches found 0
# Index 12: No matches found, increasing buffer size.
# Index 12: Buffer size 15, Matches found 0
# Index 12: No matches found, increasing buffer size.
# Index 12: Buffer size 20, Matches found 0
# Index 12: No matches found, increasing buffer size.
# Index 12: Buffer size 25, Matches found 0
# Index 12: No matches found, increasing buffer size.
# Index 12: Maximum buffer size exceeded, no suitable match found.
# Index 13: Buffer size 5, Matches found 0
# Index 13: No matches found, increasing buffer size.
# Index 13: Buffer size 10, Matches found 0
# Index 13: No matches found, increasing buffer size.
# Index 13: Buffer size 15, Matches found 0
# Index 13: No matches found, increasing buffer size.
# Index 13: Buffer size 20, Matches found 0
# Index 13: No matches found, increasing buffer size.
# Index 13: Buffer size 25, Matches found 0
# Index 13: No matches found, increasing buffer size.
# Index 13: Maximum buffer size exceeded, no suitable match found.
# Index 14: Buffer size 5, Matches found 0
# Index 14: No matches found, increasing buffer size.
# Index 14: Buffer size 10, Matches found 0
# Index 14: No matches found, increasing buffer size.
# Index 14: Buffer size 15, Matches found 0
# Index 14: No matches found, increasing buffer size.
# Index 14: Buffer size 20, Matches found 0
# Index 14: No matches found, increasing buffer size.
# Index 14: Buffer size 25, Matches found 0
# Index 14: No matches found, increasing buffer size.
# Index 14: Maximum buffer size exceeded, no suitable match found.
# Index 15: Buffer size 5, Matches found 0
# Index 15: No matches found, increasing buffer size.
# Index 15: Buffer size 10, Matches found 0
# Index 15: No matches found, increasing buffer size.
# Index 15: Buffer size 15, Matches found 0
# Index 15: No matches found, increasing buffer size.
# Index 15: Buffer size 20, Matches found 0
# Index 15: No matches found, increasing buffer size.
# Index 15: Buffer size 25, Matches found 0
# Index 15: No matches found, increasing buffer size.
# Index 15: Maximum buffer size exceeded, no suitable match found.
# Index 16: Buffer size 5, Matches found 0
# Index 16: No matches found, increasing buffer size.
# Index 16: Buffer size 10, Matches found 0
# Index 16: No matches found, increasing buffer size.
# Index 16: Buffer size 15, Matches found 0
# Index 16: No matches found, increasing buffer size.
# Index 16: Buffer size 20, Matches found 0
# Index 16: No matches found, increasing buffer size.
# Index 16: Buffer size 25, Matches found 0
# Index 16: No matches found, increasing buffer size.
# Index 16: Maximum buffer size exceeded, no suitable match found.
# Index 17: Buffer size 5, Matches found 0
# Index 17: No matches found, increasing buffer size.
# Index 17: Buffer size 10, Matches found 0
# Index 17: No matches found, increasing buffer size.
# Index 17: Buffer size 15, Matches found 0
# Index 17: No matches found, increasing buffer size.
# Index 17: Buffer size 20, Matches found 0
# Index 17: No matches found, increasing buffer size.
# Index 17: Buffer size 25, Matches found 0
# Index 17: No matches found, increasing buffer size.
# Index 17: Maximum buffer size exceeded, no suitable match found.
# Index 18: Buffer size 5, Matches found 0
# Index 18: No matches found, increasing buffer size.
# Index 18: Buffer size 10, Matches found 0
# Index 18: No matches found, increasing buffer size.
# Index 18: Buffer size 15, Matches found 0
# Index 18: No matches found, increasing buffer size.
# Index 18: Buffer size 20, Matches found 0
# Index 18: No matches found, increasing buffer size.
# Index 18: Buffer size 25, Matches found 0
# Index 18: No matches found, increasing buffer size.
# Index 18: Maximum buffer size exceeded, no suitable match found.
# Index 19: Buffer size 5, Matches found 0
# Index 19: No matches found, increasing buffer size.
# Index 19: Buffer size 10, Matches found 0
# Index 19: No matches found, increasing buffer size.
# Index 19: Buffer size 15, Matches found 0
# Index 19: No matches found, increasing buffer size.
# Index 19: Buffer size 20, Matches found 0
# Index 19: No matches found, increasing buffer size.
# Index 19: Buffer size 25, Matches found 0
# Index 19: No matches found, increasing buffer size.
# Index 19: Maximum buffer size exceeded, no suitable match found.
# Index 20: Buffer size 5, Matches found 0
# Index 20: No matches found, increasing buffer size.
# Index 20: Buffer size 10, Matches found 0
# Index 20: No matches found, increasing buffer size.
# Index 20: Buffer size 15, Matches found 0
# Index 20: No matches found, increasing buffer size.
# Index 20: Buffer size 20, Matches found 0
# Index 20: No matches found, increasing buffer size.
# Index 20: Buffer size 25, Matches found 0
# Index 20: No matches found, increasing buffer size.
# Index 20: Maximum buffer size exceeded, no suitable match found.
# Index 21: Buffer size 5, Matches found 0
# Index 21: No matches found, increasing buffer size.
# Index 21: Buffer size 10, Matches found 0
# Index 21: No matches found, increasing buffer size.
# Index 21: Buffer size 15, Matches found 0
# Index 21: No matches found, increasing buffer size.
# Index 21: Buffer size 20, Matches found 0
# Index 21: No matches found, increasing buffer size.
# Index 21: Buffer size 25, Matches found 0
# Index 21: No matches found, increasing buffer size.
# Index 21: Maximum buffer size exceeded, no suitable match found.
# Index 22: Buffer size 5, Matches found 0
# Index 22: No matches found, increasing buffer size.
# Index 22: Buffer size 10, Matches found 0
# Index 22: No matches found, increasing buffer size.
# Index 22: Buffer size 15, Matches found 0
# Index 22: No matches found, increasing buffer size.
# Index 22: Buffer size 20, Matches found 0
# Index 22: No matches found, increasing buffer size.
# Index 22: Buffer size 25, Matches found 0
# Index 22: No matches found, increasing buffer size.
# Index 22: Maximum buffer size exceeded, no suitable match found.
# Index 23: Buffer size 5, Matches found 0
# Index 23: No matches found, increasing buffer size.
# Index 23: Buffer size 10, Matches found 0
# Index 23: No matches found, increasing buffer size.
# Index 23: Buffer size 15, Matches found 0
# Index 23: No matches found, increasing buffer size.
# Index 23: Buffer size 20, Matches found 0
# Index 23: No matches found, increasing buffer size.
# Index 23: Buffer size 25, Matches found 0
# Index 23: No matches found, increasing buffer size.
# Index 23: Maximum buffer size exceeded, no suitable match found.
# Index 24: Buffer size 5, Matches found 0
# Index 24: No matches found, increasing buffer size.
# Index 24: Buffer size 10, Matches found 0
# Index 24: No matches found, increasing buffer size.
# Index 24: Buffer size 15, Matches found 0
# Index 24: No matches found, increasing buffer size.
# Index 24: Buffer size 20, Matches found 0
# Index 24: No matches found, increasing buffer size.
# Index 24: Buffer size 25, Matches found 0
# Index 24: No matches found, increasing buffer size.
# Index 24: Maximum buffer size exceeded, no suitable match found.
# Index 25: No geometry to process.
# Index 26: Buffer size 5, Matches found 0
# Index 26: No matches found, increasing buffer size.
# Index 26: Buffer size 10, Matches found 0
# Index 26: No matches found, increasing buffer size.
# Index 26: Buffer size 15, Matches found 0
# Index 26: No matches found, increasing buffer size.
# Index 26: Buffer size 20, Matches found 0
# Index 26: No matches found, increasing buffer size.
# Index 26: Buffer size 25, Matches found 0
# Index 26: No matches found, increasing buffer size.
# Index 26: Maximum buffer size exceeded, no suitable match found.
# Index 27: Buffer size 5, Matches found 0
# Index 27: No matches found, increasing buffer size.
# Index 27: Buffer size 10, Matches found 0
# Index 27: No matches found, increasing buffer size.
# Index 27: Buffer size 15, Matches found 0
# Index 27: No matches found, increasing buffer size.
# Index 27: Buffer size 20, Matches found 0
# Index 27: No matches found, increasing buffer size.
# Index 27: Buffer size 25, Matches found 0
# Index 27: No matches found, increasing buffer size.
# Index 27: Maximum buffer size exceeded, no suitable match found.
# Index 28: Buffer size 5, Matches found 0
# Index 28: No matches found, increasing buffer size.
# Index 28: Buffer size 10, Matches found 0
# Index 28: No matches found, increasing buffer size.
# Index 28: Buffer size 15, Matches found 0
# Index 28: No matches found, increasing buffer size.
# Index 28: Buffer size 20, Matches found 0
# Index 28: No matches found, increasing buffer size.
# Index 28: Buffer size 25, Matches found 0
# Index 28: No matches found, increasing buffer size.
# Index 28: Maximum buffer size exceeded, no suitable match found.
# Index 29: Buffer size 5, Matches found 0
# Index 29: No matches found, increasing buffer size.
# Index 29: Buffer size 10, Matches found 0
# Index 29: No matches found, increasing buffer size.
# Index 29: Buffer size 15, Matches found 0
# Index 29: No matches found, increasing buffer size.
# Index 29: Buffer size 20, Matches found 0
# Index 29: No matches found, increasing buffer size.
# Index 29: Buffer size 25, Matches found 0
# Index 29: No matches found, increasing buffer size.
# Index 29: Maximum buffer size exceeded, no suitable match found.
# Index 30: Buffer size 5, Matches found 0
# Index 30: No matches found, increasing buffer size.
# Index 30: Buffer size 10, Matches found 0
# Index 30: No matches found, increasing buffer size.
# Index 30: Buffer size 15, Matches found 0
# Index 30: No matches found, increasing buffer size.
# Index 30: Buffer size 20, Matches found 0
# Index 30: No matches found, increasing buffer size.
# Index 30: Buffer size 25, Matches found 0
# Index 30: No matches found, increasing buffer size.
# Index 30: Maximum buffer size exceeded, no suitable match found.
# Index 31: Buffer size 5, Matches found 0
# Index 31: No matches found, increasing buffer size.
# Index 31: Buffer size 10, Matches found 0
# Index 31: No matches found, increasing buffer size.
# Index 31: Buffer size 15, Matches found 0
# Index 31: No matches found, increasing buffer size.
# Index 31: Buffer size 20, Matches found 0
# Index 31: No matches found, increasing buffer size.
# Index 31: Buffer size 25, Matches found 0
# Index 31: No matches found, increasing buffer size.
# Index 31: Maximum buffer size exceeded, no suitable match found.
# Index 32: Buffer size 5, Matches found 0
# Index 32: No matches found, increasing buffer size.
# Index 32: Buffer size 10, Matches found 0
# Index 32: No matches found, increasing buffer size.
# Index 32: Buffer size 15, Matches found 0
# Index 32: No matches found, increasing buffer size.
# Index 32: Buffer size 20, Matches found 0
# Index 32: No matches found, increasing buffer size.
# Index 32: Buffer size 25, Matches found 0
# Index 32: No matches found, increasing buffer size.
# Index 32: Maximum buffer size exceeded, no suitable match found.
# Index 33: Buffer size 5, Matches found 0
# Index 33: No matches found, increasing buffer size.
# Index 33: Buffer size 10, Matches found 0
# Index 33: No matches found, increasing buffer size.
# Index 33: Buffer size 15, Matches found 0
# Index 33: No matches found, increasing buffer size.
# Index 33: Buffer size 20, Matches found 0
# Index 33: No matches found, increasing buffer size.
# Index 33: Buffer size 25, Matches found 0
# Index 33: No matches found, increasing buffer size.
# Index 33: Maximum buffer size exceeded, no suitable match found.
# Index 34: Buffer size 5, Matches found 0
# Index 34: No matches found, increasing buffer size.
# Index 34: Buffer size 10, Matches found 0
# Index 34: No matches found, increasing buffer size.
# Index 34: Buffer size 15, Matches found 0
# Index 34: No matches found, increasing buffer size.
# Index 34: Buffer size 20, Matches found 0
# Index 34: No matches found, increasing buffer size.
# Index 34: Buffer size 25, Matches found 0
# Index 34: No matches found, increasing buffer size.
# Index 34: Maximum buffer size exceeded, no suitable match found.
# Index 35: Buffer size 5, Matches found 0
# Index 35: No matches found, increasing buffer size.
# Index 35: Buffer size 10, Matches found 0
# Index 35: No matches found, increasing buffer size.
# Index 35: Buffer size 15, Matches found 0
# Index 35: No matches found, increasing buffer size.
# Index 35: Buffer size 20, Matches found 0
# Index 35: No matches found, increasing buffer size.
# Index 35: Buffer size 25, Matches found 0
# Index 35: No matches found, increasing buffer size.
# Index 35: Maximum buffer size exceeded, no suitable match found.
# Index 36: Buffer size 5, Matches found 0
# Index 36: No matches found, increasing buffer size.
# Index 36: Buffer size 10, Matches found 0
# Index 36: No matches found, increasing buffer size.
# Index 36: Buffer size 15, Matches found 0
# Index 36: No matches found, increasing buffer size.
# Index 36: Buffer size 20, Matches found 0
# Index 36: No matches found, increasing buffer size.
# Index 36: Buffer size 25, Matches found 0
# Index 36: No matches found, increasing buffer size.
# Index 36: Maximum buffer size exceeded, no suitable match found.
# Index 37: Buffer size 5, Matches found 0
# Index 37: No matches found, increasing buffer size.
# Index 37: Buffer size 10, Matches found 0
# Index 37: No matches found, increasing buffer size.
# Index 37: Buffer size 15, Matches found 0
# Index 37: No matches found, increasing buffer size.
# Index 37: Buffer size 20, Matches found 0
# Index 37: No matches found, increasing buffer size.
# Index 37: Buffer size 25, Matches found 0
# Index 37: No matches found, increasing buffer size.
# Index 37: Maximum buffer size exceeded, no suitable match found.
# Index 38: Buffer size 5, Matches found 0
# Index 38: No matches found, increasing buffer size.
# Index 38: Buffer size 10, Matches found 0
# Index 38: No matches found, increasing buffer size.
# Index 38: Buffer size 15, Matches found 0
# Index 38: No matches found, increasing buffer size.
# Index 38: Buffer size 20, Matches found 0
# Index 38: No matches found, increasing buffer size.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 55
#      53 # Apply the function to update the geometry of each feature in flowlines dataset
#      54 for idx, line in flowlines_gdf.iterrows():
# ---> 55     flowlines_gdf.at[idx, 'geometry'] = replace_geometry_with_closest_match(line, idx)
#      57 # Save the updated GeoDataFrame
#      58 flowlines_gdf.to_file("path_to_updated_flowlines_dataset.shp")
#
# Cell In[45], line 26, in replace_geometry_with_closest_match(line, index)
#      23 buffered_line = line.geometry.buffer(buffer_size)
#      25 # Find intersections with the same operator
# ---> 26 potential_matches = crudeoil_gdf[crudeoil_gdf.intersects(buffered_line) & (crudeoil_gdf['Operator'] == line['COMPANY_NAME'])]
#      28 # Debugging logs
#      29 print(f"Index {index}: Buffer size {buffer_size}, Matches found {len(potential_matches)}")
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/geopandas/base.py:1917, in GeoPandasBase.intersects(self, other, align)
#    1808 def intersects(self, other, align=True):
#    1809     """Returns a ``Series`` of ``dtype('bool')`` with value ``True`` for
#    1810     each aligned geometry that intersects `other`.
#    1811
#    (...)
#    1915     GeoSeries.intersection
#    1916     """
# -> 1917     return _binary_op("intersects", self, other, align)
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/geopandas/base.py:63, in _binary_op(op, this, other, align, *args, **kwargs)
#      60 def _binary_op(op, this, other, align, *args, **kwargs):
#      61     # type: (str, GeoSeries, GeoSeries, args/kwargs) -> Series[bool/float]
#      62     """Binary operation on GeoSeries objects that returns a Series"""
# ---> 63     data, index = _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      64     return Series(data, index=index)
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/geopandas/base.py:47, in _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      44 else:
#      45     raise TypeError(type(this), type(other))
# ---> 47 data = getattr(a_this, op)(other, *args, **kwargs)
#      48 return data, this.index
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/geopandas/array.py:632, in GeometryArray.intersects(self, other)
#     631 def intersects(self, other):
# --> 632     return self._binary_method("intersects", self, other)
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/geopandas/array.py:611, in GeometryArray._binary_method(op, left, right, **kwargs)
#     608         _crs_mismatch_warn(left, right, stacklevel=7)
#     609     right = right._data
# --> 611 return getattr(vectorized, op)(left._data, right, **kwargs)
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/geopandas/_vectorized.py:864, in intersects(data, other)
#     862 def intersects(data, other):
#     863     if compat.USE_SHAPELY_20:
# --> 864         return shapely.intersects(data, other)
#     865     elif compat.USE_PYGEOS:
#     866         return _binary_method("intersects", data, other)
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/shapely/decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/shapely/predicates.py:778, in intersects(a, b, **kwargs)
#     747 @multithreading_enabled
#     748 def intersects(a, b, **kwargs):
#     749     """Returns True if A and B share any portion of space.
#     750
#     751     Intersects implies that overlaps, touches and within are True.
#    (...)
#     776     False
#     777     """
# --> 778     return lib.intersects(a, b, **kwargs)
#
# KeyboardInterrupt:

# %%
import geopandas as gpd
from shapely.geometry import MultiLineString

# Ensure both datasets use the same coordinate reference system
if flowlines_gdf.crs != drop_crudeoil_offlocation_gdf.crs:
    drop_crudeoil_offlocation_gdf = drop_crudeoil_offlocation_gdf.to_crs(flowlines_gdf.crs)

def find_closest_match(line, initial_buffer=5, step=1, max_buffer=25):
    buffer_size = initial_buffer
    matched = False
    closest_match = None

    while not matched:
        # Create buffer around the linestring
        buffered_line = line.geometry.buffer(buffer_size)

        # Find intersections with the same operator
        potential_matches = drop_crudeoil_offlocation_gdf[drop_crudeoil_offlocation_gdf.intersects(buffered_line) & (drop_crudeoil_offlocation_gdf['operator'] == line['operator'])]

        if len(potential_matches) == 1:
            matched = True
            closest_match = potential_matches
        elif len(potential_matches) > 1:
            # If more than one match, decrease the buffer
            buffer_size -= step
        else:
            # If no matches, increase the buffer
            buffer_size += step * 5
            if buffer_size > max_buffer:
                # Stop if maximum buffer is exceeded
                break

    return closest_match

# Apply the function to each feature in flowlines dataset
flowlines_gdf['closest_match'] = flowlines_gdf.apply(find_closest_match, axis=1)

# You might want to inspect or export the resulting data
print(flowlines_gdf[['closest_match']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 36
#      33     return closest_match
#      35 # Apply the function to each feature in flowlines dataset
# ---> 36 flowlines_gdf['closest_match'] = flowlines_gdf.apply(find_closest_match, axis=1)
#      38 # You might want to inspect or export the resulting data
#      39 print(flowlines_gdf[['closest_match']])
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/geopandas/geodataframe.py:1568, in GeoDataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    1566 @doc(pd.DataFrame)
#    1567 def apply(self, func, axis=0, raw=False, result_type=None, args=(), **kwargs):
# -> 1568     result = super().apply(
#    1569         func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1570     )
#    1571     # pandas <1.4 re-attach last geometry col if lost
#    1572     if (
#    1573         not compat.PANDAS_GE_14
#    1574         and isinstance(result, GeoDataFrame)
#    1575         and result._geometry_column_name is None
#    1576     ):
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/pandas/core/frame.py:10347, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10333 from pandas.core.apply import frame_apply
#   10335 op = frame_apply(
#   10336     self,
#   10337     func=func,
#    (...)
#   10345     kwargs=kwargs,
#   10346 )
# > 10347 return op.apply().__finalize__(self, method="apply")
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[33], line 15, in find_closest_match(line, initial_buffer, step, max_buffer)
#      11 closest_match = None
#      13 while not matched:
#      14     # Create buffer around the linestring
# ---> 15     buffered_line = line.geometry.buffer(buffer_size)
#      17     # Find intersections with the same operator
#      18     potential_matches = drop_crudeoil_offlocation_gdf[drop_crudeoil_offlocation_gdf.intersects(buffered_line) & (drop_crudeoil_offlocation_gdf['operator'] == line['operator'])]
#
# AttributeError: 'NoneType' object has no attribute 'buffer'

# %%
# Initialize an empty list to store matched data
matched_flowlines = []

max_buffer_distance = 49.5  # Maximum buffer distance in meters
initial_buffer_distance = 0  # Initial buffer distance
matches_found = 0  # Counter for matches found

for index, flowline in flowlines_gdf.iterrows():
    # Check if two matches are already found
    # if matches_found == 2:
        # break
    
    # Check for missing geometry and skip if necessary
    if flowline.geometry is None:
        print(f"Missing geometry for flowline at index {index}. Skipping...")
        continue

    # Extract the two end points of the flowline
    coords = list(flowline.geometry.coords)
    flp_start, flp_end = Point(coords[0]), Point(coords[-1])

    buffer_distance = initial_buffer_distance
    match_found = False

    while not match_found and buffer_distance <= max_buffer_distance:
        # Buffer the flowline geometry
        buffered_flowline = flowline.geometry.buffer(buffer_distance)
        
        # Iterate over the segments of the drop_crudeoil_offlocation_gdf multistring
        for _, crudeoil_line in drop_crudeoil_offlocation_gdf.iterrows():
            # Check if the buffer intersects with the crude oil geometry
            if buffered_flowline.intersects(crudeoil_line.geometry):
                # Find the intersection points
                intersection = buffered_flowline.intersection(crudeoil_line.geometry)
                
                # Ensure the intersection is a LineString
                if isinstance(intersection, LineString):
                    intersection_start, intersection_end = intersection.coords[0], intersection.coords[-1]
                    
                    # Check if the company names match
                    if flowline['COMPANY_NAME'].strip().lower() == crudeoil_line['Operator'].strip().lower():
                        print(f"Company match found at buffer distance {buffer_distance} meters for flowline at index {index}.")
                        match_found = True
                        matches_found += 1  # Increment the counter for matches found

                        # Create a new GeoDataFrame with the updated flowline
                        updated_flowline = flowline.copy()
                        updated_line = LineString([intersection_start, intersection_end])
                        updated_flowline.geometry = updated_line

                        # Append the updated flowline to the list
                        matched_flowlines.append(updated_flowline)
                        break

        if match_found:
            break
        else:
            buffer_distance += 0.5  # Increase buffer by 0.5 meters if no match found

    if not match_found:
        print(f"No company match found for flowline at index {index} even after expanding buffer to {buffer_distance} meters.")

# Convert the list of matched flowlines to a GeoDataFrame
matched_flowlines_gdf = gpd.GeoDataFrame(matched_flowlines, columns=flowlines_gdf.columns, crs=flowlines_gdf.crs)
# Out:
# Missing geometry for flowline at index 0. Skipping...
# Company match found at buffer distance 0.5 meters for flowline at index 1.
# Company match found at buffer distance 1.5 meters for flowline at index 2.
# Company match found at buffer distance 7.0 meters for flowline at index 3.
# Company match found at buffer distance 3.5 meters for flowline at index 4.
# Company match found at buffer distance 6.5 meters for flowline at index 5.
# Company match found at buffer distance 0.5 meters for flowline at index 6.
# Company match found at buffer distance 6.5 meters for flowline at index 7.
# Company match found at buffer distance 0.5 meters for flowline at index 8.
# Company match found at buffer distance 0.5 meters for flowline at index 9.
# No company match found for flowline at index 10 even after expanding buffer to 50.0 meters.
# No company match found for flowline at index 11 even after expanding buffer to 50.0 meters.
# No company match found for flowline at index 12 even after expanding buffer to 50.0 meters.
# No company match found for flowline at index 13 even after expanding buffer to 50.0 meters.
# No company match found for flowline at index 14 even after expanding buffer to 50.0 meters.
# No company match found for flowline at index 15 even after expanding buffer to 50.0 meters.
# Company match found at buffer distance 0.5 meters for flowline at index 16.
# Company match found at buffer distance 1.0 meters for flowline at index 17.
# Company match found at buffer distance 0.5 meters for flowline at index 18.
# Company match found at buffer distance 1.0 meters for flowline at index 19.
# Company match found at buffer distance 0.5 meters for flowline at index 20.
# Company match found at buffer distance 0.5 meters for flowline at index 21.
# Company match found at buffer distance 0.5 meters for flowline at index 22.
# Company match found at buffer distance 1.0 meters for flowline at index 23.
# Company match found at buffer distance 0.5 meters for flowline at index 24.
# Missing geometry for flowline at index 25. Skipping...
# Company match found at buffer distance 0.5 meters for flowline at index 26.
# Company match found at buffer distance 0.5 meters for flowline at index 27.
# Company match found at buffer distance 0.5 meters for flowline at index 28.
# Company match found at buffer distance 0.5 meters for flowline at index 29.
# Company match found at buffer distance 0.5 meters for flowline at index 30.
# Company match found at buffer distance 1.0 meters for flowline at index 31.
# Company match found at buffer distance 1.0 meters for flowline at index 32.
# Company match found at buffer distance 0.5 meters for flowline at index 33.
# Company match found at buffer distance 0.5 meters for flowline at index 34.
# Company match found at buffer distance 28.0 meters for flowline at index 35.
# Company match found at buffer distance 0.5 meters for flowline at index 36.
# Company match found at buffer distance 1.0 meters for flowline at index 37.
# Company match found at buffer distance 0.5 meters for flowline at index 38.
# Company match found at buffer distance 0.5 meters for flowline at index 39.
# Company match found at buffer distance 0.5 meters for flowline at index 40.
# Company match found at buffer distance 0.5 meters for flowline at index 41.
# Company match found at buffer distance 0.5 meters for flowline at index 42.
# Company match found at buffer distance 0.5 meters for flowline at index 43.
# Company match found at buffer distance 25.0 meters for flowline at index 44.
# Company match found at buffer distance 0.5 meters for flowline at index 45.
# Company match found at buffer distance 1.0 meters for flowline at index 46.
# Company match found at buffer distance 0.5 meters for flowline at index 47.
# Company match found at buffer distance 1.0 meters for flowline at index 48.
# Company match found at buffer distance 0.5 meters for flowline at index 49.
# Company match found at buffer distance 1.5 meters for flowline at index 50.
# Missing geometry for flowline at index 51. Skipping...
# Missing geometry for flowline at index 52. Skipping...
# Missing geometry for flowline at index 53. Skipping...
# Missing geometry for flowline at index 54. Skipping...
# Missing geometry for flowline at index 55. Skipping...
# Missing geometry for flowline at index 56. Skipping...
# Company match found at buffer distance 0.5 meters for flowline at index 57.
# Company match found at buffer distance 1.5 meters for flowline at index 58.
# Company match found at buffer distance 0.5 meters for flowline at index 59.
# Company match found at buffer distance 4.5 meters for flowline at index 60.
# Missing geometry for flowline at index 61. Skipping...
# Company match found at buffer distance 0.5 meters for flowline at index 62.
# Company match found at buffer distance 0.5 meters for flowline at index 63.
# Company match found at buffer distance 0.5 meters for flowline at index 64.
# Company match found at buffer distance 0.5 meters for flowline at index 65.
# Company match found at buffer distance 0.5 meters for flowline at index 66.
# Company match found at buffer distance 0.5 meters for flowline at index 67.
# Company match found at buffer distance 0.5 meters for flowline at index 68.
# Company match found at buffer distance 0.5 meters for flowline at index 69.
# Company match found at buffer distance 0.5 meters for flowline at index 70.
# Company match found at buffer distance 0.5 meters for flowline at index 71.
# Company match found at buffer distance 0.5 meters for flowline at index 72.
# Company match found at buffer distance 0.5 meters for flowline at index 73.
# Company match found at buffer distance 0.5 meters for flowline at index 74.
# Company match found at buffer distance 0.5 meters for flowline at index 75.
# Company match found at buffer distance 0.5 meters for flowline at index 76.
# Company match found at buffer distance 0.5 meters for flowline at index 77.
# Company match found at buffer distance 0.5 meters for flowline at index 78.
# Company match found at buffer distance 0.5 meters for flowline at index 79.
# Company match found at buffer distance 0.5 meters for flowline at index 80.
# Missing geometry for flowline at index 81. Skipping...
# Company match found at buffer distance 0.5 meters for flowline at index 82.
# Company match found at buffer distance 0.5 meters for flowline at index 83.
# Company match found at buffer distance 0.5 meters for flowline at index 84.
# Company match found at buffer distance 0.5 meters for flowline at index 85.
# Missing geometry for flowline at index 86. Skipping...
# Missing geometry for flowline at index 87. Skipping...
# Missing geometry for flowline at index 88. Skipping...
# Missing geometry for flowline at index 89. Skipping...
# Missing geometry for flowline at index 90. Skipping...
# Missing geometry for flowline at index 91. Skipping...
# Company match found at buffer distance 0.5 meters for flowline at index 92.
# Company match found at buffer distance 0.5 meters for flowline at index 93.
# Company match found at buffer distance 0.5 meters for flowline at index 94.
# Company match found at buffer distance 0.5 meters for flowline at index 95.
# Company match found at buffer distance 0.5 meters for flowline at index 96.
# Company match found at buffer distance 0.5 meters for flowline at index 97.
# Company match found at buffer distance 0.5 meters for flowline at index 98.
# Company match found at buffer distance 6.0 meters for flowline at index 99.
# Company match found at buffer distance 0.5 meters for flowline at index 100.
# Company match found at buffer distance 0.5 meters for flowline at index 101.
# Company match found at buffer distance 0.5 meters for flowline at index 102.
# Company match found at buffer distance 0.5 meters for flowline at index 103.
# Company match found at buffer distance 0.5 meters for flowline at index 104.
# Company match found at buffer distance 0.5 meters for flowline at index 105.
# No company match found for flowline at index 106 even after expanding buffer to 50.0 meters.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 30
#      27 buffered_flowline = flowline.geometry.buffer(buffer_distance)
#      29 # Iterate over the segments of the drop_crudeoil_offlocation_gdf multistring
# ---> 30 for _, crudeoil_line in drop_crudeoil_offlocation_gdf.iterrows():
#      31     # Check if the buffer intersects with the crude oil geometry
#      32     if buffered_flowline.intersects(crudeoil_line.geometry):
#      33         # Find the intersection points
#      34         intersection = buffered_flowline.intersection(crudeoil_line.geometry)
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/pandas/core/frame.py:1542, in DataFrame.iterrows(self)
#    1540 using_cow = using_copy_on_write()
#    1541 for k, v in zip(self.index, self.values):
# -> 1542     s = klass(v, index=columns, name=k).__finalize__(self)
#    1543     if using_cow and self._mgr.is_single_block:
#    1544         s._mgr.add_references(self._mgr)  # type: ignore[arg-type]
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/geopandas/geodataframe.py:1636, in GeoDataFrame._constructor_sliced.<locals>._geodataframe_constructor_sliced(*args, **kwargs)
#    1620 def _geodataframe_constructor_sliced(*args, **kwargs):
#    1621     """
#    1622     A specialized (Geo)Series constructor which can fall back to a
#    1623     Series if a certain operation does not produce geometries:
#    (...)
#    1634       checking the identity of the index)
#    1635     """
# -> 1636     srs = pd.Series(*args, **kwargs)
#    1637     is_row_proxy = srs.index is self.columns
#    1638     if is_geometry_type(srs) and not is_row_proxy:
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/pandas/core/series.py:583, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     581         data = data.copy()
#     582 else:
# --> 583     data = sanitize_array(data, index, dtype, copy)
#     585     manager = _get_option("mode.data_manager", silent=True)
#     586     if manager == "block":
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/pandas/core/construction.py:606, in sanitize_array(data, index, dtype, copy, allow_2d)
#     604 subarr = data
#     605 if data.dtype == object:
# --> 606     subarr = maybe_infer_to_datetimelike(data)
#     607     if (
#     608         object_index
#     609         and using_pyarrow_string_dtype()
#     610         and is_string_dtype(subarr)
#     611     ):
#     612         # Avoid inference when string option is set
#     613         subarr = data
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1190, in maybe_infer_to_datetimelike(value)
#    1185     return value
#    1187 # error: Incompatible return value type (got "Union[ExtensionArray,
#    1188 # ndarray[Any, Any]]", expected "Union[ndarray[Any, Any], DatetimeArray,
#    1189 # TimedeltaArray, PeriodArray, IntervalArray]")
# -> 1190 return lib.maybe_convert_objects(  # type: ignore[return-value]
#    1191     value,
#    1192     # Here we do not convert numeric dtypes, as if we wanted that,
#    1193     #  numpy would have done it for us.
#    1194     convert_numeric=False,
#    1195     convert_non_numeric=True,
#    1196     dtype_if_all_nat=np.dtype("M8[ns]"),
#    1197 )
#
# File lib.pyx:2543, in pandas._libs.lib.maybe_convert_objects()
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/numpy/core/numeric.py:274, in full(shape, fill_value, dtype, order, like)
#     270 def _full_dispatcher(shape, fill_value, dtype=None, order=None, *, like=None):
#     271     return(like,)
# --> 274 @set_array_function_like_doc
#     275 @set_module('numpy')
#     276 def full(shape, fill_value, dtype=None, order='C', *, like=None):
#     277     """
#     278     Return a new array of given shape and type, filled with `fill_value`.
#     279
#    (...)
#     320
#     321     """
#     322     if like is not None:
#
# KeyboardInterrupt:

# %%
matched_flowlines_gdf = gpd.GeoDataFrame(matched_flowlines, columns=flowlines_gdf.columns, crs=flowlines_gdf.crs)

# %%
matched_flowlines_gdf.shape
# Out:
# (84, 19)

# %% [markdown]
# ## Spatial Join

# %%
all_flowlines = gpd.sjoin(matched_flowlines_gdf, crudeoil_offlocation_gdf, how='right', op='intersects')
all_flowlines.head()
# Out:
# /Users/ichittumuri/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3490: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#    index_left  LOCATION_ID  FLOWLINEID  STARTLOCATIONID FLOWLINEACTION  \
# 0         NaN          NaN         NaN              NaN            NaN
# 1         NaN          NaN         NaN              NaN            NaN
# 2         NaN          NaN         NaN              NaN            NaN
# 3         NaN          NaN         NaN              NaN            NaN
# 4         NaN          NaN         NaN              NaN            NaN
#
#   ENTIRELINEREMOVED ACTIONDESCRIPTION RECEIVE_DATE  OPERATOR_NUM COMPANY_NAME  \
# 0               NaN               NaN          NaN           NaN          NaN
# 1               NaN               NaN          NaN           NaN          NaN
# 2               NaN               NaN          NaN           NaN          NaN
# 3               NaN               NaN          NaN           NaN          NaN
# 4               NaN               NaN          NaN           NaN          NaN
#
#   LOCATIONTYPE  ENDLAT  ENDLONG  STARTLAT  STARTLONG PIPEMATERIAL  \
# 0          NaN     NaN      NaN       NaN        NaN          NaN
# 1          NaN     NaN      NaN       NaN        NaN          NaN
# 2          NaN     NaN      NaN       NaN        NaN          NaN
# 3          NaN     NaN      NaN       NaN        NaN          NaN
# 4          NaN     NaN      NaN       NaN        NaN          NaN
#
#   BEDDINGMATERIAL TYPEOFFLUIDTRANS  MAXOPPRESSURE  \
# 0             NaN              NaN            NaN
# 1             NaN              NaN            NaN
# 2             NaN              NaN            NaN
# 3             NaN              NaN            NaN
# 4             NaN              NaN            NaN
#
#                           Operator       Fluid      Material  Diam_in  \
# 0  EVERGREEN NATURAL RESOURCES LLC         Gas         polly      4.0
# 1                 NOBLE ENERGY INC  Multiphase  Carbon Steel      3.0
# 2                   PDC ENERGY INC        None          None      NaN
# 3                 NOBLE ENERGY INC         Gas  Carbon Steel      3.0
# 4                 NOBLE ENERGY INC  Multiphase  Carbon Steel      3.0
#
#                         Status  Length_ft  SHAPE_Length  \
# 0                       Active    2277.71    693.972162
# 1                    Abandoned     651.58    198.525215
# 2  Partial Removed see comment    1902.59    579.687012
# 3                       Active     205.62     62.649840
# 4                       Active    2069.90    630.658768
#
#                                             geometry
# 0  MULTILINESTRING ((524642.670 4117088.796, 5246...
# 1  MULTILINESTRING ((527997.281 4463899.920, 5281...
# 2  MULTILINESTRING ((537519.211 4475984.687, 5375...
# 3  MULTILINESTRING ((544793.476 4489156.672, 5447...
# 4  MULTILINESTRING ((526448.455 4461830.702, 5258...

# %%
all_flowlines.shape
# Out:
# (260026, 27)

# %%
matches_joined = all_flowlines.dropna()
matches_joined.head()
# Out:
#        index_left  LOCATION_ID  FLOWLINEID  STARTLOCATIONID  \
# 1462          8.0     452637.0    462601.0         306712.0
# 9382         16.0     336437.0    473671.0         336315.0
# 9382         21.0     336437.0    473673.0         331851.0
# 16194        69.0     461164.0    461525.0         302916.0
# 19477        57.0     321398.0    462649.0         321341.0
#
#                FLOWLINEACTION ENTIRELINEREMOVED  \
# 1462           Out of Service                 1
# 9382           Out of Service                 1
# 9382           Out of Service                 1
# 16194          Out of Service                 1
# 19477  Pre-Abandonment Notice                 1
#
#                                        ACTIONDESCRIPTION  \
# 1462   The flowline (12325148FL) servicing the Elliot...
# 9382   The flowline (12321397_FL) servicing the Geist...
# 9382   The flowline (12330823_FL) servicing the Geist...
# 16194  The flowline (12330024FL) servicing the DF RAN...
# 19477  The flowline serving the Becky 04-36 (05-013-0...
#
#                      RECEIVE_DATE  OPERATOR_NUM  \
# 1462   2023-10-24T10:08:19.323000       10459.0
# 9382   2023-10-19T11:30:16.719999       10633.0
# 9382   2023-10-19T11:30:16.719999       10633.0
# 16194  2023-10-11T16:38:16.743000       10575.0
# 19477  2023-11-17T11:11:43.016998       10459.0
#
#                                             COMPANY_NAME  \
# 1462   EXTRACTION OIL & GAS INC                      ...
# 9382   CRESTONE PEAK RESOURCES OPERATING LLC         ...
# 9382   CRESTONE PEAK RESOURCES OPERATING LLC         ...
# 16194  8 NORTH LLC                                   ...
# 19477  EXTRACTION OIL & GAS INC                      ...
#
#                 LOCATIONTYPE     ENDLAT     ENDLONG   STARTLAT   STARTLONG  \
# 1462   Production Facilities  40.267332 -105.037459  40.266917 -105.043033
# 9382   Production Facilities  40.185970 -104.918804  40.187553 -104.916936
# 9382   Production Facilities  40.185945 -104.918760  40.186544 -104.919688
# 16194  Production Facilities  40.906867 -104.200190  40.908605 -104.194062
# 19477  Production Facilities  40.089921 -105.066961  40.090185 -105.069508
#
#        PIPEMATERIAL   BEDDINGMATERIAL TYPEOFFLUIDTRANS  MAXOPPRESSURE  \
# 1462   Carbon Steel  Native Materials       Multiphase         1140.0
# 9382   Carbon Steel  Native Materials       Multiphase          265.0
# 9382   Carbon Steel  Native Materials       Multiphase          320.0
# 16194  Carbon Steel  Native Materials       Multiphase           57.0
# 19477  Carbon Steel  Native Materials       Multiphase          410.0
#
#                                     Operator       Fluid      Material  \
# 1462                EXTRACTION OIL & GAS INC  Multiphase  Carbon Steel
# 9382   CRESTONE PEAK RESOURCES OPERATING LLC  Multiphase         Steel
# 9382   CRESTONE PEAK RESOURCES OPERATING LLC  Multiphase         Steel
# 16194                            8 NORTH LLC  Multiphase  Carbon Steel
# 19477               EXTRACTION OIL & GAS INC  Multiphase  Carbon Steel
#
#        Diam_in          Status  Length_ft  SHAPE_Length  \
# 1462     2.375  Out of Service     510.01    155.389256
# 9382     2.000       Abandoned    3457.32   1053.369404
# 9382     2.000       Abandoned    3457.32   1053.369404
# 16194    2.375  Out of Service    2381.13    725.519247
# 19477    2.250  Out of Service     969.49    295.382313
#
#                                                 geometry
# 1462   MULTILINESTRING ((496681.603 4457400.496, 4966...
# 9382   MULTILINESTRING ((507139.811 4448160.801, 5071...
# 9382   MULTILINESTRING ((507139.811 4448160.801, 5071...
# 16194  MULTILINESTRING ((567873.747 4528925.507, 5678...
# 19477  MULTILINESTRING ((494261.152 4438023.066, 4942...

# %%
matches_joined.shape
# Out:
# (25, 27)

# %%
all_flowlines.to_file("all_flowlines.geojson", driver='GeoJSON')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 all_flowlines.to_file("all_flowlines.geojson", driver='GeoJSON')
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/geopandas/geodataframe.py:1246, in GeoDataFrame.to_file(self, filename, driver, schema, index, **kwargs)
#    1155 """Write the ``GeoDataFrame`` to a file.
#    1156
#    1157 By default, an ESRI shapefile is written, but any OGR data source
#    (...)
#    1242
#    1243 """
#    1244 from geopandas.io.file import _to_file
# -> 1246 _to_file(self, filename, driver, schema, index, **kwargs)
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/geopandas/io/file.py:633, in _to_file(df, filename, driver, schema, index, mode, crs, engine, **kwargs)
#     630     raise ValueError(f"'mode' should be one of 'w' or 'a', got '{mode}' instead")
#     632 if engine == "fiona":
# --> 633     _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     634 elif engine == "pyogrio":
#     635     _to_file_pyogrio(df, filename, driver, schema, crs, mode, **kwargs)
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/geopandas/io/file.py:664, in _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     660     crs_wkt = crs.to_wkt("WKT1_GDAL")
#     661 with fiona.open(
#     662     filename, mode=mode, driver=driver, crs_wkt=crs_wkt, schema=schema, **kwargs
#     663 ) as colxn:
# --> 664     colxn.writerecords(df.iterfeatures())
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/fiona/collection.py:558, in Collection.writerecords(self, records)
#     556 if self.mode not in ("a", "w"):
#     557     raise OSError("collection not open for writing")
# --> 558 self.session.writerecs(records, self)
#     559 self._len = self.session.get_length()
#     560 self._bounds = None
#
# File fiona/ogrext.pyx:1392, in fiona.ogrext.WritingSession.writerecs()
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/geopandas/geodataframe.py:951, in GeoDataFrame.iterfeatures(self, na, show_bbox, drop_id)
#     949 feature["type"] = "Feature"
#     950 feature["properties"] = properties_items
# --> 951 feature["geometry"] = mapping(geom) if geom else None
#     953 if show_bbox:
#     954     feature["bbox"] = geom.bounds if geom else None
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/shapely/geometry/base.py:937, in BaseMultipartGeometry.__bool__(self)
#     936 def __bool__(self):
# --> 937     return self.is_empty is False
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/shapely/geometry/base.py:629, in BaseGeometry.is_empty(self)
#     626 @property
#     627 def is_empty(self):
#     628     """True if the set of points in this geometry is empty, else False"""
# --> 629     return bool(shapely.is_empty(self))
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/shapely/decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File ~/Desktop/MINES/COGCC-Risk-Analysis/.venv/lib/python3.9/site-packages/shapely/predicates.py:162, in is_empty(geometry, **kwargs)
#     137 @multithreading_enabled
#     138 def is_empty(geometry, **kwargs):
#     139     """Returns True if a geometry is an empty point, polygon, etc.
#     140
#     141     Parameters
#    (...)
#     160     False
#     161     """
# --> 162     return lib.is_empty(geometry, **kwargs)
#
# KeyboardInterrupt:

# %%
matches_joined.to_file("matched_flowlines.geojson", driver='GeoJSON')
